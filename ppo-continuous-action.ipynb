# %%
# !apt-get install -y \
#     libgl1-mesa-dev \
#     libgl1-mesa-glx \
#     libglew-dev \
#     libosmesa6-dev \
#     software-properties-common

# !apt-get install -y patchelf

# !apt-get update --fix-missing
# !pip install mujoco
# !pip install  gymnasium
# !apt-get update --fix-missing
# !pip uninstall stable-baselines3

# %%
import os
import time
import wandb
import random
from distutils.util import strtobool

import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Normal
from torch.utils.tensorboard import SummaryWriter

# %%
def make_env(env_id, idx, capture_video, run_name, gamma):
    def thunk():
        if capture_video:
            env = gym.make(env_id, render_mode="rgb_array")
        else:
            env = gym.make(env_id)
        env = gym.wrappers.FlattenObservation(env)
        env = gym.wrappers.RecordEpisodeStatistics(env)
        if capture_video and idx == 0:
            env = gym.wrappers.RecordVideo(env, f"videos/{run_name}")
        env = gym.wrappers.ClipAction(env)
        env = gym.wrappers.NormalizeObservation(env)
        env = gym.wrappers.TransformObservation(env, lambda obs: np.clip(obs, -10, 10))
        env = gym.wrappers.NormalizeReward(env, gamma=gamma)
        env = gym.wrappers.TransformReward(env, lambda reward: np.clip(reward, -10, 10))
        return env

    return thunk

# %%
def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, std)
    torch.nn.init.constant_(layer.bias, bias_const)
    return layer

# %%
class Agent(nn.Module):

    def __init__(self, envs):
        super().__init__()
        self.critic = nn.Sequential(
            layer_init(nn.Linear(np.array(envs.single_observation_space.shape).prod(),64)),
            nn.Tanh(),
            layer_init(nn.Linear(64,64)),
            nn.Tanh(),
            layer_init(nn.Linear(64,1), std=1.0),
        )

        self.actor_mean = nn.Sequential(
            layer_init(nn.Linear(np.array(envs.single_observation_space.shape).prod(),64)),
            nn.Tanh(),
            layer_init(nn.Linear(64,64)),
            nn.Tanh(),
            layer_init(nn.Linear(64,np.prod(envs.single_action_space.shape)), std=0.01),
        )

        self.actor_logstd = nn.Parameter(torch.zeros(1,np.prod(envs.single_action_space.shape)))

    def get_value(self, x):
        return self.critic(x)

    def get_action_and_value(self, x, action=None):
        action_value = self.critic(x)
        action_mean = self.actor_mean(x)
        action_logstd = self.actor_logstd.expand_as(action_mean)
        action_std = torch.exp(action_logstd)
        probs = Normal(action_mean,action_std)
        if action is None:
            action = probs.sample()
        return action, probs.log_prob(action).sum(1), probs.entropy().sum(1),action_value

# %%
def train(
    seed,
    env_id,
    total_timesteps,
    learning_rate,
    num_envs,
    num_steps,
    gamma,
    gae_lambda,
    num_minibatches,
    update_epochs,
    clip_coef,
    entropy_coef,
    vf_coef,
    max_grad_norm,
    target_kl):

    batch_size = int(num_envs * num_steps)
    minibatch_size = batch_size // num_minibatches

    run_name = f"{env_id}__{seed}__{int(time.time())}"
    wandb.init(
        project="ppo-mujoco-benchmark",
        config={
            "env":env_id,
            "timesteps":total_timesteps,
            "lr":learning_rate,
            "num_steps":num_steps,
            "gamma":gamma,
            "gae_lambda":gae_lambda,
            "num_minibatches":num_minibatches,
            "update_epochs":update_epochs,
            "clip_coef":clip_coef,
            "entropy_coef":entropy_coef,
            "vf_coef":vf_coef,
            "max_grad_norm":max_grad_norm
        },
        sync_tensorboard=True,
        monitor_gym=True,
        name=run_name
    )
    writer = SummaryWriter(f"runs/{run_name}")

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    envs = gym.vector.SyncVectorEnv(
        [make_env(env_id, i, True, run_name, gamma) for i in range(num_envs)]
    )

    agent = Agent(envs).to(device)
    optimizer = optim.Adam(agent.parameters(),lr=learning_rate, eps=1e-5)

    obs = torch.zeros((num_steps, num_envs) + envs.single_observation_space.shape).to(device)
    actions = torch.zeros((num_steps,num_envs) + envs.single_action_space.shape).to(device)
    logprobs = torch.zeros((num_steps, num_envs)).to(device)
    rewards = torch.zeros((num_steps, num_envs)).to(device)
    dones = torch.zeros((num_steps, num_envs)).to(device)
    values = torch.zeros((num_steps, num_envs)).to(device)

    global_step = 0
    start_time = time.time()
    next_obs, _ = envs.reset(seed=seed)
    next_obs = torch.Tensor(next_obs).to(device)
    next_done = torch.zeros(num_envs).to(device)
    num_updates = total_timesteps // batch_size

    for update in range(1, num_updates + 1):

        frac = 1.0 - (update - 1.0) / num_updates
        lrnow = frac * learning_rate
        optimizer.param_groups[0]["lr"] = lrnow

        for step in range(num_steps):

            global_step += 1 * num_envs
            obs[step] = next_obs
            dones[step] = next_done

            with torch.no_grad():
                action, logprob, _, value = agent.get_action_and_value(next_obs)
                values[step] = value.flatten()

            actions[step] = action
            logprobs[step] = logprob

            next_obs, reward, terminated, truncated, infos = envs.step(action.cpu().numpy())
            done = np.logical_or(terminated, truncated)
            rewards[step] = torch.tensor(reward).to(device).view(-1)
            next_obs, next_done = torch.Tensor(next_obs).to(device), torch.Tensor(next_done).to(device)

            if "final_info" not in infos:
                continue

            for info in infos["final_info"]:
                if info is None:
                    continue

                print(f"global_step={global_step}, episodic_return={info['episode']['r']}")
                writer.add_scalar("charts/episodic_return", info["episode"]["r"], global_step)
                writer.add_scalar("charts/episodic_lenght", info["episode"]["l"], global_step)

        with torch.no_grad():
            next_value = agent.get_value(next_obs).reshape(1, -1)
            advantages = torch.zeros_like(rewards).to(device)
            lastgaelam = 0
            for t in reversed(range(num_steps)):
                if t == num_steps - 1:
                    nextnonterminal = 1.0 - next_done
                    nextvalues = next_value
                else:
                    nextnonterminal = 1.0 - dones[t + 1]
                    nextvalues = values [t + 1]

                delta = rewards[t] + gamma * nextvalues * nextnonterminal - values[t]
                advantages[t] = delta + gamma * gae_lambda * nextnonterminal  * lastgaelam
                lastgaelam = advantages[t]
            returns = advantages + values


        b_obs = obs.reshape((-1, ) + envs.single_observation_space.shape )
        b_logprobs = logprobs.reshape(-1)
        b_actions = actions.reshape((-1, ) + envs.single_action_space.shape)
        b_advantages = advantages.reshape(-1)
        b_returns = returns.reshape(-1)
        b_values = values.reshape(-1)

        b_inds = np.arange(batch_size)
        clipfracs = []

        for epoch in range(update_epochs):
            np.random.shuffle(b_inds)
            for start in range(0, batch_size, minibatch_size):
                end = start + minibatch_size
                mb_inds = b_inds[start:end]

                _, newlogprob, entropy, newvalue = agent.get_action_and_value(b_obs[mb_inds],b_actions[mb_inds])
                logratio = newlogprob - b_logprobs[mb_inds]
                ratio = logratio.exp()

                with torch.no_grad():
                    old_approx_kl = (-logratio).mean()
                    approx_kl = ((ratio -1) - logratio).mean()

                mb_advantages = b_advantages[mb_inds]
                mb_advantages = (mb_advantages - mb_advantages.mean()) / (mb_advantages.std() + 1e-8)

                pg_loss1 = -mb_advantages * ratio
                pg_loss2 = -mb_advantages * torch.clamp(ratio, 1 - clip_coef, 1 + clip_coef )
                pg_loss = torch.max(pg_loss1, pg_loss2).mean()

                newvalue = newvalue.view(-1)

                v_loss_unclipped = (newvalue - b_returns[mb_inds]) ** 2
                v_clipped = b_values[mb_inds] + torch.clamp(
                    newvalue - b_values[mb_inds],
                    -clip_coef,
                    clip_coef,
                )
                v_loss_clipped = (v_clipped - b_returns[mb_inds]) ** 2
                v_loss_max = torch.max(v_loss_unclipped, v_loss_clipped)
                v_loss = 0.5 * v_loss_max.mean()

                entropy_loss = entropy.mean()
                loss = pg_loss - entropy_coef * entropy_loss + v_loss * vf_coef


                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(agent.parameters(), max_grad_norm)
                optimizer.step()

            if target_kl is not None:
                if approx_kl > target_kl:
                    break

            y_pred, y_true = b_values.cpu().numpy(), b_returns.cpu().numpy()
            var_y = np.var(y_true)
            explained_var = np.nan if var_y == 0 else 1 - np.var(y_true - y_pred) / var_y

            writer.add_scalar("charts/learning_rate", optimizer.param_groups[0]["lr"], global_step)
            writer.add_scalar("losses/value_loss", v_loss.item(), global_step)
            writer.add_scalar("losses/policy_loss", pg_loss.item(), global_step)
            writer.add_scalar("losses/entropy", entropy_loss.item(), global_step)
            writer.add_scalar("losses/old_approx_kl", old_approx_kl.item(), global_step)
            writer.add_scalar("losses/approx_kl",approx_kl.item(), global_step)
            writer.add_scalar("losses/explained_variance", explained_var, global_step)
            writer.add_scalar("charts/SPS", int(global_step/ (time.time() - start_time)), global_step)

    envs.close()
    writer.close()

# %%
seed = 2
total_timesteps = 1000000
learning_rate = 0.00003
num_envs = 1
num_steps = 2048
gamma = 0.99
gae_lambda = 0.95
num_minibatches = 64
update_epochs = 10
clip_coef = 0.5
ent_coef = 0.0
vf_coef = 0.5
max_grad_norm = 0.5
target_kl = None
env = {"hopper":"Hopper-v2","humanoid":"Humanoid-v2","halfCheetah":"HalfCheetah-v2","ant":"Ant-v2"}

# %%
train(seed,
      env["hopper"],
      total_timesteps,
      learning_rate,
      num_envs,
      num_steps,
      gamma,
      gae_lambda,
      num_minibatches,
      update_epochs,
      clip_coef,
      ent_coef,
      vf_coef,
      max_grad_norm,
      target_kl)
# Out:
# Finishing last run (ID:9ajhwry9) before initializing another...
# VBox(children=(Label(value='6.987 MB of 6.987 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>charts/SPS</td><td>▁▇████████████▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>charts/episodic_lenght</td><td>▂▁▁▁▁▂▁▁▂▁▃▃▃▄▃▃▃▅▂▄▃▄▅▅▆▅▅▅▅▆▅▆▇▅▄▆█▆█▇</td></tr><tr><td>charts/episodic_return</td><td>▁▁▁▁▁▂▁▁▁▁▂▂▃▃▃▃▃▄▂▄▃▄▅▄▅▅▄▅▅▆▅▆▆▅▄▅█▆▇▇</td></tr><tr><td>charts/learning_rate</td><td>███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁</td></tr><tr><td>global_step</td><td>▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>losses/approx_kl</td><td>▂▃▃▃▄▄▅█▅▅▄▃▄▄▃▅▃▄▅▄▃▃▅▃▆▅▆▄▄▃▃▂▃▃▃▂▂▁▁▁</td></tr><tr><td>losses/entropy</td><td>███▇▇▆▆▆▅▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>losses/explained_variance</td><td>▃▃▁▄▅▇█▇▇███████████████████████████████</td></tr><tr><td>losses/old_approx_kl</td><td>▄▆▁▅▅█▃▅▇▇▃▅▆▇▆▁▅▃▄▆▇▁▁▅▆▇▆▅▁▄▅▃▄▅▄▅▄▄▄▃</td></tr><tr><td>losses/policy_loss</td><td>▇▅▄▃▆▃▅▃▄▆▁▄▄▅▄▅▄▄▂▄▅▅▅▂▂▃▄▆▆▄▂▇▄▅▇▇█▇▇▇</td></tr><tr><td>losses/value_loss</td><td>█▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>charts/SPS</td><td>150.0</td></tr><tr><td>charts/episodic_lenght</td><td>90.0</td></tr><tr><td>charts/episodic_return</td><td>619.55664</td></tr><tr><td>charts/learning_rate</td><td>0.0</td></tr><tr><td>global_step</td><td>999424</td></tr><tr><td>losses/approx_kl</td><td>0.0</td></tr><tr><td>losses/entropy</td><td>21.40192</td></tr><tr><td>losses/explained_variance</td><td>0.85805</td></tr><tr><td>losses/old_approx_kl</td><td>-0.0002</td></tr><tr><td>losses/policy_loss</td><td>0.0001</td></tr><tr><td>losses/value_loss</td><td>0.00086</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Humanoid-v2__2__1700143689</strong> at: <a href='https://wandb.ai/chkda/ppo-mujoco-benchmark/runs/9ajhwry9' target="_blank">https://wandb.ai/chkda/ppo-mujoco-benchmark/runs/9ajhwry9</a><br/> View job at <a href='https://wandb.ai/chkda/ppo-mujoco-benchmark/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjExNjIyMDcxMw==/version_details/v5' target="_blank">https://wandb.ai/chkda/ppo-mujoco-benchmark/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjExNjIyMDcxMw==/version_details/v5</a><br/>Synced 5 W&B file(s), 27 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231116_140809-9ajhwry9/logs</code>
# Successfully finished last run (ID:9ajhwry9). Initializing new run:<br/>
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/notebooks/rl-algos/wandb/run-20231116_160344-olzbx70t</code>
# Syncing run <strong><a href='https://wandb.ai/chkda/ppo-mujoco-benchmark/runs/olzbx70t' target="_blank">Hopper-v2__2__1700150624</a></strong> to <a href='https://wandb.ai/chkda/ppo-mujoco-benchmark' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/chkda/ppo-mujoco-benchmark' target="_blank">https://wandb.ai/chkda/ppo-mujoco-benchmark</a>
#  View run at <a href='https://wandb.ai/chkda/ppo-mujoco-benchmark/runs/olzbx70t' target="_blank">https://wandb.ai/chkda/ppo-mujoco-benchmark/runs/olzbx70t</a>
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# /usr/local/lib/python3.9/dist-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment Hopper-v2 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(
# /usr/local/lib/python3.9/dist-packages/gymnasium/envs/mujoco/mujoco_env.py:211: DeprecationWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.deprecation(
# Moviepy - Building video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-0.mp4
# global_step=21, episodic_return=[22.78595]
# Moviepy - Building video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-1.mp4.
# Moviepy - Writing video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-1.mp4
# global_step=51, episodic_return=[36.201855]
# global_step=72, episodic_return=[23.97786]
# global_step=82, episodic_return=[4.733545]
# global_step=99, episodic_return=[10.860237]
# global_step=116, episodic_return=[10.610827]
# global_step=125, episodic_return=[6.901435]
# global_step=135, episodic_return=[8.571838]
# Moviepy - Building video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-8.mp4.
# Moviepy - Writing video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-8.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-8.mp4
# global_step=155, episodic_return=[20.855782]
# global_step=174, episodic_return=[13.612928]
# global_step=194, episodic_return=[9.241912]
# global_step=217, episodic_return=[22.081654]
# global_step=235, episodic_return=[15.023452]
# global_step=248, episodic_return=[3.9606402]
# global_step=259, episodic_return=[9.447323]
# global_step=306, episodic_return=[38.756435]
# global_step=323, episodic_return=[8.405559]
# global_step=342, episodic_return=[12.99211]
# global_step=356, episodic_return=[8.711075]
# global_step=374, episodic_return=[18.762356]
# global_step=387, episodic_return=[10.6585865]
# global_step=434, episodic_return=[74.67044]
# global_step=441, episodic_return=[4.609004]
# global_step=457, episodic_return=[10.13831]
# global_step=480, episodic_return=[25.526222]
# global_step=494, episodic_return=[12.102865]
# global_step=511, episodic_return=[19.087944]
# Moviepy - Building video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-27.mp4.
# Moviepy - Writing video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-27.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-27.mp4
# global_step=526, episodic_return=[7.005193]
# global_step=540, episodic_return=[13.418036]
# global_step=567, episodic_return=[21.080496]
# global_step=581, episodic_return=[9.381006]
# global_step=601, episodic_return=[21.635185]
# global_step=617, episodic_return=[14.461506]
# global_step=666, episodic_return=[52.98349]
# global_step=688, episodic_return=[22.04763]
# global_step=705, episodic_return=[11.505437]
# global_step=725, episodic_return=[8.445497]
# global_step=744, episodic_return=[18.79848]
# global_step=776, episodic_return=[27.377815]
# global_step=821, episodic_return=[43.512737]
# global_step=848, episodic_return=[14.8426485]
# global_step=868, episodic_return=[10.478578]
# global_step=889, episodic_return=[24.80492]
# global_step=904, episodic_return=[14.426449]
# global_step=920, episodic_return=[12.382785]
# global_step=936, episodic_return=[15.499781]
# global_step=992, episodic_return=[90.34652]
# global_step=1002, episodic_return=[8.2004385]
# global_step=1020, episodic_return=[8.271515]
# global_step=1036, episodic_return=[13.353082]
# global_step=1061, episodic_return=[17.222794]
# global_step=1075, episodic_return=[13.01845]
# global_step=1098, episodic_return=[25.487658]
# global_step=1107, episodic_return=[6.9929276]
# global_step=1114, episodic_return=[4.6855507]
# global_step=1131, episodic_return=[17.651102]
# global_step=1144, episodic_return=[10.1756315]
# global_step=1160, episodic_return=[8.785212]
# global_step=1193, episodic_return=[20.333618]
# global_step=1210, episodic_return=[10.002697]
# global_step=1221, episodic_return=[8.730489]
# global_step=1235, episodic_return=[12.317964]
# global_step=1248, episodic_return=[5.153725]
# global_step=1266, episodic_return=[16.74383]
# Moviepy - Building video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-64.mp4.
# Moviepy - Writing video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-64.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-64.mp4
# global_step=1276, episodic_return=[8.004535]
# global_step=1288, episodic_return=[10.985145]
# global_step=1309, episodic_return=[10.34255]
# global_step=1322, episodic_return=[6.2239747]
# global_step=1345, episodic_return=[27.626156]
# global_step=1358, episodic_return=[11.80439]
# global_step=1370, episodic_return=[11.156066]
# global_step=1394, episodic_return=[11.034778]
# global_step=1408, episodic_return=[11.645918]
# global_step=1420, episodic_return=[8.071956]
# global_step=1438, episodic_return=[16.569595]
# global_step=1469, episodic_return=[27.591425]
# global_step=1481, episodic_return=[10.115369]
# global_step=1501, episodic_return=[15.680364]
# global_step=1524, episodic_return=[17.506306]
# global_step=1538, episodic_return=[9.04779]
# global_step=1546, episodic_return=[4.864487]
# global_step=1572, episodic_return=[15.464795]
# global_step=1589, episodic_return=[13.485472]
# global_step=1599, episodic_return=[6.6228275]
# global_step=1624, episodic_return=[32.115345]
# global_step=1641, episodic_return=[12.790471]
# global_step=1661, episodic_return=[8.864438]
# global_step=1698, episodic_return=[39.767097]
# global_step=1711, episodic_return=[7.772832]
# global_step=1735, episodic_return=[18.433437]
# global_step=1746, episodic_return=[9.805973]
# global_step=1775, episodic_return=[19.714558]
# global_step=1795, episodic_return=[11.216541]
# global_step=1807, episodic_return=[9.785376]
# global_step=1816, episodic_return=[5.671393]
# global_step=1830, episodic_return=[11.810668]
# global_step=1846, episodic_return=[15.250599]
# global_step=1866, episodic_return=[10.318937]
# global_step=1881, episodic_return=[8.087862]
# global_step=1894, episodic_return=[6.648379]
# global_step=1910, episodic_return=[9.671999]
# global_step=1930, episodic_return=[8.670297]
# global_step=1958, episodic_return=[25.621815]
# global_step=2000, episodic_return=[30.266758]
# global_step=2021, episodic_return=[7.0303884]
# global_step=2030, episodic_return=[6.065892]
# global_step=2051, episodic_return=[10.1362705]
# global_step=2090, episodic_return=[29.122898]
# global_step=2132, episodic_return=[28.0439]
# global_step=2144, episodic_return=[10.04659]
# global_step=2162, episodic_return=[10.126253]
# global_step=2196, episodic_return=[26.447124]
# global_step=2213, episodic_return=[10.3700075]
# global_step=2233, episodic_return=[23.718729]
# global_step=2251, episodic_return=[8.46216]
# global_step=2261, episodic_return=[8.322682]
# global_step=2275, episodic_return=[12.056589]
# global_step=2287, episodic_return=[8.809629]
# global_step=2296, episodic_return=[7.6107273]
# global_step=2314, episodic_return=[15.964191]
# global_step=2323, episodic_return=[5.794452]
# global_step=2332, episodic_return=[6.6349688]
# global_step=2347, episodic_return=[9.402947]
# global_step=2376, episodic_return=[25.0398]
# global_step=2397, episodic_return=[23.054544]
# Moviepy - Building video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-125.mp4.
# Moviepy - Writing video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-125.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-125.mp4
# global_step=2409, episodic_return=[7.2866344]
# global_step=2437, episodic_return=[36.84675]
# global_step=2454, episodic_return=[18.51517]
# global_step=2464, episodic_return=[8.035395]
# global_step=2475, episodic_return=[7.497376]
# global_step=2487, episodic_return=[9.135271]
# global_step=2506, episodic_return=[16.270504]
# global_step=2518, episodic_return=[8.216037]
# global_step=2527, episodic_return=[6.7215886]
# global_step=2591, episodic_return=[117.26105]
# global_step=2609, episodic_return=[18.196932]
# global_step=2620, episodic_return=[8.980855]
# global_step=2634, episodic_return=[10.92584]
# global_step=2653, episodic_return=[17.657818]
# global_step=2676, episodic_return=[10.538136]
# global_step=2691, episodic_return=[9.761757]
# global_step=2747, episodic_return=[87.47001]
# global_step=2765, episodic_return=[11.702009]
# global_step=2806, episodic_return=[32.802887]
# global_step=2818, episodic_return=[10.8737]
# global_step=2842, episodic_return=[29.947374]
# global_step=2858, episodic_return=[13.758559]
# global_step=2869, episodic_return=[8.005264]
# global_step=2882, episodic_return=[7.9599524]
# global_step=2901, episodic_return=[9.631929]
# global_step=2916, episodic_return=[15.316397]
# global_step=2936, episodic_return=[11.95052]
# global_step=2947, episodic_return=[7.9323077]
# global_step=2957, episodic_return=[6.62689]
# global_step=2986, episodic_return=[19.937174]
# global_step=3018, episodic_return=[14.104262]
# global_step=3027, episodic_return=[6.5455494]
# global_step=3043, episodic_return=[13.44235]
# global_step=3063, episodic_return=[20.09212]
# global_step=3078, episodic_return=[10.310337]
# global_step=3094, episodic_return=[8.6770115]
# global_step=3106, episodic_return=[6.0498524]
# global_step=3135, episodic_return=[36.97492]
# global_step=3151, episodic_return=[11.736275]
# global_step=3176, episodic_return=[23.97704]
# global_step=3186, episodic_return=[7.2717443]
# global_step=3217, episodic_return=[38.048176]
# global_step=3233, episodic_return=[14.417183]
# global_step=3261, episodic_return=[26.552156]
# global_step=3275, episodic_return=[13.143725]
# global_step=3292, episodic_return=[15.051492]
# global_step=3313, episodic_return=[19.681612]
# global_step=3324, episodic_return=[9.145499]
# global_step=3335, episodic_return=[8.9813]
# global_step=3347, episodic_return=[7.3625917]
# global_step=3357, episodic_return=[6.88957]
# global_step=3369, episodic_return=[7.6979103]
# global_step=3395, episodic_return=[23.275846]
# global_step=3408, episodic_return=[9.975347]
# global_step=3474, episodic_return=[90.24538]
# global_step=3496, episodic_return=[12.8252945]
# global_step=3506, episodic_return=[4.483366]
# global_step=3532, episodic_return=[29.251621]
# global_step=3551, episodic_return=[16.637907]
# global_step=3575, episodic_return=[21.075432]
# global_step=3617, episodic_return=[65.72606]
# global_step=3644, episodic_return=[33.809914]
# global_step=3673, episodic_return=[30.894535]
# global_step=3692, episodic_return=[13.5286255]
# global_step=3700, episodic_return=[5.123032]
# global_step=3726, episodic_return=[14.934986]
# global_step=3739, episodic_return=[5.7680545]
# global_step=3756, episodic_return=[13.6955805]
# global_step=3771, episodic_return=[9.463326]
# global_step=3780, episodic_return=[6.4220753]
# global_step=3838, episodic_return=[98.412155]
# global_step=3853, episodic_return=[12.559672]
# global_step=3927, episodic_return=[102.41988]
# global_step=3941, episodic_return=[12.227107]
# global_step=3994, episodic_return=[71.8086]
# global_step=4039, episodic_return=[34.050823]
# global_step=4055, episodic_return=[14.129664]
# global_step=4083, episodic_return=[39.639328]
# global_step=4106, episodic_return=[30.243118]
# global_step=4134, episodic_return=[20.334208]
# global_step=4196, episodic_return=[64.21321]
# global_step=4211, episodic_return=[14.170601]
# global_step=4227, episodic_return=[14.416044]
# global_step=4243, episodic_return=[10.667455]
# global_step=4275, episodic_return=[9.556605]
# global_step=4310, episodic_return=[35.950565]
# global_step=4322, episodic_return=[11.180645]
# global_step=4350, episodic_return=[10.106503]
# global_step=4362, episodic_return=[7.8701673]
# global_step=4372, episodic_return=[7.9729877]
# global_step=4379, episodic_return=[4.7295403]
# Moviepy - Building video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-216.mp4.
# Moviepy - Writing video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-216.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-216.mp4
# global_step=4426, episodic_return=[59.68289]
# global_step=4448, episodic_return=[12.876695]
# global_step=4462, episodic_return=[9.5455475]
# global_step=4476, episodic_return=[9.884925]
# global_step=4491, episodic_return=[11.848594]
# global_step=4511, episodic_return=[17.737097]
# global_step=4566, episodic_return=[96.991455]
# global_step=4581, episodic_return=[13.478153]
# global_step=4607, episodic_return=[10.613042]
# global_step=4621, episodic_return=[12.077562]
# global_step=4630, episodic_return=[6.78384]
# global_step=4639, episodic_return=[4.939935]
# global_step=4655, episodic_return=[8.111456]
# global_step=4687, episodic_return=[25.536617]
# global_step=4715, episodic_return=[14.656013]
# global_step=4730, episodic_return=[13.451569]
# global_step=4761, episodic_return=[43.18876]
# global_step=4821, episodic_return=[99.072716]
# global_step=4858, episodic_return=[33.011837]
# global_step=4886, episodic_return=[30.163136]
# global_step=4906, episodic_return=[12.190961]
# global_step=4928, episodic_return=[26.058702]
# global_step=4955, episodic_return=[28.745358]
# global_step=4964, episodic_return=[6.477964]
# global_step=4976, episodic_return=[9.399765]
# global_step=4986, episodic_return=[9.069439]
# global_step=5013, episodic_return=[24.942669]
# global_step=5082, episodic_return=[111.429955]
# global_step=5107, episodic_return=[18.885792]
# global_step=5154, episodic_return=[80.35846]
# global_step=5169, episodic_return=[14.032774]
# global_step=5194, episodic_return=[20.803234]
# global_step=5214, episodic_return=[18.80049]
# global_step=5265, episodic_return=[60.529736]
# global_step=5288, episodic_return=[25.592005]
# global_step=5302, episodic_return=[12.721649]
# global_step=5328, episodic_return=[27.812159]
# global_step=5343, episodic_return=[7.6032352]
# global_step=5368, episodic_return=[9.615866]
# global_step=5399, episodic_return=[14.119249]
# global_step=5412, episodic_return=[11.464199]
# global_step=5430, episodic_return=[16.282637]
# global_step=5485, episodic_return=[70.15557]
# global_step=12655, episodic_return=[67.319]
# global_step=12671, episodic_return=[16.219015]
# global_step=12686, episodic_return=[7.7648234]
# global_step=12698, episodic_return=[8.856998]
# global_step=12728, episodic_return=[36.325436]
# global_step=12736, episodic_return=[4.906083]
# global_step=12771, episodic_return=[57.69206]
# global_step=12784, episodic_return=[9.628276]
# global_step=12818, episodic_return=[58.66621]
# global_step=12847, episodic_return=[49.158524]
# global_step=12859, episodic_return=[9.157012]
# global_step=12879, episodic_return=[20.48853]
# global_step=12936, episodic_return=[106.28612]
# global_step=12966, episodic_return=[24.116453]
# global_step=13010, episodic_return=[79.09544]
# global_step=13032, episodic_return=[30.062063]
# global_step=13051, episodic_return=[19.908272]
# global_step=13063, episodic_return=[9.501684]
# global_step=13097, episodic_return=[56.426365]
# global_step=13138, episodic_return=[44.380013]
# global_step=13166, episodic_return=[47.215622]
# global_step=13185, episodic_return=[18.153177]
# global_step=13220, episodic_return=[59.27007]
# global_step=13240, episodic_return=[18.325651]
# global_step=13328, episodic_return=[157.66917]
# global_step=13355, episodic_return=[45.428913]
# global_step=13383, episodic_return=[45.988033]
# global_step=13403, episodic_return=[23.01185]
# global_step=13448, episodic_return=[76.177795]
# global_step=13481, episodic_return=[52.23939]
# global_step=13529, episodic_return=[87.82486]
# global_step=13573, episodic_return=[75.54392]
# global_step=13604, episodic_return=[50.77603]
# global_step=13616, episodic_return=[10.24606]
# global_step=13631, episodic_return=[10.996973]
# global_step=13661, episodic_return=[49.698833]
# global_step=13696, episodic_return=[58.127567]
# global_step=13734, episodic_return=[64.20887]
# global_step=13763, episodic_return=[48.68246]
# global_step=13803, episodic_return=[66.76548]
# global_step=13813, episodic_return=[7.8030066]
# global_step=13854, episodic_return=[68.45218]
# global_step=13874, episodic_return=[14.775288]
# global_step=13913, episodic_return=[66.23102]
# global_step=13945, episodic_return=[54.878876]
# global_step=13983, episodic_return=[65.44416]
# global_step=14010, episodic_return=[45.178112]
# global_step=14042, episodic_return=[55.760044]
# global_step=14106, episodic_return=[108.18503]
# global_step=14116, episodic_return=[7.7861204]
# global_step=14136, episodic_return=[23.488796]
# global_step=14145, episodic_return=[6.389368]
# global_step=14179, episodic_return=[56.281372]
# global_step=14214, episodic_return=[60.405926]
# global_step=14228, episodic_return=[12.864382]
# global_step=14262, episodic_return=[58.622665]
# global_step=14278, episodic_return=[12.19385]
# global_step=14310, episodic_return=[54.556194]
# global_step=14336, episodic_return=[22.596123]
# global_step=14369, episodic_return=[54.252346]
# global_step=14383, episodic_return=[7.7926035]
# global_step=14427, episodic_return=[76.52545]
# global_step=14441, episodic_return=[11.452098]
# global_step=14455, episodic_return=[14.195672]
# global_step=14484, episodic_return=[48.297398]
# global_step=14514, episodic_return=[49.815117]
# global_step=14545, episodic_return=[51.436337]
# global_step=14578, episodic_return=[56.26451]
# global_step=14609, episodic_return=[52.898026]
# global_step=14642, episodic_return=[55.50713]
# global_step=14666, episodic_return=[29.09781]
# global_step=14677, episodic_return=[7.191748]
# global_step=14708, episodic_return=[51.04277]
# global_step=14740, episodic_return=[54.04034]
# global_step=14768, episodic_return=[45.661747]
# global_step=14802, episodic_return=[59.021534]
# global_step=14834, episodic_return=[53.125088]
# global_step=14867, episodic_return=[57.284657]
# global_step=14895, episodic_return=[48.044342]
# global_step=14932, episodic_return=[59.896786]
# global_step=14946, episodic_return=[12.449198]
# global_step=14978, episodic_return=[53.16938]
# global_step=15011, episodic_return=[55.36523]
# global_step=15044, episodic_return=[50.991776]
# global_step=15059, episodic_return=[16.707708]
# global_step=15069, episodic_return=[8.030386]
# global_step=15099, episodic_return=[49.323936]
# global_step=15134, episodic_return=[60.231205]
# global_step=15172, episodic_return=[64.73093]
# global_step=15190, episodic_return=[17.030584]
# global_step=15215, episodic_return=[41.504402]
# global_step=15252, episodic_return=[62.738297]
# global_step=15260, episodic_return=[6.4017344]
# global_step=15298, episodic_return=[66.83923]
# global_step=15327, episodic_return=[48.61334]
# global_step=15355, episodic_return=[45.982952]
# global_step=15389, episodic_return=[55.31757]
# global_step=15423, episodic_return=[59.023197]
# global_step=15467, episodic_return=[76.19877]
# global_step=15499, episodic_return=[55.541725]
# global_step=15527, episodic_return=[47.969776]
# global_step=15554, episodic_return=[44.909245]
# global_step=15583, episodic_return=[47.96586]
# global_step=15609, episodic_return=[42.9541]
# global_step=15624, episodic_return=[17.870335]
# global_step=15638, episodic_return=[12.5720215]
# global_step=15670, episodic_return=[52.284687]
# global_step=15682, episodic_return=[9.273989]
# global_step=15708, episodic_return=[42.979088]
# global_step=15721, episodic_return=[12.990164]
# global_step=15760, episodic_return=[64.02276]
# global_step=15784, episodic_return=[25.583078]
# global_step=15814, episodic_return=[28.16947]
# global_step=15851, episodic_return=[64.417885]
# global_step=15860, episodic_return=[6.728979]
# global_step=15875, episodic_return=[14.144312]
# global_step=15904, episodic_return=[50.85005]
# global_step=15930, episodic_return=[28.171165]
# global_step=15960, episodic_return=[49.736973]
# global_step=15988, episodic_return=[46.66453]
# global_step=15995, episodic_return=[5.003826]
# global_step=16023, episodic_return=[47.870598]
# global_step=16038, episodic_return=[15.729078]
# global_step=16075, episodic_return=[63.275528]
# global_step=16086, episodic_return=[7.150067]
# global_step=16123, episodic_return=[64.31561]
# global_step=16149, episodic_return=[43.609394]
# global_step=16161, episodic_return=[10.315818]
# global_step=16188, episodic_return=[45.519176]
# global_step=16198, episodic_return=[8.420032]
# global_step=16211, episodic_return=[9.58044]
# global_step=16221, episodic_return=[8.576529]
# global_step=16232, episodic_return=[8.000138]
# global_step=16244, episodic_return=[7.036248]
# global_step=16271, episodic_return=[45.873703]
# global_step=16280, episodic_return=[5.0262866]
# global_step=16317, episodic_return=[61.243263]
# global_step=16361, episodic_return=[78.85736]
# global_step=16376, episodic_return=[11.668414]
# global_step=16388, episodic_return=[12.10831]
# global_step=16413, episodic_return=[42.72594]
# global_step=16426, episodic_return=[12.358182]
# global_step=16451, episodic_return=[42.51406]
# global_step=16462, episodic_return=[9.7118]
# global_step=16498, episodic_return=[60.208294]
# global_step=16524, episodic_return=[43.99353]
# global_step=16550, episodic_return=[43.85236]
# global_step=16565, episodic_return=[11.377742]
# global_step=16592, episodic_return=[44.946083]
# global_step=16620, episodic_return=[46.7321]
# global_step=16644, episodic_return=[40.547924]
# global_step=16672, episodic_return=[47.750877]
# global_step=16707, episodic_return=[58.63285]
# global_step=16763, episodic_return=[86.66132]
# global_step=16794, episodic_return=[51.06198]
# global_step=16811, episodic_return=[10.036116]
# global_step=16840, episodic_return=[49.08847]
# global_step=16851, episodic_return=[8.67472]
# global_step=16880, episodic_return=[48.331238]
# global_step=16903, episodic_return=[39.672684]
# global_step=16936, episodic_return=[54.89308]
# global_step=16967, episodic_return=[51.123592]
# global_step=16996, episodic_return=[48.58904]
# global_step=17005, episodic_return=[6.644565]
# global_step=17043, episodic_return=[63.235718]
# global_step=17071, episodic_return=[46.903934]
# global_step=17102, episodic_return=[53.833923]
# global_step=17133, episodic_return=[51.016903]
# global_step=17168, episodic_return=[57.596634]
# global_step=17182, episodic_return=[9.961488]
# global_step=17193, episodic_return=[7.963187]
# global_step=17219, episodic_return=[43.427937]
# global_step=17248, episodic_return=[48.0415]
# global_step=17268, episodic_return=[19.871088]
# global_step=17295, episodic_return=[44.890316]
# global_step=17322, episodic_return=[45.696983]
# Moviepy - Building video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-729.mp4.
# Moviepy - Writing video /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-729.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/videos/Hopper-v2__2__1700150624/rl-video-episode-729.mp4
# global_step=17353, episodic_return=[51.027447]
# global_step=17373, episodic_return=[21.743185]
# global_step=17407, episodic_return=[55.735935]
# global_step=17419, episodic_return=[9.244238]
# global_step=17451, episodic_return=[54.1162]
# global_step=17481, episodic_return=[49.77081]
# global_step=17493, episodic_return=[10.490501]
# global_step=17501, episodic_return=[4.3196564]
# global_step=17532, episodic_return=[53.146824]
# global_step=17562, episodic_return=[49.88034]
# global_step=17589, episodic_return=[45.72382]
# global_step=17607, episodic_return=[9.702725]
# global_step=17637, episodic_return=[45.15964]
# global_step=17668, episodic_return=[51.532253]
# global_step=17697, episodic_return=[26.877377]
# global_step=17722, episodic_return=[41.433887]
# global_step=17750, episodic_return=[46.89461]
# global_step=17761, episodic_return=[8.979247]
# global_step=17774, episodic_return=[10.650771]
# global_step=17810, episodic_return=[59.659515]
# global_step=17856, episodic_return=[81.63147]
# global_step=17885, episodic_return=[34.7497]
# global_step=17895, episodic_return=[7.3082986]
# global_step=17913, episodic_return=[16.310085]
# global_step=17939, episodic_return=[44.438854]
# global_step=17954, episodic_return=[14.456591]
# global_step=17992, episodic_return=[54.127228]
# global_step=18021, episodic_return=[49.34397]
# global_step=18058, episodic_return=[59.778614]
# global_step=18085, episodic_return=[44.418503]
# global_step=18095, episodic_return=[7.450039]
# global_step=18130, episodic_return=[59.315334]
# global_step=18156, episodic_return=[43.459038]
# global_step=18188, episodic_return=[52.76161]
# global_step=18215, episodic_return=[45.19748]
# global_step=18228, episodic_return=[9.630605]
# global_step=18292, episodic_return=[117.60263]
# global_step=18317, episodic_return=[42.1115]
# global_step=18329, episodic_return=[10.805771]
# global_step=18341, episodic_return=[4.745009]
# global_step=18369, episodic_return=[47.438133]
# global_step=20544, episodic_return=[78.2532]
# global_step=20569, episodic_return=[41.82241]
# global_step=20597, episodic_return=[48.910603]
# global_step=20624, episodic_return=[45.722366]
# global_step=20670, episodic_return=[73.93253]
# global_step=20701, episodic_return=[53.56277]
# global_step=20730, episodic_return=[48.286354]
# global_step=20744, episodic_return=[14.1838665]
# global_step=20760, episodic_return=[15.919301]
# global_step=20775, episodic_return=[12.899347]
# global_step=20799, episodic_return=[41.064285]
# global_step=20825, episodic_return=[44.08454]
# global_step=20851, episodic_return=[42.742]
# global_step=20878, episodic_return=[46.668785]
# global_step=20906, episodic_return=[45.79697]
# global_step=20931, episodic_return=[29.512306]
# global_step=20961, episodic_return=[52.22283]
# global_step=20989, episodic_return=[49.044193]
# global_step=21018, episodic_return=[49.137783]
# global_step=21033, episodic_return=[15.287115]
# global_step=21061, episodic_return=[47.03739]
# global_step=21094, episodic_return=[57.41065]
# global_step=21124, episodic_return=[52.332855]
# global_step=21155, episodic_return=[50.78102]
# global_step=21182, episodic_return=[46.225216]
# global_step=21195, episodic_return=[12.824983]
# global_step=21223, episodic_return=[48.21564]
# global_step=21251, episodic_return=[46.264458]
# global_step=21289, episodic_return=[65.82896]
# global_step=21319, episodic_return=[49.411522]
# global_step=21346, episodic_return=[46.407154]
# global_step=21372, episodic_return=[44.08083]
# global_step=21403, episodic_return=[52.18588]
# ...
# global_step=451150, episodic_return=[650.933]
# global_step=451285, episodic_return=[363.80063]
# global_step=451489, episodic_return=[631.2527]
# global_step=451654, episodic_return=[499.0063]
# global_step=451856, episodic_return=[650.1869]
# global_step=452056, episodic_return=[632.4252]
# global_step=452311, episodic_return=[826.45026]
# global_step=452512, episodic_return=[625.2366]
# global_step=452719, episodic_return=[678.8719]
# global_step=452933, episodic_return=[677.461]
# global_step=453128, episodic_return=[620.3613]
# global_step=453260, episodic_return=[356.28568]
# global_step=453400, episodic_return=[382.969]
# global_step=453602, episodic_return=[663.14087]
# global_step=453740, episodic_return=[371.35736]
# global_step=453973, episodic_return=[735.0371]
# global_step=454170, episodic_return=[620.7204]
# global_step=454382, episodic_return=[649.94495]
# global_step=454567, episodic_return=[573.50714]
# global_step=454725, episodic_return=[460.31735]
# global_step=454908, episodic_return=[583.3572]
# global_step=455117, episodic_return=[640.6891]
# global_step=455277, episodic_return=[462.37906]
# global_step=455490, episodic_return=[667.09644]
# global_step=455706, episodic_return=[675.5136]
# global_step=455908, episodic_return=[612.83777]
# global_step=456046, episodic_return=[368.9661]
# global_step=456181, episodic_return=[361.42938]
# global_step=456384, episodic_return=[647.7179]
# global_step=456577, episodic_return=[609.9924]
# global_step=456789, episodic_return=[656.1452]
# global_step=457002, episodic_return=[658.42377]
# global_step=457187, episodic_return=[587.539]
# global_step=457386, episodic_return=[662.0066]
# global_step=457592, episodic_return=[636.5586]
# global_step=457796, episodic_return=[659.74207]
# global_step=458006, episodic_return=[640.9115]
# global_step=458182, episodic_return=[551.2166]
# global_step=458380, episodic_return=[611.24335]
# global_step=458591, episodic_return=[694.3563]
# global_step=458793, episodic_return=[628.2224]
# global_step=459004, episodic_return=[657.8407]
# global_step=459201, episodic_return=[647.4824]
# global_step=459400, episodic_return=[613.41833]
# global_step=459605, episodic_return=[627.4465]
# global_step=459808, episodic_return=[629.783]
# global_step=460003, episodic_return=[630.631]
# global_step=460224, episodic_return=[691.6875]
# global_step=460421, episodic_return=[625.0478]
# global_step=460633, episodic_return=[662.2826]
# global_step=460839, episodic_return=[641.90216]
# global_step=461035, episodic_return=[621.03107]
# global_step=461237, episodic_return=[625.5072]
# global_step=461439, episodic_return=[626.0646]
# global_step=461657, episodic_return=[689.30194]
# global_step=461869, episodic_return=[656.2103]
# global_step=462072, episodic_return=[645.5098]
# global_step=462297, episodic_return=[689.0945]
# global_step=462506, episodic_return=[695.5088]
# global_step=462729, episodic_return=[737.04114]
# global_step=462910, episodic_return=[552.5891]
# global_step=463114, episodic_return=[649.7862]
# global_step=463328, episodic_return=[660.9716]
# global_step=463499, episodic_return=[544.2379]
# global_step=463709, episodic_return=[647.3136]
# global_step=463847, episodic_return=[374.38544]
# global_step=464051, episodic_return=[633.0082]
# global_step=464250, episodic_return=[629.1627]
# global_step=464482, episodic_return=[763.1396]
# global_step=464705, episodic_return=[701.5843]
# global_step=464901, episodic_return=[634.7401]
# global_step=465116, episodic_return=[658.4293]
# global_step=465319, episodic_return=[661.6204]
# global_step=465526, episodic_return=[658.8337]
# global_step=465703, episodic_return=[573.322]
# global_step=465904, episodic_return=[627.4884]
# global_step=466099, episodic_return=[605.2971]
# global_step=466287, episodic_return=[617.0181]
# global_step=466423, episodic_return=[375.3826]
# global_step=466585, episodic_return=[500.59003]
# global_step=466767, episodic_return=[590.56323]
# global_step=466961, episodic_return=[603.6033]
# global_step=467097, episodic_return=[366.8158]
# global_step=467270, episodic_return=[556.3985]
# global_step=467481, episodic_return=[654.57764]
# global_step=467652, episodic_return=[565.9042]
# global_step=467848, episodic_return=[640.00696]
# global_step=468038, episodic_return=[582.9415]
# global_step=468222, episodic_return=[608.45496]
# global_step=468425, episodic_return=[632.2273]
# global_step=468566, episodic_return=[393.4071]
# global_step=468771, episodic_return=[676.00287]
# global_step=468967, episodic_return=[598.0388]
# global_step=469184, episodic_return=[647.4969]
# global_step=469385, episodic_return=[649.3415]
# global_step=469589, episodic_return=[629.7221]
# global_step=469825, episodic_return=[767.0646]
# global_step=470027, episodic_return=[625.6204]
# global_step=470187, episodic_return=[480.26996]
# global_step=470398, episodic_return=[659.746]
# global_step=470585, episodic_return=[610.4172]
# global_step=470785, episodic_return=[617.08923]
# global_step=470984, episodic_return=[613.0462]
# global_step=471195, episodic_return=[652.9546]
# global_step=471390, episodic_return=[601.4217]
# global_step=471597, episodic_return=[649.46857]
# global_step=471814, episodic_return=[699.1333]
# global_step=472065, episodic_return=[813.59546]
# global_step=472268, episodic_return=[659.3379]
# global_step=472484, episodic_return=[694.0246]
# global_step=472691, episodic_return=[627.4035]
# global_step=472855, episodic_return=[503.24146]
# global_step=473043, episodic_return=[617.1885]
# global_step=473219, episodic_return=[575.01697]
# global_step=473404, episodic_return=[605.38196]
# global_step=473542, episodic_return=[381.01923]
# global_step=473736, episodic_return=[592.5936]
# global_step=473891, episodic_return=[453.99985]
# global_step=474074, episodic_return=[596.8047]
# global_step=474265, episodic_return=[614.85925]
# global_step=474461, episodic_return=[605.1924]
# global_step=474642, episodic_return=[586.1807]
# global_step=474833, episodic_return=[612.84406]
# global_step=475035, episodic_return=[646.66113]
# global_step=475212, episodic_return=[575.7838]
# global_step=475405, episodic_return=[636.20874]
# global_step=475610, episodic_return=[634.8002]
# global_step=475807, episodic_return=[611.60614]
# global_step=476010, episodic_return=[619.7794]
# global_step=476204, episodic_return=[648.3623]
# global_step=476421, episodic_return=[673.53534]
# global_step=476672, episodic_return=[838.6641]
# global_step=476866, episodic_return=[630.01465]
# global_step=477028, episodic_return=[490.25424]
# global_step=477248, episodic_return=[700.3377]
# global_step=477462, episodic_return=[662.4667]
# global_step=477668, episodic_return=[634.84735]
# global_step=477925, episodic_return=[820.68835]
# global_step=478135, episodic_return=[643.68616]
# global_step=478345, episodic_return=[651.7968]
# global_step=478550, episodic_return=[645.4837]
# global_step=478734, episodic_return=[601.6309]
# global_step=478936, episodic_return=[630.356]
# global_step=479132, episodic_return=[644.9887]
# global_step=479337, episodic_return=[636.77295]
# global_step=479518, episodic_return=[566.51025]
# global_step=479724, episodic_return=[643.982]
# global_step=479911, episodic_return=[554.81067]
# global_step=480113, episodic_return=[620.3584]
# global_step=480315, episodic_return=[622.57764]
# global_step=480499, episodic_return=[540.96436]
# global_step=480687, episodic_return=[616.852]
# global_step=480898, episodic_return=[639.3996]
# global_step=481116, episodic_return=[690.304]
# global_step=481329, episodic_return=[626.5447]
# global_step=481519, episodic_return=[603.15796]
# global_step=481715, episodic_return=[637.0529]
# global_step=481909, episodic_return=[610.3718]
# global_step=482113, episodic_return=[630.4882]
# global_step=482308, episodic_return=[618.2983]
# global_step=482506, episodic_return=[633.27356]
# global_step=482700, episodic_return=[594.9411]
# global_step=482893, episodic_return=[637.2539]
# global_step=483078, episodic_return=[577.21313]
# global_step=483287, episodic_return=[647.5815]
# global_step=483466, episodic_return=[570.91077]
# global_step=483667, episodic_return=[616.7887]
# global_step=483874, episodic_return=[641.26874]
# global_step=484036, episodic_return=[507.67126]
# global_step=484243, episodic_return=[639.05225]
# global_step=484444, episodic_return=[617.23785]
# global_step=484643, episodic_return=[606.34064]
# global_step=484846, episodic_return=[631.73694]
# global_step=485021, episodic_return=[564.4603]
# global_step=485229, episodic_return=[641.87366]
# global_step=485442, episodic_return=[659.4928]
# global_step=485639, episodic_return=[634.0617]
# global_step=485845, episodic_return=[640.6198]
# global_step=486048, episodic_return=[625.18726]
# global_step=486240, episodic_return=[621.47864]
# global_step=486433, episodic_return=[613.8414]
# global_step=486621, episodic_return=[576.56976]
# global_step=486822, episodic_return=[622.7268]
# global_step=487026, episodic_return=[626.0787]
# global_step=487182, episodic_return=[464.20483]
# global_step=487379, episodic_return=[619.6745]
# global_step=487561, episodic_return=[571.21545]
# global_step=487756, episodic_return=[613.95874]
# global_step=487966, episodic_return=[644.7096]
# global_step=488166, episodic_return=[615.4041]
# global_step=488351, episodic_return=[544.3244]
# global_step=488550, episodic_return=[633.8987]
# global_step=488750, episodic_return=[618.7453]
# global_step=488915, episodic_return=[524.7288]
# global_step=489126, episodic_return=[649.7487]
# global_step=489331, episodic_return=[646.2037]
# global_step=489506, episodic_return=[574.84503]
# global_step=489731, episodic_return=[730.3415]
# global_step=489937, episodic_return=[639.76636]
# global_step=490153, episodic_return=[701.5022]
# global_step=490367, episodic_return=[673.0886]
# global_step=490580, episodic_return=[663.60876]
# global_step=490795, episodic_return=[663.1134]
# global_step=490995, episodic_return=[620.59045]
# global_step=491206, episodic_return=[654.5248]
# global_step=491416, episodic_return=[648.0545]
# global_step=491613, episodic_return=[653.0302]
# global_step=491825, episodic_return=[654.20044]
# global_step=492006, episodic_return=[584.9934]
# global_step=492138, episodic_return=[348.35654]
# global_step=492337, episodic_return=[613.79486]
# global_step=492510, episodic_return=[570.5958]
# global_step=492718, episodic_return=[627.73413]
# global_step=492936, episodic_return=[669.8485]
# global_step=493074, episodic_return=[383.5818]
# global_step=493286, episodic_return=[652.20776]
# global_step=493482, episodic_return=[611.0778]
# global_step=493683, episodic_return=[649.025]
# global_step=493862, episodic_return=[586.5538]
# global_step=494061, episodic_return=[611.2959]
# global_step=494259, episodic_return=[609.7835]
# global_step=494457, episodic_return=[611.3276]
# global_step=494653, episodic_return=[643.30707]
# global_step=494851, episodic_return=[608.236]
# global_step=495057, episodic_return=[641.3511]
# global_step=495255, episodic_return=[607.60565]
# global_step=495459, episodic_return=[628.4421]
# global_step=495667, episodic_return=[639.21484]
# global_step=495866, episodic_return=[630.74286]
# global_step=496072, episodic_return=[636.7504]
# global_step=496270, episodic_return=[608.71216]
# global_step=496452, episodic_return=[597.3848]
# global_step=496673, episodic_return=[687.5773]
# global_step=496878, episodic_return=[641.957]
# global_step=497084, episodic_return=[644.56683]
# global_step=497297, episodic_return=[660.6096]
# global_step=497516, episodic_return=[684.12006]
# global_step=497729, episodic_return=[650.97614]
# global_step=497928, episodic_return=[622.743]
# global_step=498140, episodic_return=[654.5071]
# global_step=498341, episodic_return=[627.64716]
# global_step=498544, episodic_return=[622.19934]
# global_step=498743, episodic_return=[578.2452]
# global_step=498946, episodic_return=[626.6615]
# global_step=499138, episodic_return=[586.7223]
# global_step=499344, episodic_return=[642.5974]
# global_step=499561, episodic_return=[650.7595]
# global_step=499761, episodic_return=[616.2967]
# global_step=499978, episodic_return=[674.36536]
# global_step=500170, episodic_return=[638.00397]
# global_step=500395, episodic_return=[714.1587]
# global_step=500612, episodic_return=[684.064]
# global_step=500826, episodic_return=[655.48236]
# global_step=501022, episodic_return=[628.8645]
# global_step=501235, episodic_return=[656.92664]
# global_step=501465, episodic_return=[742.00366]
# global_step=501684, episodic_return=[687.00525]
# global_step=501879, episodic_return=[628.7845]
# global_step=502156, episodic_return=[905.1966]
# global_step=502369, episodic_return=[642.7871]
# global_step=502588, episodic_return=[674.22644]
# global_step=502800, episodic_return=[652.1535]
# global_step=503040, episodic_return=[787.5292]
# global_step=503264, episodic_return=[719.5224]
# global_step=503524, episodic_return=[858.9563]
# global_step=503723, episodic_return=[633.7534]
# global_step=503932, episodic_return=[642.6873]
# global_step=504154, episodic_return=[713.3258]
# global_step=504405, episodic_return=[835.6535]
# global_step=504618, episodic_return=[647.1892]
# global_step=504830, episodic_return=[638.3889]
# global_step=505046, episodic_return=[667.7962]
# global_step=505248, episodic_return=[618.3121]
# global_step=505479, episodic_return=[743.6652]
# global_step=505736, episodic_return=[857.2238]
# global_step=505986, episodic_return=[829.9946]
# global_step=506254, episodic_return=[878.4407]
# global_step=506470, episodic_return=[731.7292]
# global_step=506702, episodic_return=[755.0307]
# global_step=506913, episodic_return=[664.8958]
# global_step=507178, episodic_return=[878.21405]
# global_step=507426, episodic_return=[834.6183]
# global_step=507642, episodic_return=[666.7219]
# global_step=507914, episodic_return=[834.37103]
# global_step=508133, episodic_return=[692.751]
# global_step=508330, episodic_return=[611.5745]
# global_step=508539, episodic_return=[645.0768]
# global_step=508751, episodic_return=[652.54395]
# global_step=508958, episodic_return=[640.48267]
# global_step=509162, episodic_return=[625.84485]
# global_step=509365, episodic_return=[621.25354]
# global_step=509576, episodic_return=[627.6034]
# global_step=509808, episodic_return=[723.6577]
# global_step=510008, episodic_return=[621.5459]
# global_step=510215, episodic_return=[638.1667]
# global_step=510438, episodic_return=[705.5653]
# global_step=510673, episodic_return=[769.5176]
# global_step=510833, episodic_return=[487.4597]
# global_step=511028, episodic_return=[600.74286]
# global_step=511242, episodic_return=[665.0518]
# global_step=511453, episodic_return=[655.3192]
# global_step=511650, episodic_return=[628.444]
# global_step=511858, episodic_return=[641.5915]
# global_step=512064, episodic_return=[642.0866]
# global_step=512272, episodic_return=[638.5917]
# global_step=512484, episodic_return=[659.60876]
# global_step=512695, episodic_return=[648.1365]
# global_step=512946, episodic_return=[840.121]
# global_step=513161, episodic_return=[658.75085]
# global_step=513368, episodic_return=[634.8848]
# global_step=513635, episodic_return=[858.8744]
# global_step=513851, episodic_return=[666.1832]
# global_step=514107, episodic_return=[851.63257]
# global_step=514314, episodic_return=[634.0441]
# global_step=514563, episodic_return=[834.1087]
# global_step=514797, episodic_return=[749.8421]
# global_step=515062, episodic_return=[872.39166]
# global_step=515265, episodic_return=[622.40796]
# global_step=515466, episodic_return=[620.1672]
# global_step=515682, episodic_return=[635.0829]
# global_step=515891, episodic_return=[631.7921]
# global_step=516107, episodic_return=[662.3331]
# global_step=516421, episodic_return=[1059.9875]
# global_step=516666, episodic_return=[811.87787]
# global_step=516878, episodic_return=[654.1652]
# global_step=517133, episodic_return=[802.3103]
# global_step=517404, episodic_return=[849.42175]
# global_step=517666, episodic_return=[836.55835]
# global_step=517882, episodic_return=[666.8327]
# global_step=518152, episodic_return=[838.5197]
# global_step=518370, episodic_return=[683.95294]
# global_step=518584, episodic_return=[639.4152]
# global_step=518823, episodic_return=[783.3956]
# global_step=519077, episodic_return=[838.1647]
# global_step=519304, episodic_return=[678.8348]
# global_step=519565, episodic_return=[860.73364]
# global_step=519796, episodic_return=[732.97217]
# global_step=519990, episodic_return=[566.7486]
