# %%
import os
import random
import time
import wandb
from distutils.util import strtobool
from typing import Callable
import flax
import flax.linen as nn
import gymnasium as gym
import jax
import jax.numpy as jnp
import numpy as np
import optax

from flax.training.train_state import TrainState
from stable_baselines3.common.buffers import ReplayBuffer
from torch.utils.tensorboard import SummaryWriter

# %%
def make_env(env_id, seed, idx, capture_video, run_name):
    def thunk():
        if capture_video and idx == 0:
            env = gym.make(env_id, render_mode="rgb_array")
            env = gym.wrappers.RecordVideo(env, f"video/{run_name}")
        else:
            env = gym.make(env_id)
        env = gym.wrappers.RecordEpisodeStatistics(env)
        env.action_space.seed(seed)

        return env

    return thunk

# %%
class QNetwork(nn.Module):
    action_dim: int

    @nn.compact
    def __call__(self, x: jnp.ndarray):
        x = nn.Dense(120)(x)
        x = nn.relu(x)
        x = nn.Dense(84)(x)
        x = nn.relu(x)
        x = nn.Dense(self.action_dim)(x)
        # x = nn.relu(x)

        return x

# %%
class TrainState(TrainState):
    target_params: flax.core.FrozenDict

# %%
def linear_schedule(start_e: float, end_e: float, duration: int, t: int):
    slope = (end_e - start_e)/ duration
    return max(slope * t + start_e, end_e)

# %%
def evaluate(model_path: str,
             make_env: Callable,
             env_id: str,
             eval_episodes: int,
             run_name: str,
             Model: nn.Module,
             epsilon: float = 0.05,
             capture_video: bool = True,
             seed=1):
    envs = gym.vector.SyncVectorEnv([make_env(env_id, 0, 0, capture_video, run_name)])
    obs, _ = envs.reset()
    model = Model(action_dim=envs.single_action_space.n)
    q_key = jax.random.PRNGKey(seed)
    params = model.init(q_key, obs)
    with open(model_path, "rb") as f:
        params = flax.serialization.from_bytes(params, f.read())
    model.apply = jax.jit(model.apply)

    episodic_returns = []

    while len(episodic_returns) < eval_episodes:
        if random.random() < epsilon:
            actions = np.array([envs.single_action_space.sample() for _ in range(envs.num_envs)])
        else:
            q_values = model.apply(params,obs)
            actions = q_values.argmax(axis=-1)
            actions = jax.device_get(actions)
        next_obs, _, _, _, infos = envs.step(actions)
        if "final_info" in infos:
            for info in infos["final_info"]:
                if "episode" not in info:
                    continue
                print(f"eval_episode={len(episodic_returns)}, episodic_return={info['episode']['r']}")
                episodic_returns += [info["episode"]["r"]]

        obs = next_obs

    return episodic_returns

# %%
envs = {"cartPole":"CartPole-v1","acrobot":"Acrobot-v1","mountainCar":"MountainCar-v0"}
n_timesteps = 500000
learning_rate = 0.00025
buffer_size = 10000
gamma = 0.99
target_network_frequency = 500
max_grad_norm = 0.5
batch_size = 128
start_e = 1
end_e = 0.05
exploration_fraction = 0.5
learning_starts = 10000
train_frequency = 10
seed = 1
capture_video = True
tau = 1
num_envs = 1

# %%
def train(env_id,timesteps,learning_rate,buffer_size,gamma,
          target_network_frequency,max_grad_norm,batch_size,
          start_e,end_e,exploration_fraction,learning_starts,
          train_frequency,seed,tau,num_envs):

    run_name = f"{env_id}__{seed}__{int(time.time())}"
    wandb.init(
        project="dqn-classic-control-benchmark",
        config={
            "env":env_id,
            "timesteps":timesteps,
            "lr":learning_rate,
            "buffer_size":buffer_size,
            "gamma":gamma,
            "target_network_frequency":target_network_frequency,
            "batch_size":batch_size,
            "start_e":start_e,
            "end_e":end_e,
            "exploration_fraction":exploration_fraction,
            "learning_starts":learning_starts,
            "train_frequency":train_frequency,
            "seed":seed,
            "tau":tau,
            "num_envs":num_envs,
        },
        sync_tensorboard=True,
        monitor_gym=True,
        name=run_name,
    )
    
    writer = SummaryWriter(f"runs/{run_name}")

    random.seed(seed)
    np.random.seed(seed)
    key = jax.random.PRNGKey(seed)
    key, q_key = jax.random.split(key, 2)

    envs = gym.vector.SyncVectorEnv(
        [make_env(env_id, seed + i, i, True, run_name) for i in range(num_envs)]
    )

    obs, _ = envs.reset(seed=seed)

    q_network = QNetwork(action_dim=envs.single_action_space.n)

    q_state = TrainState.create(
        apply_fn=q_network.apply,
        params=q_network.init(q_key, obs),
        target_params=q_network.init(q_key,obs),
        tx=optax.adam(learning_rate=learning_rate)
    )

    q_network.apply = jax.jit(q_network.apply)
    q_state = q_state.replace(target_params=optax.incremental_update(q_state.params, q_state.target_params, 1))

    rb = ReplayBuffer(
        buffer_size,
        envs.single_observation_space,
        envs.single_action_space,
        "cpu",
        n_envs=num_envs,
        handle_timeout_termination=False,
    )

    @jax.jit
    def update(q_state, observations, actions, next_observations, rewards, dones):
        q_next_target = q_network.apply(q_state.target_params, next_observations)
        q_next_target = jnp.max(q_next_target, axis=-1)
        next_q_value = rewards + (1 - dones) * gamma * q_next_target

        def mse_loss(params):
            q_pred = q_network.apply(params, observations)
            q_pred = q_pred[jnp.arange(q_pred.shape[0]), actions.squeeze()]
            return ((q_pred - next_q_value)**2).mean(), q_pred

        (loss_value,q_pred), grads = jax.value_and_grad(mse_loss,has_aux=True)(q_state.params)
        q_state = q_state.apply_gradients(grads=grads)
        return loss_value, q_pred, q_state

    start_time = time.time()

    obs, _ = envs.reset(seed=seed)
    for global_step in range(timesteps):
        epsilon = linear_schedule(start_e, end_e, exploration_fraction * timesteps, global_step)
        if random.random() < epsilon:
            actions = np.array([envs.single_action_space.sample() for _ in range(envs.num_envs)])
        else:
            q_values = q_network.apply(q_state.params, obs)
            actions = q_values.argmax(axis=-1)
            actions = jax.device_get(actions)

        next_obs, rewards, terminated, truncated, infos = envs.step(actions)

        if "final_info" in infos:
            for info in infos["final_info"]:
                if "episode" not in info:
                    continue

                print(f"global_step={global_step}, episodic_return={info['episode']['r']}")
                writer.add_scalar("charts/episodic_return",info["episode"]["r"], global_step)
                writer.add_scalar("charts/episodic_length",info["episode"]["l"], global_step)
                writer.add_scalar("charts/epsilon",epsilon,global_step)


        real_next_obs = next_obs.copy()
        for idx,d in enumerate(truncated):
            if d and "final_observations" in infos:
                real_next_obs[idx] = infos["final_observations"][idx]
        rb.add(obs, real_next_obs, actions, rewards, terminated, infos)

        obs = next_obs

        if global_step > learning_starts:
            if global_step % train_frequency == 0:
                data = rb.sample(batch_size)

                loss, old_val, q_state = update(
                    q_state,
                    data.observations.numpy(),
                    data.actions.numpy(),
                    data.next_observations.numpy(),
                    data.rewards.flatten().numpy(),
                    data.dones.flatten().numpy(),
                )

                if global_step % 100 == 0:
                    writer.add_scalar("losses/td_loss",jax.device_get(loss),global_step)
                    writer.add_scalar("losses/q_values",jax.device_get(old_val).mean(), global_step)
                    writer.add_scalar("charts/SPS",int(global_step / (time.time() - start_time)),global_step)

            if global_step % target_network_frequency == 0:
                q_state = q_state.replace(
                    target_params=optax.incremental_update(q_state.params, q_state.target_params, tau)
                )

    model_path = f"runs/{run_name}.cleanrl_model"
    with open(model_path,"wb") as f:
        f.write(flax.serialization.to_bytes(q_state.params))

    print("Model Saved")

    episodic_returns = evaluate(
        model_path,
        make_env,
        env_id,
        run_name=f"{run_name}-eval",
        Model=QNetwork,
        epsilon=0.05,
        eval_episodes=100
    )

    for idx, episodic_return in enumerate(episodic_returns):
        writer.add_scalar("eval/episodic_return", episodic_return,idx)

    envs.close()
    writer.close()
    wandb.finish()

# %%
train(envs["mountainCar"],n_timesteps,learning_rate,buffer_size,gamma,target_network_frequency,max_grad_norm,batch_size,start_e,end_e,exploration_fraction,learning_starts,train_frequency,seed,tau,num_envs)
# Out:
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/notebooks/rl-algos/wandb/run-20231113_143957-n4zhtrln</code>
# Syncing run <strong><a href='https://wandb.ai/chkda/dqn-classic-control-benchmark/runs/n4zhtrln' target="_blank">MountainCar-v0__1__1699886397</a></strong> to <a href='https://wandb.ai/chkda/dqn-classic-control-benchmark' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/chkda/dqn-classic-control-benchmark' target="_blank">https://wandb.ai/chkda/dqn-classic-control-benchmark</a>
#  View run at <a href='https://wandb.ai/chkda/dqn-classic-control-benchmark/runs/n4zhtrln' target="_blank">https://wandb.ai/chkda/dqn-classic-control-benchmark/runs/n4zhtrln</a>
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-0.mp4
# global_step=199, episodic_return=[-200.]
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-1.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-1.mp4
# global_step=399, episodic_return=[-200.]
# global_step=599, episodic_return=[-200.]
# global_step=799, episodic_return=[-200.]
# global_step=999, episodic_return=[-200.]
# global_step=1199, episodic_return=[-200.]
# global_step=1399, episodic_return=[-200.]
# global_step=1599, episodic_return=[-200.]
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-8.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-8.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-8.mp4
# global_step=1799, episodic_return=[-200.]
# global_step=1999, episodic_return=[-200.]
# global_step=2199, episodic_return=[-200.]
# global_step=2399, episodic_return=[-200.]
# global_step=2599, episodic_return=[-200.]
# global_step=2799, episodic_return=[-200.]
# global_step=2999, episodic_return=[-200.]
# global_step=3199, episodic_return=[-200.]
# global_step=3399, episodic_return=[-200.]
# global_step=3599, episodic_return=[-200.]
# global_step=3799, episodic_return=[-200.]
# global_step=3999, episodic_return=[-200.]
# global_step=4199, episodic_return=[-200.]
# global_step=4399, episodic_return=[-200.]
# global_step=4599, episodic_return=[-200.]
# global_step=4799, episodic_return=[-200.]
# global_step=4999, episodic_return=[-200.]
# global_step=5199, episodic_return=[-200.]
# global_step=5399, episodic_return=[-200.]
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-27.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-27.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-27.mp4
# global_step=5599, episodic_return=[-200.]
# global_step=5799, episodic_return=[-200.]
# global_step=5999, episodic_return=[-200.]
# global_step=6199, episodic_return=[-200.]
# global_step=6399, episodic_return=[-200.]
# global_step=6599, episodic_return=[-200.]
# global_step=6799, episodic_return=[-200.]
# global_step=6999, episodic_return=[-200.]
# global_step=7199, episodic_return=[-200.]
# global_step=7399, episodic_return=[-200.]
# global_step=7599, episodic_return=[-200.]
# global_step=7799, episodic_return=[-200.]
# global_step=7999, episodic_return=[-200.]
# global_step=8199, episodic_return=[-200.]
# global_step=8399, episodic_return=[-200.]
# global_step=8599, episodic_return=[-200.]
# global_step=8799, episodic_return=[-200.]
# global_step=8999, episodic_return=[-200.]
# global_step=9199, episodic_return=[-200.]
# global_step=9399, episodic_return=[-200.]
# global_step=9599, episodic_return=[-200.]
# global_step=9799, episodic_return=[-200.]
# global_step=9999, episodic_return=[-200.]
# global_step=10199, episodic_return=[-200.]
# global_step=10399, episodic_return=[-200.]
# global_step=10599, episodic_return=[-200.]
# global_step=10799, episodic_return=[-200.]
# global_step=10999, episodic_return=[-200.]
# global_step=11199, episodic_return=[-200.]
# global_step=11399, episodic_return=[-200.]
# global_step=11599, episodic_return=[-200.]
# global_step=11799, episodic_return=[-200.]
# global_step=11999, episodic_return=[-200.]
# global_step=12199, episodic_return=[-200.]
# global_step=12399, episodic_return=[-200.]
# global_step=12599, episodic_return=[-200.]
# global_step=12799, episodic_return=[-200.]
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-64.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-64.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-64.mp4
# global_step=12999, episodic_return=[-200.]
# global_step=13199, episodic_return=[-200.]
# global_step=13399, episodic_return=[-200.]
# global_step=13599, episodic_return=[-200.]
# global_step=13799, episodic_return=[-200.]
# global_step=13999, episodic_return=[-200.]
# global_step=14199, episodic_return=[-200.]
# global_step=14399, episodic_return=[-200.]
# global_step=14599, episodic_return=[-200.]
# global_step=14799, episodic_return=[-200.]
# global_step=14999, episodic_return=[-200.]
# global_step=15199, episodic_return=[-200.]
# global_step=15399, episodic_return=[-200.]
# global_step=15599, episodic_return=[-200.]
# global_step=15799, episodic_return=[-200.]
# global_step=15999, episodic_return=[-200.]
# global_step=16199, episodic_return=[-200.]
# global_step=16399, episodic_return=[-200.]
# global_step=16599, episodic_return=[-200.]
# global_step=16799, episodic_return=[-200.]
# global_step=16999, episodic_return=[-200.]
# global_step=17199, episodic_return=[-200.]
# global_step=17399, episodic_return=[-200.]
# global_step=17599, episodic_return=[-200.]
# global_step=17799, episodic_return=[-200.]
# global_step=17999, episodic_return=[-200.]
# global_step=18199, episodic_return=[-200.]
# global_step=18399, episodic_return=[-200.]
# global_step=18599, episodic_return=[-200.]
# global_step=18799, episodic_return=[-200.]
# global_step=18999, episodic_return=[-200.]
# global_step=19199, episodic_return=[-200.]
# global_step=19399, episodic_return=[-200.]
# global_step=19599, episodic_return=[-200.]
# global_step=19799, episodic_return=[-200.]
# global_step=19999, episodic_return=[-200.]
# global_step=20199, episodic_return=[-200.]
# global_step=20399, episodic_return=[-200.]
# global_step=20599, episodic_return=[-200.]
# global_step=20799, episodic_return=[-200.]
# global_step=20999, episodic_return=[-200.]
# global_step=21199, episodic_return=[-200.]
# global_step=21399, episodic_return=[-200.]
# global_step=21599, episodic_return=[-200.]
# global_step=21799, episodic_return=[-200.]
# global_step=21999, episodic_return=[-200.]
# global_step=22199, episodic_return=[-200.]
# global_step=22399, episodic_return=[-200.]
# global_step=22599, episodic_return=[-200.]
# global_step=22799, episodic_return=[-200.]
# global_step=22999, episodic_return=[-200.]
# global_step=23199, episodic_return=[-200.]
# global_step=23399, episodic_return=[-200.]
# global_step=23599, episodic_return=[-200.]
# global_step=23799, episodic_return=[-200.]
# global_step=23999, episodic_return=[-200.]
# global_step=24199, episodic_return=[-200.]
# global_step=24399, episodic_return=[-200.]
# global_step=24599, episodic_return=[-200.]
# global_step=24799, episodic_return=[-200.]
# global_step=24999, episodic_return=[-200.]
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-125.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-125.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-125.mp4
# global_step=25199, episodic_return=[-200.]
# global_step=25399, episodic_return=[-200.]
# global_step=25599, episodic_return=[-200.]
# global_step=25799, episodic_return=[-200.]
# global_step=25999, episodic_return=[-200.]
# global_step=26199, episodic_return=[-200.]
# global_step=26399, episodic_return=[-200.]
# global_step=26599, episodic_return=[-200.]
# global_step=26799, episodic_return=[-200.]
# global_step=26999, episodic_return=[-200.]
# global_step=27199, episodic_return=[-200.]
# global_step=27399, episodic_return=[-200.]
# global_step=27599, episodic_return=[-200.]
# global_step=27799, episodic_return=[-200.]
# global_step=27999, episodic_return=[-200.]
# global_step=28199, episodic_return=[-200.]
# global_step=28399, episodic_return=[-200.]
# global_step=28599, episodic_return=[-200.]
# global_step=28799, episodic_return=[-200.]
# global_step=28999, episodic_return=[-200.]
# global_step=29199, episodic_return=[-200.]
# global_step=29399, episodic_return=[-200.]
# global_step=29599, episodic_return=[-200.]
# global_step=29799, episodic_return=[-200.]
# global_step=29999, episodic_return=[-200.]
# global_step=30199, episodic_return=[-200.]
# global_step=30399, episodic_return=[-200.]
# global_step=30599, episodic_return=[-200.]
# global_step=30799, episodic_return=[-200.]
# global_step=30999, episodic_return=[-200.]
# global_step=31199, episodic_return=[-200.]
# global_step=31399, episodic_return=[-200.]
# global_step=31599, episodic_return=[-200.]
# global_step=31799, episodic_return=[-200.]
# global_step=31999, episodic_return=[-200.]
# global_step=32199, episodic_return=[-200.]
# global_step=32399, episodic_return=[-200.]
# global_step=32599, episodic_return=[-200.]
# global_step=32799, episodic_return=[-200.]
# global_step=32999, episodic_return=[-200.]
# global_step=33199, episodic_return=[-200.]
# global_step=33399, episodic_return=[-200.]
# global_step=33599, episodic_return=[-200.]
# global_step=33799, episodic_return=[-200.]
# global_step=33999, episodic_return=[-200.]
# global_step=34199, episodic_return=[-200.]
# global_step=34399, episodic_return=[-200.]
# global_step=34599, episodic_return=[-200.]
# global_step=34799, episodic_return=[-200.]
# global_step=34999, episodic_return=[-200.]
# global_step=35199, episodic_return=[-200.]
# global_step=35399, episodic_return=[-200.]
# global_step=35599, episodic_return=[-200.]
# global_step=35799, episodic_return=[-200.]
# global_step=35999, episodic_return=[-200.]
# global_step=36199, episodic_return=[-200.]
# global_step=36399, episodic_return=[-200.]
# global_step=36599, episodic_return=[-200.]
# global_step=36799, episodic_return=[-200.]
# global_step=36999, episodic_return=[-200.]
# global_step=37199, episodic_return=[-200.]
# global_step=37399, episodic_return=[-200.]
# global_step=37599, episodic_return=[-200.]
# global_step=37799, episodic_return=[-200.]
# global_step=37999, episodic_return=[-200.]
# global_step=38199, episodic_return=[-200.]
# global_step=38399, episodic_return=[-200.]
# global_step=38599, episodic_return=[-200.]
# global_step=38799, episodic_return=[-200.]
# global_step=38999, episodic_return=[-200.]
# global_step=39199, episodic_return=[-200.]
# global_step=39399, episodic_return=[-200.]
# global_step=39599, episodic_return=[-200.]
# global_step=39799, episodic_return=[-200.]
# global_step=39999, episodic_return=[-200.]
# global_step=40199, episodic_return=[-200.]
# global_step=40399, episodic_return=[-200.]
# global_step=40599, episodic_return=[-200.]
# global_step=40799, episodic_return=[-200.]
# global_step=40999, episodic_return=[-200.]
# global_step=41199, episodic_return=[-200.]
# global_step=41399, episodic_return=[-200.]
# global_step=41599, episodic_return=[-200.]
# global_step=41799, episodic_return=[-200.]
# global_step=41999, episodic_return=[-200.]
# global_step=42199, episodic_return=[-200.]
# global_step=42399, episodic_return=[-200.]
# global_step=42599, episodic_return=[-200.]
# global_step=42799, episodic_return=[-200.]
# global_step=42999, episodic_return=[-200.]
# global_step=43199, episodic_return=[-200.]
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-216.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-216.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-216.mp4
# global_step=43399, episodic_return=[-200.]
# global_step=43599, episodic_return=[-200.]
# global_step=43799, episodic_return=[-200.]
# global_step=43999, episodic_return=[-200.]
# global_step=44199, episodic_return=[-200.]
# global_step=44399, episodic_return=[-200.]
# global_step=44599, episodic_return=[-200.]
# global_step=44799, episodic_return=[-200.]
# global_step=44999, episodic_return=[-200.]
# global_step=45199, episodic_return=[-200.]
# global_step=45399, episodic_return=[-200.]
# global_step=45599, episodic_return=[-200.]
# global_step=45799, episodic_return=[-200.]
# global_step=45999, episodic_return=[-200.]
# global_step=46199, episodic_return=[-200.]
# global_step=46399, episodic_return=[-200.]
# global_step=46599, episodic_return=[-200.]
# global_step=46799, episodic_return=[-200.]
# global_step=46999, episodic_return=[-200.]
# global_step=47199, episodic_return=[-200.]
# global_step=47399, episodic_return=[-200.]
# global_step=47599, episodic_return=[-200.]
# global_step=47799, episodic_return=[-200.]
# global_step=47999, episodic_return=[-200.]
# global_step=48199, episodic_return=[-200.]
# global_step=48399, episodic_return=[-200.]
# global_step=48599, episodic_return=[-200.]
# global_step=48799, episodic_return=[-200.]
# global_step=48999, episodic_return=[-200.]
# global_step=49199, episodic_return=[-200.]
# global_step=49399, episodic_return=[-200.]
# global_step=49599, episodic_return=[-200.]
# global_step=49799, episodic_return=[-200.]
# global_step=49999, episodic_return=[-200.]
# global_step=50199, episodic_return=[-200.]
# global_step=50399, episodic_return=[-200.]
# global_step=50599, episodic_return=[-200.]
# global_step=50799, episodic_return=[-200.]
# global_step=50999, episodic_return=[-200.]
# global_step=51199, episodic_return=[-200.]
# global_step=51399, episodic_return=[-200.]
# global_step=51599, episodic_return=[-200.]
# global_step=51799, episodic_return=[-200.]
# global_step=51999, episodic_return=[-200.]
# global_step=52199, episodic_return=[-200.]
# global_step=52399, episodic_return=[-200.]
# global_step=52599, episodic_return=[-200.]
# global_step=52799, episodic_return=[-200.]
# global_step=52999, episodic_return=[-200.]
# global_step=53199, episodic_return=[-200.]
# global_step=53399, episodic_return=[-200.]
# global_step=53599, episodic_return=[-200.]
# global_step=53799, episodic_return=[-200.]
# global_step=53999, episodic_return=[-200.]
# global_step=54199, episodic_return=[-200.]
# global_step=54399, episodic_return=[-200.]
# global_step=54599, episodic_return=[-200.]
# global_step=54799, episodic_return=[-200.]
# global_step=54999, episodic_return=[-200.]
# global_step=55199, episodic_return=[-200.]
# global_step=55399, episodic_return=[-200.]
# global_step=55599, episodic_return=[-200.]
# global_step=55799, episodic_return=[-200.]
# global_step=55999, episodic_return=[-200.]
# global_step=56199, episodic_return=[-200.]
# global_step=56399, episodic_return=[-200.]
# global_step=56599, episodic_return=[-200.]
# global_step=56799, episodic_return=[-200.]
# global_step=56999, episodic_return=[-200.]
# global_step=57199, episodic_return=[-200.]
# global_step=57399, episodic_return=[-200.]
# global_step=57599, episodic_return=[-200.]
# global_step=57799, episodic_return=[-200.]
# global_step=57999, episodic_return=[-200.]
# global_step=58199, episodic_return=[-200.]
# global_step=58399, episodic_return=[-200.]
# global_step=58599, episodic_return=[-200.]
# global_step=58799, episodic_return=[-200.]
# global_step=58999, episodic_return=[-200.]
# global_step=59199, episodic_return=[-200.]
# global_step=59399, episodic_return=[-200.]
# global_step=59599, episodic_return=[-200.]
# global_step=59799, episodic_return=[-200.]
# global_step=59999, episodic_return=[-200.]
# global_step=60199, episodic_return=[-200.]
# global_step=60399, episodic_return=[-200.]
# global_step=60599, episodic_return=[-200.]
# global_step=60799, episodic_return=[-200.]
# global_step=60999, episodic_return=[-200.]
# global_step=61199, episodic_return=[-200.]
# global_step=61399, episodic_return=[-200.]
# global_step=61599, episodic_return=[-200.]
# global_step=61799, episodic_return=[-200.]
# global_step=61999, episodic_return=[-200.]
# global_step=62199, episodic_return=[-200.]
# global_step=62399, episodic_return=[-200.]
# global_step=62599, episodic_return=[-200.]
# global_step=62799, episodic_return=[-200.]
# global_step=62999, episodic_return=[-200.]
# global_step=63199, episodic_return=[-200.]
# global_step=63399, episodic_return=[-200.]
# global_step=63599, episodic_return=[-200.]
# global_step=63799, episodic_return=[-200.]
# global_step=63999, episodic_return=[-200.]
# global_step=64199, episodic_return=[-200.]
# global_step=64399, episodic_return=[-200.]
# global_step=64599, episodic_return=[-200.]
# global_step=64799, episodic_return=[-200.]
# global_step=64999, episodic_return=[-200.]
# global_step=65199, episodic_return=[-200.]
# global_step=65399, episodic_return=[-200.]
# global_step=65599, episodic_return=[-200.]
# global_step=65799, episodic_return=[-200.]
# global_step=65999, episodic_return=[-200.]
# global_step=66199, episodic_return=[-200.]
# global_step=66399, episodic_return=[-200.]
# global_step=66599, episodic_return=[-200.]
# global_step=66799, episodic_return=[-200.]
# global_step=66999, episodic_return=[-200.]
# global_step=67199, episodic_return=[-200.]
# global_step=67399, episodic_return=[-200.]
# global_step=67599, episodic_return=[-200.]
# global_step=67799, episodic_return=[-200.]
# global_step=67999, episodic_return=[-200.]
# global_step=68199, episodic_return=[-200.]
# global_step=68399, episodic_return=[-200.]
# global_step=68599, episodic_return=[-200.]
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-343.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-343.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-343.mp4
# global_step=68799, episodic_return=[-200.]
# global_step=68999, episodic_return=[-200.]
# global_step=69199, episodic_return=[-200.]
# global_step=69399, episodic_return=[-200.]
# global_step=69599, episodic_return=[-200.]
# global_step=69799, episodic_return=[-200.]
# global_step=69999, episodic_return=[-200.]
# global_step=70199, episodic_return=[-200.]
# global_step=70399, episodic_return=[-200.]
# global_step=70599, episodic_return=[-200.]
# global_step=70799, episodic_return=[-200.]
# global_step=70999, episodic_return=[-200.]
# global_step=71199, episodic_return=[-200.]
# global_step=71399, episodic_return=[-200.]
# global_step=71599, episodic_return=[-200.]
# global_step=71799, episodic_return=[-200.]
# global_step=71999, episodic_return=[-200.]
# global_step=72199, episodic_return=[-200.]
# global_step=72399, episodic_return=[-200.]
# global_step=72599, episodic_return=[-200.]
# global_step=72799, episodic_return=[-200.]
# global_step=72999, episodic_return=[-200.]
# global_step=73199, episodic_return=[-200.]
# global_step=73399, episodic_return=[-200.]
# global_step=73599, episodic_return=[-200.]
# global_step=73799, episodic_return=[-200.]
# global_step=73999, episodic_return=[-200.]
# global_step=74199, episodic_return=[-200.]
# global_step=74399, episodic_return=[-200.]
# global_step=74599, episodic_return=[-200.]
# global_step=74799, episodic_return=[-200.]
# global_step=74999, episodic_return=[-200.]
# global_step=75199, episodic_return=[-200.]
# global_step=75399, episodic_return=[-200.]
# global_step=75599, episodic_return=[-200.]
# global_step=75799, episodic_return=[-200.]
# global_step=75999, episodic_return=[-200.]
# global_step=76199, episodic_return=[-200.]
# global_step=76399, episodic_return=[-200.]
# global_step=76599, episodic_return=[-200.]
# global_step=76799, episodic_return=[-200.]
# global_step=76999, episodic_return=[-200.]
# global_step=77199, episodic_return=[-200.]
# global_step=77399, episodic_return=[-200.]
# global_step=77599, episodic_return=[-200.]
# global_step=77799, episodic_return=[-200.]
# global_step=77999, episodic_return=[-200.]
# global_step=78199, episodic_return=[-200.]
# global_step=78399, episodic_return=[-200.]
# global_step=78599, episodic_return=[-200.]
# global_step=78799, episodic_return=[-200.]
# global_step=78999, episodic_return=[-200.]
# global_step=79199, episodic_return=[-200.]
# global_step=79399, episodic_return=[-200.]
# global_step=79599, episodic_return=[-200.]
# global_step=79799, episodic_return=[-200.]
# global_step=79999, episodic_return=[-200.]
# global_step=80199, episodic_return=[-200.]
# global_step=80399, episodic_return=[-200.]
# global_step=80599, episodic_return=[-200.]
# global_step=80799, episodic_return=[-200.]
# global_step=80999, episodic_return=[-200.]
# global_step=81199, episodic_return=[-200.]
# global_step=81399, episodic_return=[-200.]
# global_step=81599, episodic_return=[-200.]
# global_step=81799, episodic_return=[-200.]
# global_step=81999, episodic_return=[-200.]
# global_step=82199, episodic_return=[-200.]
# global_step=82399, episodic_return=[-200.]
# global_step=82599, episodic_return=[-200.]
# global_step=82799, episodic_return=[-200.]
# global_step=82999, episodic_return=[-200.]
# global_step=83199, episodic_return=[-200.]
# global_step=83399, episodic_return=[-200.]
# global_step=83599, episodic_return=[-200.]
# global_step=83799, episodic_return=[-200.]
# global_step=83999, episodic_return=[-200.]
# global_step=84199, episodic_return=[-200.]
# global_step=84399, episodic_return=[-200.]
# global_step=84599, episodic_return=[-200.]
# global_step=84799, episodic_return=[-200.]
# global_step=84999, episodic_return=[-200.]
# global_step=85199, episodic_return=[-200.]
# global_step=85399, episodic_return=[-200.]
# global_step=85599, episodic_return=[-200.]
# global_step=85799, episodic_return=[-200.]
# global_step=85999, episodic_return=[-200.]
# global_step=86199, episodic_return=[-200.]
# global_step=86399, episodic_return=[-200.]
# global_step=86599, episodic_return=[-200.]
# global_step=86799, episodic_return=[-200.]
# global_step=86999, episodic_return=[-200.]
# global_step=87199, episodic_return=[-200.]
# global_step=87399, episodic_return=[-200.]
# global_step=87599, episodic_return=[-200.]
# global_step=87799, episodic_return=[-200.]
# global_step=87999, episodic_return=[-200.]
# global_step=88199, episodic_return=[-200.]
# global_step=88399, episodic_return=[-200.]
# global_step=88599, episodic_return=[-200.]
# global_step=88799, episodic_return=[-200.]
# global_step=88999, episodic_return=[-200.]
# global_step=89199, episodic_return=[-200.]
# global_step=89399, episodic_return=[-200.]
# global_step=89599, episodic_return=[-200.]
# global_step=89799, episodic_return=[-200.]
# global_step=89999, episodic_return=[-200.]
# global_step=90199, episodic_return=[-200.]
# global_step=90399, episodic_return=[-200.]
# global_step=90599, episodic_return=[-200.]
# global_step=90799, episodic_return=[-200.]
# global_step=90999, episodic_return=[-200.]
# global_step=91199, episodic_return=[-200.]
# global_step=91399, episodic_return=[-200.]
# global_step=91599, episodic_return=[-200.]
# global_step=91799, episodic_return=[-200.]
# global_step=91999, episodic_return=[-200.]
# global_step=92199, episodic_return=[-200.]
# global_step=92399, episodic_return=[-200.]
# global_step=92599, episodic_return=[-200.]
# global_step=92799, episodic_return=[-200.]
# global_step=92999, episodic_return=[-200.]
# global_step=93199, episodic_return=[-200.]
# global_step=93399, episodic_return=[-200.]
# global_step=93599, episodic_return=[-200.]
# global_step=93799, episodic_return=[-200.]
# global_step=93999, episodic_return=[-200.]
# global_step=94199, episodic_return=[-200.]
# global_step=94399, episodic_return=[-200.]
# global_step=94599, episodic_return=[-200.]
# global_step=94799, episodic_return=[-200.]
# global_step=94999, episodic_return=[-200.]
# global_step=95199, episodic_return=[-200.]
# global_step=95399, episodic_return=[-200.]
# global_step=95599, episodic_return=[-200.]
# global_step=95799, episodic_return=[-200.]
# global_step=95999, episodic_return=[-200.]
# global_step=96199, episodic_return=[-200.]
# global_step=96399, episodic_return=[-200.]
# global_step=96599, episodic_return=[-200.]
# global_step=96799, episodic_return=[-200.]
# global_step=96999, episodic_return=[-200.]
# global_step=97199, episodic_return=[-200.]
# global_step=97399, episodic_return=[-200.]
# global_step=97599, episodic_return=[-200.]
# global_step=97799, episodic_return=[-200.]
# global_step=97999, episodic_return=[-200.]
# global_step=98199, episodic_return=[-200.]
# global_step=98399, episodic_return=[-200.]
# global_step=98599, episodic_return=[-200.]
# global_step=98799, episodic_return=[-200.]
# global_step=98999, episodic_return=[-200.]
# global_step=99199, episodic_return=[-200.]
# global_step=99399, episodic_return=[-200.]
# global_step=99599, episodic_return=[-200.]
# global_step=99799, episodic_return=[-200.]
# global_step=99999, episodic_return=[-200.]
# global_step=100199, episodic_return=[-200.]
# global_step=100399, episodic_return=[-200.]
# global_step=100599, episodic_return=[-200.]
# global_step=100799, episodic_return=[-200.]
# global_step=100999, episodic_return=[-200.]
# global_step=101199, episodic_return=[-200.]
# global_step=101399, episodic_return=[-200.]
# global_step=101599, episodic_return=[-200.]
# global_step=101799, episodic_return=[-200.]
# global_step=101999, episodic_return=[-200.]
# global_step=102199, episodic_return=[-200.]
# global_step=102399, episodic_return=[-200.]
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-512.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-512.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-512.mp4
# global_step=102599, episodic_return=[-200.]
# global_step=102799, episodic_return=[-200.]
# global_step=102999, episodic_return=[-200.]
# global_step=103199, episodic_return=[-200.]
# global_step=103399, episodic_return=[-200.]
# global_step=103599, episodic_return=[-200.]
# global_step=103799, episodic_return=[-200.]
# global_step=103999, episodic_return=[-200.]
# global_step=104199, episodic_return=[-200.]
# global_step=104399, episodic_return=[-200.]
# global_step=104599, episodic_return=[-200.]
# global_step=104799, episodic_return=[-200.]
# global_step=104999, episodic_return=[-200.]
# global_step=105199, episodic_return=[-200.]
# global_step=105399, episodic_return=[-200.]
# global_step=105599, episodic_return=[-200.]
# global_step=105799, episodic_return=[-200.]
# global_step=105999, episodic_return=[-200.]
# global_step=106199, episodic_return=[-200.]
# global_step=106399, episodic_return=[-200.]
# global_step=106599, episodic_return=[-200.]
# global_step=106799, episodic_return=[-200.]
# global_step=106999, episodic_return=[-200.]
# global_step=107199, episodic_return=[-200.]
# global_step=107399, episodic_return=[-200.]
# global_step=107599, episodic_return=[-200.]
# global_step=107799, episodic_return=[-200.]
# global_step=107999, episodic_return=[-200.]
# global_step=108199, episodic_return=[-200.]
# global_step=108399, episodic_return=[-200.]
# global_step=108599, episodic_return=[-200.]
# global_step=108799, episodic_return=[-200.]
# global_step=108999, episodic_return=[-200.]
# global_step=109199, episodic_return=[-200.]
# global_step=109399, episodic_return=[-200.]
# global_step=109599, episodic_return=[-200.]
# global_step=109799, episodic_return=[-200.]
# global_step=109999, episodic_return=[-200.]
# global_step=110199, episodic_return=[-200.]
# global_step=110399, episodic_return=[-200.]
# global_step=110599, episodic_return=[-200.]
# global_step=110799, episodic_return=[-200.]
# global_step=110999, episodic_return=[-200.]
# global_step=111199, episodic_return=[-200.]
# global_step=111399, episodic_return=[-200.]
# global_step=111599, episodic_return=[-200.]
# global_step=111799, episodic_return=[-200.]
# global_step=111999, episodic_return=[-200.]
# global_step=112199, episodic_return=[-200.]
# global_step=112399, episodic_return=[-200.]
# global_step=112599, episodic_return=[-200.]
# global_step=112799, episodic_return=[-200.]
# global_step=112999, episodic_return=[-200.]
# global_step=113199, episodic_return=[-200.]
# global_step=113399, episodic_return=[-200.]
# global_step=113599, episodic_return=[-200.]
# global_step=113799, episodic_return=[-200.]
# global_step=113999, episodic_return=[-200.]
# global_step=114199, episodic_return=[-200.]
# global_step=114399, episodic_return=[-200.]
# global_step=114599, episodic_return=[-200.]
# global_step=114799, episodic_return=[-200.]
# global_step=114999, episodic_return=[-200.]
# global_step=115199, episodic_return=[-200.]
# global_step=115399, episodic_return=[-200.]
# global_step=115599, episodic_return=[-200.]
# global_step=115799, episodic_return=[-200.]
# global_step=115999, episodic_return=[-200.]
# global_step=116199, episodic_return=[-200.]
# global_step=116399, episodic_return=[-200.]
# global_step=116599, episodic_return=[-200.]
# global_step=116799, episodic_return=[-200.]
# global_step=116999, episodic_return=[-200.]
# global_step=117199, episodic_return=[-200.]
# global_step=117399, episodic_return=[-200.]
# global_step=117599, episodic_return=[-200.]
# global_step=117799, episodic_return=[-200.]
# global_step=117999, episodic_return=[-200.]
# global_step=118199, episodic_return=[-200.]
# global_step=118399, episodic_return=[-200.]
# global_step=118599, episodic_return=[-200.]
# global_step=118799, episodic_return=[-200.]
# global_step=118999, episodic_return=[-200.]
# global_step=119199, episodic_return=[-200.]
# global_step=119399, episodic_return=[-200.]
# global_step=119599, episodic_return=[-200.]
# global_step=119799, episodic_return=[-200.]
# global_step=119999, episodic_return=[-200.]
# global_step=120199, episodic_return=[-200.]
# global_step=120399, episodic_return=[-200.]
# global_step=120599, episodic_return=[-200.]
# global_step=120799, episodic_return=[-200.]
# global_step=120999, episodic_return=[-200.]
# global_step=121199, episodic_return=[-200.]
# global_step=121399, episodic_return=[-200.]
# global_step=121599, episodic_return=[-200.]
# global_step=121799, episodic_return=[-200.]
# global_step=121999, episodic_return=[-200.]
# global_step=122199, episodic_return=[-200.]
# global_step=122399, episodic_return=[-200.]
# global_step=122599, episodic_return=[-200.]
# global_step=122799, episodic_return=[-200.]
# global_step=122999, episodic_return=[-200.]
# global_step=123199, episodic_return=[-200.]
# global_step=123399, episodic_return=[-200.]
# global_step=123599, episodic_return=[-200.]
# global_step=123799, episodic_return=[-200.]
# global_step=123999, episodic_return=[-200.]
# global_step=124199, episodic_return=[-200.]
# global_step=124399, episodic_return=[-200.]
# global_step=124599, episodic_return=[-200.]
# global_step=124799, episodic_return=[-200.]
# global_step=124999, episodic_return=[-200.]
# global_step=125199, episodic_return=[-200.]
# global_step=125399, episodic_return=[-200.]
# global_step=125599, episodic_return=[-200.]
# global_step=125799, episodic_return=[-200.]
# global_step=125999, episodic_return=[-200.]
# global_step=126199, episodic_return=[-200.]
# global_step=126399, episodic_return=[-200.]
# global_step=126599, episodic_return=[-200.]
# global_step=126799, episodic_return=[-200.]
# global_step=126999, episodic_return=[-200.]
# global_step=127199, episodic_return=[-200.]
# global_step=127399, episodic_return=[-200.]
# global_step=127599, episodic_return=[-200.]
# global_step=127799, episodic_return=[-200.]
# global_step=127999, episodic_return=[-200.]
# global_step=128199, episodic_return=[-200.]
# global_step=128399, episodic_return=[-200.]
# global_step=128599, episodic_return=[-200.]
# global_step=128799, episodic_return=[-200.]
# global_step=128999, episodic_return=[-200.]
# global_step=129199, episodic_return=[-200.]
# global_step=129399, episodic_return=[-200.]
# global_step=129599, episodic_return=[-200.]
# global_step=129799, episodic_return=[-200.]
# global_step=129999, episodic_return=[-200.]
# global_step=130199, episodic_return=[-200.]
# global_step=130399, episodic_return=[-200.]
# global_step=130599, episodic_return=[-200.]
# global_step=130799, episodic_return=[-200.]
# global_step=130999, episodic_return=[-200.]
# global_step=131199, episodic_return=[-200.]
# global_step=131399, episodic_return=[-200.]
# global_step=131599, episodic_return=[-200.]
# global_step=131799, episodic_return=[-200.]
# global_step=131999, episodic_return=[-200.]
# global_step=132199, episodic_return=[-200.]
# global_step=132399, episodic_return=[-200.]
# global_step=132599, episodic_return=[-200.]
# global_step=132799, episodic_return=[-200.]
# global_step=132999, episodic_return=[-200.]
# global_step=133199, episodic_return=[-200.]
# global_step=133399, episodic_return=[-200.]
# global_step=133599, episodic_return=[-200.]
# global_step=133799, episodic_return=[-200.]
# global_step=133999, episodic_return=[-200.]
# global_step=134199, episodic_return=[-200.]
# global_step=134399, episodic_return=[-200.]
# global_step=134599, episodic_return=[-200.]
# global_step=134799, episodic_return=[-200.]
# global_step=134999, episodic_return=[-200.]
# global_step=135199, episodic_return=[-200.]
# global_step=135399, episodic_return=[-200.]
# global_step=135599, episodic_return=[-200.]
# global_step=135799, episodic_return=[-200.]
# global_step=135999, episodic_return=[-200.]
# global_step=136199, episodic_return=[-200.]
# global_step=136399, episodic_return=[-200.]
# global_step=136599, episodic_return=[-200.]
# global_step=136799, episodic_return=[-200.]
# global_step=136999, episodic_return=[-200.]
# global_step=137199, episodic_return=[-200.]
# global_step=137399, episodic_return=[-200.]
# global_step=137599, episodic_return=[-200.]
# global_step=137799, episodic_return=[-200.]
# global_step=137999, episodic_return=[-200.]
# global_step=138199, episodic_return=[-200.]
# global_step=138399, episodic_return=[-200.]
# global_step=138599, episodic_return=[-200.]
# global_step=138799, episodic_return=[-200.]
# global_step=138999, episodic_return=[-200.]
# global_step=139199, episodic_return=[-200.]
# global_step=139399, episodic_return=[-200.]
# global_step=139599, episodic_return=[-200.]
# global_step=139799, episodic_return=[-200.]
# global_step=139999, episodic_return=[-200.]
# global_step=140199, episodic_return=[-200.]
# global_step=140399, episodic_return=[-200.]
# global_step=140599, episodic_return=[-200.]
# global_step=140799, episodic_return=[-200.]
# global_step=140999, episodic_return=[-200.]
# global_step=141199, episodic_return=[-200.]
# global_step=141399, episodic_return=[-200.]
# global_step=141599, episodic_return=[-200.]
# global_step=141799, episodic_return=[-200.]
# global_step=141999, episodic_return=[-200.]
# global_step=142199, episodic_return=[-200.]
# global_step=142399, episodic_return=[-200.]
# global_step=142599, episodic_return=[-200.]
# global_step=142799, episodic_return=[-200.]
# global_step=142999, episodic_return=[-200.]
# global_step=143199, episodic_return=[-200.]
# global_step=143399, episodic_return=[-200.]
# global_step=143599, episodic_return=[-200.]
# global_step=143799, episodic_return=[-200.]
# global_step=143999, episodic_return=[-200.]
# global_step=144199, episodic_return=[-200.]
# global_step=144399, episodic_return=[-200.]
# global_step=144599, episodic_return=[-200.]
# global_step=144799, episodic_return=[-200.]
# global_step=144999, episodic_return=[-200.]
# global_step=145199, episodic_return=[-200.]
# global_step=145399, episodic_return=[-200.]
# global_step=145599, episodic_return=[-200.]
# global_step=145799, episodic_return=[-200.]
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-729.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-729.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-729.mp4
# global_step=145999, episodic_return=[-200.]
# global_step=146199, episodic_return=[-200.]
# global_step=146399, episodic_return=[-200.]
# global_step=146599, episodic_return=[-200.]
# global_step=146799, episodic_return=[-200.]
# global_step=146999, episodic_return=[-200.]
# global_step=147199, episodic_return=[-200.]
# global_step=147399, episodic_return=[-200.]
# global_step=147599, episodic_return=[-200.]
# global_step=147799, episodic_return=[-200.]
# global_step=147999, episodic_return=[-200.]
# global_step=148199, episodic_return=[-200.]
# global_step=148399, episodic_return=[-200.]
# global_step=148599, episodic_return=[-200.]
# global_step=148799, episodic_return=[-200.]
# global_step=148999, episodic_return=[-200.]
# global_step=149199, episodic_return=[-200.]
# global_step=149399, episodic_return=[-200.]
# global_step=149599, episodic_return=[-200.]
# global_step=149799, episodic_return=[-200.]
# global_step=149999, episodic_return=[-200.]
# global_step=150199, episodic_return=[-200.]
# global_step=150399, episodic_return=[-200.]
# global_step=150599, episodic_return=[-200.]
# global_step=150799, episodic_return=[-200.]
# global_step=150999, episodic_return=[-200.]
# global_step=151199, episodic_return=[-200.]
# global_step=151399, episodic_return=[-200.]
# global_step=151599, episodic_return=[-200.]
# global_step=151799, episodic_return=[-200.]
# global_step=151999, episodic_return=[-200.]
# global_step=152199, episodic_return=[-200.]
# global_step=152399, episodic_return=[-200.]
# global_step=152599, episodic_return=[-200.]
# global_step=152799, episodic_return=[-200.]
# global_step=152999, episodic_return=[-200.]
# global_step=153199, episodic_return=[-200.]
# global_step=153399, episodic_return=[-200.]
# global_step=153599, episodic_return=[-200.]
# global_step=153799, episodic_return=[-200.]
# global_step=153999, episodic_return=[-200.]
# global_step=154199, episodic_return=[-200.]
# global_step=154399, episodic_return=[-200.]
# global_step=154599, episodic_return=[-200.]
# global_step=154799, episodic_return=[-200.]
# global_step=154999, episodic_return=[-200.]
# global_step=155199, episodic_return=[-200.]
# global_step=155399, episodic_return=[-200.]
# global_step=155599, episodic_return=[-200.]
# global_step=155799, episodic_return=[-200.]
# global_step=155999, episodic_return=[-200.]
# global_step=156199, episodic_return=[-200.]
# global_step=156399, episodic_return=[-200.]
# global_step=156599, episodic_return=[-200.]
# global_step=156799, episodic_return=[-200.]
# global_step=156999, episodic_return=[-200.]
# global_step=157199, episodic_return=[-200.]
# global_step=157399, episodic_return=[-200.]
# global_step=157599, episodic_return=[-200.]
# global_step=157799, episodic_return=[-200.]
# global_step=157999, episodic_return=[-200.]
# global_step=158199, episodic_return=[-200.]
# global_step=158399, episodic_return=[-200.]
# global_step=158599, episodic_return=[-200.]
# global_step=158799, episodic_return=[-200.]
# global_step=158999, episodic_return=[-200.]
# global_step=159199, episodic_return=[-200.]
# global_step=159399, episodic_return=[-200.]
# global_step=159599, episodic_return=[-200.]
# global_step=159799, episodic_return=[-200.]
# global_step=159999, episodic_return=[-200.]
# global_step=160199, episodic_return=[-200.]
# global_step=160399, episodic_return=[-200.]
# global_step=160599, episodic_return=[-200.]
# global_step=160799, episodic_return=[-200.]
# global_step=160999, episodic_return=[-200.]
# global_step=161199, episodic_return=[-200.]
# global_step=161399, episodic_return=[-200.]
# global_step=161599, episodic_return=[-200.]
# global_step=161799, episodic_return=[-200.]
# global_step=161999, episodic_return=[-200.]
# global_step=162199, episodic_return=[-200.]
# global_step=162399, episodic_return=[-200.]
# global_step=162599, episodic_return=[-200.]
# global_step=162799, episodic_return=[-200.]
# global_step=162999, episodic_return=[-200.]
# global_step=163199, episodic_return=[-200.]
# global_step=163399, episodic_return=[-200.]
# global_step=163599, episodic_return=[-200.]
# global_step=163799, episodic_return=[-200.]
# global_step=163999, episodic_return=[-200.]
# global_step=164199, episodic_return=[-200.]
# global_step=164399, episodic_return=[-200.]
# global_step=164599, episodic_return=[-200.]
# global_step=164799, episodic_return=[-200.]
# global_step=164999, episodic_return=[-200.]
# global_step=165199, episodic_return=[-200.]
# global_step=165399, episodic_return=[-200.]
# global_step=165599, episodic_return=[-200.]
# global_step=165799, episodic_return=[-200.]
# global_step=165999, episodic_return=[-200.]
# global_step=166199, episodic_return=[-200.]
# global_step=166399, episodic_return=[-200.]
# global_step=166599, episodic_return=[-200.]
# global_step=166799, episodic_return=[-200.]
# global_step=166999, episodic_return=[-200.]
# global_step=167199, episodic_return=[-200.]
# global_step=167399, episodic_return=[-200.]
# global_step=167599, episodic_return=[-200.]
# global_step=167799, episodic_return=[-200.]
# global_step=167999, episodic_return=[-200.]
# global_step=168199, episodic_return=[-200.]
# global_step=168399, episodic_return=[-200.]
# global_step=168599, episodic_return=[-200.]
# global_step=168799, episodic_return=[-200.]
# global_step=168999, episodic_return=[-200.]
# global_step=169199, episodic_return=[-200.]
# global_step=169399, episodic_return=[-200.]
# global_step=169599, episodic_return=[-200.]
# global_step=169799, episodic_return=[-200.]
# global_step=169999, episodic_return=[-200.]
# global_step=170199, episodic_return=[-200.]
# global_step=170399, episodic_return=[-200.]
# global_step=170599, episodic_return=[-200.]
# global_step=170799, episodic_return=[-200.]
# global_step=170999, episodic_return=[-200.]
# global_step=171199, episodic_return=[-200.]
# global_step=171399, episodic_return=[-200.]
# global_step=171599, episodic_return=[-200.]
# global_step=171799, episodic_return=[-200.]
# global_step=171999, episodic_return=[-200.]
# global_step=172199, episodic_return=[-200.]
# global_step=172399, episodic_return=[-200.]
# global_step=172599, episodic_return=[-200.]
# global_step=172799, episodic_return=[-200.]
# global_step=172999, episodic_return=[-200.]
# global_step=173199, episodic_return=[-200.]
# global_step=173399, episodic_return=[-200.]
# global_step=173599, episodic_return=[-200.]
# global_step=173799, episodic_return=[-200.]
# global_step=173999, episodic_return=[-200.]
# global_step=174199, episodic_return=[-200.]
# global_step=174399, episodic_return=[-200.]
# global_step=174599, episodic_return=[-200.]
# global_step=174799, episodic_return=[-200.]
# global_step=174999, episodic_return=[-200.]
# global_step=175199, episodic_return=[-200.]
# global_step=175399, episodic_return=[-200.]
# global_step=175599, episodic_return=[-200.]
# global_step=175799, episodic_return=[-200.]
# global_step=175999, episodic_return=[-200.]
# global_step=176199, episodic_return=[-200.]
# global_step=176399, episodic_return=[-200.]
# global_step=176599, episodic_return=[-200.]
# global_step=176799, episodic_return=[-200.]
# global_step=176999, episodic_return=[-200.]
# global_step=177199, episodic_return=[-200.]
# global_step=177399, episodic_return=[-200.]
# global_step=177599, episodic_return=[-200.]
# global_step=177799, episodic_return=[-200.]
# global_step=177999, episodic_return=[-200.]
# global_step=178199, episodic_return=[-200.]
# global_step=178399, episodic_return=[-200.]
# global_step=178599, episodic_return=[-200.]
# global_step=178799, episodic_return=[-200.]
# global_step=178999, episodic_return=[-200.]
# global_step=179199, episodic_return=[-200.]
# global_step=179399, episodic_return=[-200.]
# global_step=179599, episodic_return=[-200.]
# global_step=179799, episodic_return=[-200.]
# global_step=179999, episodic_return=[-200.]
# global_step=180199, episodic_return=[-200.]
# global_step=180399, episodic_return=[-200.]
# global_step=180599, episodic_return=[-200.]
# global_step=180799, episodic_return=[-200.]
# global_step=180999, episodic_return=[-200.]
# global_step=181199, episodic_return=[-200.]
# global_step=181399, episodic_return=[-200.]
# global_step=181599, episodic_return=[-200.]
# global_step=181799, episodic_return=[-200.]
# global_step=181999, episodic_return=[-200.]
# global_step=182199, episodic_return=[-200.]
# global_step=182399, episodic_return=[-200.]
# global_step=182599, episodic_return=[-200.]
# global_step=182799, episodic_return=[-200.]
# global_step=182999, episodic_return=[-200.]
# global_step=183199, episodic_return=[-200.]
# global_step=183399, episodic_return=[-200.]
# global_step=183599, episodic_return=[-200.]
# global_step=183799, episodic_return=[-200.]
# global_step=183999, episodic_return=[-200.]
# global_step=184199, episodic_return=[-200.]
# global_step=184399, episodic_return=[-200.]
# global_step=184599, episodic_return=[-200.]
# global_step=184799, episodic_return=[-200.]
# global_step=184999, episodic_return=[-200.]
# global_step=185199, episodic_return=[-200.]
# global_step=185399, episodic_return=[-200.]
# global_step=185599, episodic_return=[-200.]
# global_step=185799, episodic_return=[-200.]
# global_step=185999, episodic_return=[-200.]
# global_step=186199, episodic_return=[-200.]
# global_step=186399, episodic_return=[-200.]
# global_step=186599, episodic_return=[-200.]
# global_step=186799, episodic_return=[-200.]
# global_step=186999, episodic_return=[-200.]
# global_step=187199, episodic_return=[-200.]
# global_step=187399, episodic_return=[-200.]
# global_step=187599, episodic_return=[-200.]
# global_step=187799, episodic_return=[-200.]
# global_step=187999, episodic_return=[-200.]
# global_step=188199, episodic_return=[-200.]
# global_step=188399, episodic_return=[-200.]
# global_step=188599, episodic_return=[-200.]
# global_step=188799, episodic_return=[-200.]
# global_step=188999, episodic_return=[-200.]
# global_step=189199, episodic_return=[-200.]
# global_step=189399, episodic_return=[-200.]
# global_step=189599, episodic_return=[-200.]
# global_step=189799, episodic_return=[-200.]
# global_step=189999, episodic_return=[-200.]
# global_step=190199, episodic_return=[-200.]
# global_step=190399, episodic_return=[-200.]
# global_step=190599, episodic_return=[-200.]
# global_step=190799, episodic_return=[-200.]
# global_step=190999, episodic_return=[-200.]
# global_step=191199, episodic_return=[-200.]
# global_step=191399, episodic_return=[-200.]
# global_step=191599, episodic_return=[-200.]
# global_step=191799, episodic_return=[-200.]
# global_step=191999, episodic_return=[-200.]
# global_step=192199, episodic_return=[-200.]
# global_step=192399, episodic_return=[-200.]
# global_step=192599, episodic_return=[-200.]
# global_step=192799, episodic_return=[-200.]
# global_step=192999, episodic_return=[-200.]
# global_step=193199, episodic_return=[-200.]
# global_step=193399, episodic_return=[-200.]
# global_step=193599, episodic_return=[-200.]
# global_step=193799, episodic_return=[-200.]
# global_step=193999, episodic_return=[-200.]
# global_step=194199, episodic_return=[-200.]
# global_step=194399, episodic_return=[-200.]
# global_step=194599, episodic_return=[-200.]
# global_step=194799, episodic_return=[-200.]
# global_step=194999, episodic_return=[-200.]
# global_step=195199, episodic_return=[-200.]
# global_step=195399, episodic_return=[-200.]
# global_step=195599, episodic_return=[-200.]
# global_step=195799, episodic_return=[-200.]
# global_step=195999, episodic_return=[-200.]
# global_step=196199, episodic_return=[-200.]
# global_step=196399, episodic_return=[-200.]
# global_step=196599, episodic_return=[-200.]
# global_step=196799, episodic_return=[-200.]
# global_step=196999, episodic_return=[-200.]
# global_step=197199, episodic_return=[-200.]
# global_step=197399, episodic_return=[-200.]
# global_step=197599, episodic_return=[-200.]
# global_step=197799, episodic_return=[-200.]
# global_step=197999, episodic_return=[-200.]
# global_step=198199, episodic_return=[-200.]
# global_step=198399, episodic_return=[-200.]
# global_step=198599, episodic_return=[-200.]
# global_step=198799, episodic_return=[-200.]
# global_step=198999, episodic_return=[-200.]
# global_step=199199, episodic_return=[-200.]
# global_step=199399, episodic_return=[-200.]
# global_step=199599, episodic_return=[-200.]
# global_step=199799, episodic_return=[-200.]
# global_step=199999, episodic_return=[-200.]
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-1000.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397/rl-video-episode-1000.mp4
# ...
# global_step=464999, episodic_return=[-200.]
# global_step=465199, episodic_return=[-200.]
# global_step=465399, episodic_return=[-200.]
# global_step=465599, episodic_return=[-200.]
# global_step=465799, episodic_return=[-200.]
# global_step=465999, episodic_return=[-200.]
# global_step=466199, episodic_return=[-200.]
# global_step=466399, episodic_return=[-200.]
# global_step=466599, episodic_return=[-200.]
# global_step=466799, episodic_return=[-200.]
# global_step=466999, episodic_return=[-200.]
# global_step=467199, episodic_return=[-200.]
# global_step=467399, episodic_return=[-200.]
# global_step=467599, episodic_return=[-200.]
# global_step=467799, episodic_return=[-200.]
# global_step=467999, episodic_return=[-200.]
# global_step=468199, episodic_return=[-200.]
# global_step=468399, episodic_return=[-200.]
# global_step=468599, episodic_return=[-200.]
# global_step=468799, episodic_return=[-200.]
# global_step=468999, episodic_return=[-200.]
# global_step=469199, episodic_return=[-200.]
# global_step=469399, episodic_return=[-200.]
# global_step=469599, episodic_return=[-200.]
# global_step=469799, episodic_return=[-200.]
# global_step=469999, episodic_return=[-200.]
# global_step=470199, episodic_return=[-200.]
# global_step=470399, episodic_return=[-200.]
# global_step=470599, episodic_return=[-200.]
# global_step=470799, episodic_return=[-200.]
# global_step=470999, episodic_return=[-200.]
# global_step=471199, episodic_return=[-200.]
# global_step=471399, episodic_return=[-200.]
# global_step=471599, episodic_return=[-200.]
# global_step=471799, episodic_return=[-200.]
# global_step=471999, episodic_return=[-200.]
# global_step=472199, episodic_return=[-200.]
# global_step=472399, episodic_return=[-200.]
# global_step=472599, episodic_return=[-200.]
# global_step=472799, episodic_return=[-200.]
# global_step=472999, episodic_return=[-200.]
# global_step=473199, episodic_return=[-200.]
# global_step=473399, episodic_return=[-200.]
# global_step=473599, episodic_return=[-200.]
# global_step=473799, episodic_return=[-200.]
# global_step=473999, episodic_return=[-200.]
# global_step=474199, episodic_return=[-200.]
# global_step=474399, episodic_return=[-200.]
# global_step=474599, episodic_return=[-200.]
# global_step=474799, episodic_return=[-200.]
# global_step=474999, episodic_return=[-200.]
# global_step=475199, episodic_return=[-200.]
# global_step=475399, episodic_return=[-200.]
# global_step=475599, episodic_return=[-200.]
# global_step=475799, episodic_return=[-200.]
# global_step=475999, episodic_return=[-200.]
# global_step=476199, episodic_return=[-200.]
# global_step=476399, episodic_return=[-200.]
# global_step=476599, episodic_return=[-200.]
# global_step=476799, episodic_return=[-200.]
# global_step=476999, episodic_return=[-200.]
# global_step=477199, episodic_return=[-200.]
# global_step=477399, episodic_return=[-200.]
# global_step=477599, episodic_return=[-200.]
# global_step=477799, episodic_return=[-200.]
# global_step=477999, episodic_return=[-200.]
# global_step=478199, episodic_return=[-200.]
# global_step=478399, episodic_return=[-200.]
# global_step=478599, episodic_return=[-200.]
# global_step=478799, episodic_return=[-200.]
# global_step=478999, episodic_return=[-200.]
# global_step=479199, episodic_return=[-200.]
# global_step=479399, episodic_return=[-200.]
# global_step=479599, episodic_return=[-200.]
# global_step=479799, episodic_return=[-200.]
# global_step=479999, episodic_return=[-200.]
# global_step=480199, episodic_return=[-200.]
# global_step=480399, episodic_return=[-200.]
# global_step=480599, episodic_return=[-200.]
# global_step=480799, episodic_return=[-200.]
# global_step=480999, episodic_return=[-200.]
# global_step=481199, episodic_return=[-200.]
# global_step=481399, episodic_return=[-200.]
# global_step=481599, episodic_return=[-200.]
# global_step=481799, episodic_return=[-200.]
# global_step=481999, episodic_return=[-200.]
# global_step=482199, episodic_return=[-200.]
# global_step=482399, episodic_return=[-200.]
# global_step=482599, episodic_return=[-200.]
# global_step=482799, episodic_return=[-200.]
# global_step=482999, episodic_return=[-200.]
# global_step=483199, episodic_return=[-200.]
# global_step=483399, episodic_return=[-200.]
# global_step=483599, episodic_return=[-200.]
# global_step=483799, episodic_return=[-200.]
# global_step=483999, episodic_return=[-200.]
# global_step=484199, episodic_return=[-200.]
# global_step=484399, episodic_return=[-200.]
# global_step=484599, episodic_return=[-200.]
# global_step=484799, episodic_return=[-200.]
# global_step=484999, episodic_return=[-200.]
# global_step=485199, episodic_return=[-200.]
# global_step=485399, episodic_return=[-200.]
# global_step=485599, episodic_return=[-200.]
# global_step=485799, episodic_return=[-200.]
# global_step=485999, episodic_return=[-200.]
# global_step=486199, episodic_return=[-200.]
# global_step=486399, episodic_return=[-200.]
# global_step=486599, episodic_return=[-200.]
# global_step=486799, episodic_return=[-200.]
# global_step=486999, episodic_return=[-200.]
# global_step=487199, episodic_return=[-200.]
# global_step=487399, episodic_return=[-200.]
# global_step=487599, episodic_return=[-200.]
# global_step=487799, episodic_return=[-200.]
# global_step=487999, episodic_return=[-200.]
# global_step=488199, episodic_return=[-200.]
# global_step=488399, episodic_return=[-200.]
# global_step=488599, episodic_return=[-200.]
# global_step=488799, episodic_return=[-200.]
# global_step=488999, episodic_return=[-200.]
# global_step=489199, episodic_return=[-200.]
# global_step=489399, episodic_return=[-200.]
# global_step=489599, episodic_return=[-200.]
# global_step=489799, episodic_return=[-200.]
# global_step=489999, episodic_return=[-200.]
# global_step=490199, episodic_return=[-200.]
# global_step=490399, episodic_return=[-200.]
# global_step=490599, episodic_return=[-200.]
# global_step=490799, episodic_return=[-200.]
# global_step=490999, episodic_return=[-200.]
# global_step=491199, episodic_return=[-200.]
# global_step=491399, episodic_return=[-200.]
# global_step=491599, episodic_return=[-200.]
# global_step=491799, episodic_return=[-200.]
# global_step=491999, episodic_return=[-200.]
# global_step=492199, episodic_return=[-200.]
# global_step=492399, episodic_return=[-200.]
# global_step=492599, episodic_return=[-200.]
# global_step=492799, episodic_return=[-200.]
# global_step=492999, episodic_return=[-200.]
# global_step=493199, episodic_return=[-200.]
# global_step=493399, episodic_return=[-200.]
# global_step=493599, episodic_return=[-200.]
# global_step=493799, episodic_return=[-200.]
# global_step=493999, episodic_return=[-200.]
# global_step=494199, episodic_return=[-200.]
# global_step=494399, episodic_return=[-200.]
# global_step=494599, episodic_return=[-200.]
# global_step=494799, episodic_return=[-200.]
# global_step=494999, episodic_return=[-200.]
# global_step=495199, episodic_return=[-200.]
# global_step=495399, episodic_return=[-200.]
# global_step=495599, episodic_return=[-200.]
# global_step=495799, episodic_return=[-200.]
# global_step=495999, episodic_return=[-200.]
# global_step=496199, episodic_return=[-200.]
# global_step=496399, episodic_return=[-200.]
# global_step=496599, episodic_return=[-200.]
# global_step=496799, episodic_return=[-200.]
# global_step=496999, episodic_return=[-200.]
# global_step=497199, episodic_return=[-200.]
# global_step=497399, episodic_return=[-200.]
# global_step=497599, episodic_return=[-200.]
# global_step=497799, episodic_return=[-200.]
# global_step=497999, episodic_return=[-200.]
# global_step=498199, episodic_return=[-200.]
# global_step=498399, episodic_return=[-200.]
# global_step=498599, episodic_return=[-200.]
# global_step=498799, episodic_return=[-200.]
# global_step=498999, episodic_return=[-200.]
# global_step=499199, episodic_return=[-200.]
# global_step=499399, episodic_return=[-200.]
# global_step=499599, episodic_return=[-200.]
# global_step=499799, episodic_return=[-200.]
# global_step=499999, episodic_return=[-200.]
# Model Saved
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-0.mp4
# eval_episode=0, episodic_return=[-200.]
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-1.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-1.mp4
# eval_episode=1, episodic_return=[-200.]
# eval_episode=2, episodic_return=[-200.]
# eval_episode=3, episodic_return=[-200.]
# eval_episode=4, episodic_return=[-200.]
# eval_episode=5, episodic_return=[-200.]
# eval_episode=6, episodic_return=[-200.]
# eval_episode=7, episodic_return=[-200.]
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-8.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-8.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-8.mp4
# eval_episode=8, episodic_return=[-200.]
# eval_episode=9, episodic_return=[-200.]
# eval_episode=10, episodic_return=[-200.]
# eval_episode=11, episodic_return=[-200.]
# eval_episode=12, episodic_return=[-200.]
# eval_episode=13, episodic_return=[-200.]
# eval_episode=14, episodic_return=[-200.]
# eval_episode=15, episodic_return=[-200.]
# eval_episode=16, episodic_return=[-200.]
# eval_episode=17, episodic_return=[-200.]
# eval_episode=18, episodic_return=[-200.]
# eval_episode=19, episodic_return=[-200.]
# eval_episode=20, episodic_return=[-200.]
# eval_episode=21, episodic_return=[-200.]
# eval_episode=22, episodic_return=[-200.]
# eval_episode=23, episodic_return=[-200.]
# eval_episode=24, episodic_return=[-200.]
# eval_episode=25, episodic_return=[-200.]
# eval_episode=26, episodic_return=[-200.]
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-27.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-27.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-27.mp4
# eval_episode=27, episodic_return=[-200.]
# eval_episode=28, episodic_return=[-200.]
# eval_episode=29, episodic_return=[-200.]
# eval_episode=30, episodic_return=[-200.]
# eval_episode=31, episodic_return=[-200.]
# eval_episode=32, episodic_return=[-200.]
# eval_episode=33, episodic_return=[-200.]
# eval_episode=34, episodic_return=[-200.]
# eval_episode=35, episodic_return=[-200.]
# eval_episode=36, episodic_return=[-200.]
# eval_episode=37, episodic_return=[-200.]
# eval_episode=38, episodic_return=[-200.]
# eval_episode=39, episodic_return=[-200.]
# eval_episode=40, episodic_return=[-200.]
# eval_episode=41, episodic_return=[-200.]
# eval_episode=42, episodic_return=[-200.]
# eval_episode=43, episodic_return=[-200.]
# eval_episode=44, episodic_return=[-200.]
# eval_episode=45, episodic_return=[-200.]
# eval_episode=46, episodic_return=[-200.]
# eval_episode=47, episodic_return=[-200.]
# eval_episode=48, episodic_return=[-200.]
# eval_episode=49, episodic_return=[-200.]
# eval_episode=50, episodic_return=[-200.]
# eval_episode=51, episodic_return=[-200.]
# eval_episode=52, episodic_return=[-200.]
# eval_episode=53, episodic_return=[-200.]
# eval_episode=54, episodic_return=[-200.]
# eval_episode=55, episodic_return=[-200.]
# eval_episode=56, episodic_return=[-200.]
# eval_episode=57, episodic_return=[-200.]
# eval_episode=58, episodic_return=[-200.]
# eval_episode=59, episodic_return=[-200.]
# eval_episode=60, episodic_return=[-200.]
# eval_episode=61, episodic_return=[-200.]
# eval_episode=62, episodic_return=[-200.]
# eval_episode=63, episodic_return=[-200.]
# Moviepy - Building video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-64.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-64.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/MountainCar-v0__1__1699886397-eval/rl-video-episode-64.mp4
# eval_episode=64, episodic_return=[-200.]
# eval_episode=65, episodic_return=[-200.]
# eval_episode=66, episodic_return=[-200.]
# eval_episode=67, episodic_return=[-200.]
# eval_episode=68, episodic_return=[-200.]
# eval_episode=69, episodic_return=[-200.]
# eval_episode=70, episodic_return=[-200.]
# eval_episode=71, episodic_return=[-200.]
# eval_episode=72, episodic_return=[-200.]
# eval_episode=73, episodic_return=[-200.]
# eval_episode=74, episodic_return=[-200.]
# eval_episode=75, episodic_return=[-200.]
# eval_episode=76, episodic_return=[-200.]
# eval_episode=77, episodic_return=[-200.]
# eval_episode=78, episodic_return=[-200.]
# eval_episode=79, episodic_return=[-200.]
# eval_episode=80, episodic_return=[-200.]
# eval_episode=81, episodic_return=[-200.]
# eval_episode=82, episodic_return=[-200.]
# eval_episode=83, episodic_return=[-200.]
# eval_episode=84, episodic_return=[-200.]
# eval_episode=85, episodic_return=[-200.]
# eval_episode=86, episodic_return=[-200.]
# eval_episode=87, episodic_return=[-200.]
# eval_episode=88, episodic_return=[-200.]
# eval_episode=89, episodic_return=[-200.]
# eval_episode=90, episodic_return=[-200.]
# eval_episode=91, episodic_return=[-200.]
# eval_episode=92, episodic_return=[-200.]
# eval_episode=93, episodic_return=[-200.]
# eval_episode=94, episodic_return=[-200.]
# eval_episode=95, episodic_return=[-200.]
# eval_episode=96, episodic_return=[-200.]
# eval_episode=97, episodic_return=[-200.]
# eval_episode=98, episodic_return=[-200.]
# eval_episode=99, episodic_return=[-200.]
# VBox(children=(Label(value='1.606 MB of 1.606 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>charts/SPS</td><td>▁▄▅▆▇▇▇█▇▇█▇▇▇▇▇▇▇▇▆▆▅▅▅▅▅▅▄▄▄▄▄▄▄▄▄▄▄▄▄</td></tr><tr><td>charts/episodic_length</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>charts/episodic_return</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>charts/epsilon</td><td>██▇▇▇▆▆▆▅▅▅▄▄▃▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/episodic_return</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>losses/q_values</td><td>█▇▆▅▅▄▄▄▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>losses/td_loss</td><td>▂▄█▆▆▇▇▃▅█▄▄▂▂▁▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>charts/SPS</td><td>931.0</td></tr><tr><td>charts/episodic_length</td><td>200.0</td></tr><tr><td>charts/episodic_return</td><td>-200.0</td></tr><tr><td>charts/epsilon</td><td>0.05</td></tr><tr><td>eval/episodic_return</td><td>-200.0</td></tr><tr><td>global_step</td><td>499999</td></tr><tr><td>losses/q_values</td><td>-99.8811</td></tr><tr><td>losses/td_loss</td><td>1e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">MountainCar-v0__1__1699886397</strong> at: <a href='https://wandb.ai/chkda/dqn-classic-control-benchmark/runs/n4zhtrln' target="_blank">https://wandb.ai/chkda/dqn-classic-control-benchmark/runs/n4zhtrln</a><br/> View job at <a href='https://wandb.ai/chkda/dqn-classic-control-benchmark/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjExNTMzNDk4OA==/version_details/v0' target="_blank">https://wandb.ai/chkda/dqn-classic-control-benchmark/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjExNTMzNDk4OA==/version_details/v0</a><br/>Synced 5 W&B file(s), 17 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231113_143957-n4zhtrln/logs</code>
