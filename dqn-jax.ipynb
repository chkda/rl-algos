# %%
import os
import random
import time
import wandb
from distutils.util import strtobool
from typing import Callable
import flax
import flax.linen as nn
import gymnasium as gym
import jax
import jax.numpy as jnp
import numpy as np
import optax

from flax.training.train_state import TrainState
from stable_baselines3.common.buffers import ReplayBuffer
from torch.utils.tensorboard import SummaryWriter

# %%
def make_env(env_id, seed, idx, capture_video, run_name):
    def thunk():
        if capture_video and idx == 0:
            env = gym.make(env_id, render_mode="rgb_array")
            env = gym.wrappers.RecordVideo(env, f"video/{run_name}")
        else:
            env = gym.make(env_id)
        env = gym.wrappers.RecordEpisodeStatistics(env)
        env.action_space.seed(seed)

        return env

    return thunk

# %%
class QNetwork(nn.Module):
    action_dim: int

    @nn.compact
    def __call__(self, x: jnp.ndarray):
        x = nn.Dense(120)(x)
        x = nn.relu(x)
        x = nn.Dense(84)(x)
        x = nn.relu(x)
        x = nn.Dense(self.action_dim)(x)
        # x = nn.relu(x)

        return x

# %%
class TrainState(TrainState):
    target_params: flax.core.FrozenDict

# %%
def linear_schedule(start_e: float, end_e: float, duration: int, t: int):
    slope = (end_e - start_e)/ duration
    return max(slope * t + start_e, end_e)

# %%
def evaluate(model_path: str,
             make_env: Callable,
             env_id: str,
             eval_episodes: int,
             run_name: str,
             Model: nn.Module,
             epsilon: float = 0.05,
             capture_video: bool = True,
             seed=1):
    envs = gym.vector.SyncVectorEnv([make_env(env_id, 0, 0, capture_video, run_name)])
    obs, _ = envs.reset()
    model = Model(action_dim=envs.single_action_space.n)
    q_key = jax.random.PRNGKey(seed)
    params = model.init(q_key, obs)
    with open(model_path, "rb") as f:
        params = flax.serialization.from_bytes(params, f.read())
    model.apply = jax.jit(model.apply)

    episodic_returns = []

    while len(episodic_returns) < eval_episodes:
        if random.random() < epsilon:
            actions = np.array([envs.single_action_space.sample() for _ in range(envs.num_envs)])
        else:
            q_values = model.apply(params,obs)
            actions = q_values.argmax(axis=-1)
            actions = jax.device_get(actions)
        next_obs, _, _, _, infos = envs.step(actions)
        if "final_info" in infos:
            for info in infos["final_info"]:
                if "episode" not in info:
                    continue
                print(f"eval_episode={len(episodic_returns)}, episodic_return={info['episode']['r']}")
                episodic_returns += [info["episode"]["r"]]

        obs = next_obs

    return episodic_returns

# %%
envs = {"cartPole":"CartPole-v1","acrobot":"Acrobot-v1","mountainCar":"MountainCar-v0"}
n_timesteps = 500000
learning_rate = 0.00025
buffer_size = 10000
gamma = 0.99
target_network_frequency = 500
max_grad_norm = 0.5
batch_size = 1024
start_e = 1
end_e = 0.05
exploration_fraction = 0.5
learning_starts = 10000
train_frequency = 10
seed = 1
capture_video = True
tau = 1
num_envs = 1

# %%
def train(env_id,timesteps,learning_rate,buffer_size,gamma,
          target_network_frequency,max_grad_norm,batch_size,
          start_e,end_e,exploration_fraction,learning_starts,
          train_frequency,seed,tau,num_envs):

    run_name = f"{env_id}__{seed}__{int(time.time())}"
    wandb.init(
        project="rl-algos-benchmark",
        config={
            "env":env_id,
            "timesteps":timesteps,
            "lr":learning_rate,
            "buffer_size":buffer_size,
            "gamma":gamma,
            "target_network_frequency":target_network_frequency,
            "batch_size":batch_size,
            "start_e":start_e,
            "end_e":end_e,
            "exploration_fraction":exploration_fraction,
            "learning_starts":learning_starts,
            "train_frequency":train_frequency,
            "seed":seed,
            "tau":tau,
            "num_envs":num_envs,
        },
        sync_tensorboard=True,
        monitor_gym=True,
        name=run_name,
    )
    
    writer = SummaryWriter(f"runs/{run_name}")

    random.seed(seed)
    np.random.seed(seed)
    key = jax.random.PRNGKey(seed)
    key, q_key = jax.random.split(key, 2)

    envs = gym.vector.SyncVectorEnv(
        [make_env(env_id, seed + i, i, True, run_name) for i in range(num_envs)]
    )

    obs, _ = envs.reset(seed=seed)

    q_network = QNetwork(action_dim=envs.single_action_space.n)

    q_state = TrainState.create(
        apply_fn=q_network.apply,
        params=q_network.init(q_key, obs),
        target_params=q_network.init(q_key,obs),
        tx=optax.adam(learning_rate=learning_rate)
    )

    q_network.apply = jax.jit(q_network.apply)
    q_state = q_state.replace(target_params=optax.incremental_update(q_state.params, q_state.target_params, 1))

    rb = ReplayBuffer(
        buffer_size,
        envs.single_observation_space,
        envs.single_action_space,
        "cpu",
        n_envs=num_envs,
        handle_timeout_termination=False,
    )

    @jax.jit
    def update(q_state, observations, actions, next_observations, rewards, dones):
        q_next_target = q_network.apply(q_state.target_params, next_observations)
        q_next_target = jnp.max(q_next_target, axis=-1)
        next_q_value = rewards + (1 - dones) * gamma * q_next_target

        def mse_loss(params):
            q_pred = q_network.apply(params, observations)
            q_pred = q_pred[jnp.arange(q_pred.shape[0]), actions.squeeze()]
            return ((q_pred - next_q_value)**2).mean(), q_pred

        (loss_value,q_pred), grads = jax.value_and_grad(mse_loss,has_aux=True)(q_state.params)
        q_state = q_state.apply_gradients(grads=grads)
        return loss_value, q_pred, q_state

    start_time = time.time()

    obs, _ = envs.reset(seed=seed)
    for global_step in range(timesteps):
        epsilon = linear_schedule(start_e, end_e, exploration_fraction * timesteps, global_step)
        if random.random() < epsilon:
            actions = np.array([envs.single_action_space.sample() for _ in range(envs.num_envs)])
        else:
            q_values = q_network.apply(q_state.params, obs)
            actions = q_values.argmax(axis=-1)
            actions = jax.device_get(actions)

        next_obs, rewards, terminated, truncated, infos = envs.step(actions)

        if "final_info" in infos:
            for info in infos["final_info"]:
                if "episode" not in info:
                    continue

                print(f"global_step={global_step}, episodic_return={info['episode']['r']}")
                writer.add_scalar("charts/episodic_return",info["episode"]["r"], global_step)
                writer.add_scalar("charts/episodic_length",info["episode"]["l"], global_step)
                writer.add_scalar("charts/epsilon",epsilon,global_step)


        real_next_obs = next_obs.copy()
        for idx,d in enumerate(truncated):
            if d and "final_observations" in infos:
                real_next_obs[idx] = infos["final_observations"][idx]
        rb.add(obs, real_next_obs, actions, rewards, terminated, infos)

        obs = next_obs

        if global_step > learning_starts:
            if global_step % train_frequency == 0:
                data = rb.sample(batch_size)

                loss, old_val, q_state = update(
                    q_state,
                    data.observations.numpy(),
                    data.actions.numpy(),
                    data.next_observations.numpy(),
                    data.rewards.flatten().numpy(),
                    data.dones.flatten().numpy(),
                )

                if global_step % 100 == 0:
                    writer.add_scalar("losses/td_loss",jax.device_get(loss),global_step)
                    writer.add_scalar("losses/q_values",jax.device_get(old_val).mean(), global_step)
                    writer.add_scalar("charts/SPS",int(global_step / (time.time() - start_time)),global_step)

            if global_step % target_network_frequency == 0:
                q_state = q_state.replace(
                    target_params=optax.incremental_update(q_state.params, q_state.target_params, tau)
                )

    model_path = f"runs/{run_name}.cleanrl_model"
    with open(model_path,"wb") as f:
        f.write(flax.serialization.to_bytes(q_state.params))

    print("Model Saved")

    episodic_returns = evaluate(
        model_path,
        make_env,
        env_id,
        run_name=f"{run_name}-eval",
        Model=QNetwork,
        epsilon=0.05,
        eval_episodes=100
    )

    for idx, episodic_return in enumerate(episodic_returns):
        writer.add_scalar("eval/episodic_return", episodic_return,idx)

    envs.close()
    writer.close()
    wandb.finish()

# %%
train(envs["acrobot"],n_timesteps,learning_rate,buffer_size,gamma,target_network_frequency,max_grad_norm,batch_size,start_e,end_e,exploration_fraction,learning_starts,train_frequency,seed,tau,num_envs)
# Out:
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/notebooks/rl-algos/wandb/run-20231113_113613-a8xpkqlw</code>
# Syncing run <strong><a href='https://wandb.ai/chkda/rl-algos-benchmark/runs/a8xpkqlw' target="_blank">Acrobot-v1__1__1699875373</a></strong> to <a href='https://wandb.ai/chkda/rl-algos-benchmark' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/chkda/rl-algos-benchmark' target="_blank">https://wandb.ai/chkda/rl-algos-benchmark</a>
#  View run at <a href='https://wandb.ai/chkda/rl-algos-benchmark/runs/a8xpkqlw' target="_blank">https://wandb.ai/chkda/rl-algos-benchmark/runs/a8xpkqlw</a>
# wandb: WARNING Found log directory outside of given root_logdir, dropping given root_logdir for event file in runs/Acrobot-v1__1__1699875373
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-0.mp4
# global_step=499, episodic_return=[-500.]
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-1.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-1.mp4
# global_step=999, episodic_return=[-500.]
# global_step=1499, episodic_return=[-500.]
# global_step=1999, episodic_return=[-500.]
# global_step=2499, episodic_return=[-500.]
# global_step=2999, episodic_return=[-500.]
# global_step=3499, episodic_return=[-500.]
# global_step=3999, episodic_return=[-500.]
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-8.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-8.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-8.mp4
# global_step=4499, episodic_return=[-500.]
# global_step=4999, episodic_return=[-500.]
# global_step=5499, episodic_return=[-500.]
# global_step=5999, episodic_return=[-500.]
# global_step=6499, episodic_return=[-500.]
# global_step=6999, episodic_return=[-500.]
# global_step=7499, episodic_return=[-500.]
# global_step=7999, episodic_return=[-500.]
# global_step=8499, episodic_return=[-500.]
# global_step=8999, episodic_return=[-500.]
# global_step=9499, episodic_return=[-500.]
# global_step=9999, episodic_return=[-500.]
# global_step=10499, episodic_return=[-500.]
# global_step=10999, episodic_return=[-500.]
# global_step=11499, episodic_return=[-500.]
# global_step=11999, episodic_return=[-500.]
# global_step=12499, episodic_return=[-500.]
# global_step=12999, episodic_return=[-500.]
# global_step=13499, episodic_return=[-500.]
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-27.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-27.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-27.mp4
# global_step=13999, episodic_return=[-500.]
# global_step=14499, episodic_return=[-500.]
# global_step=14999, episodic_return=[-500.]
# global_step=15499, episodic_return=[-500.]
# global_step=15999, episodic_return=[-500.]
# global_step=16499, episodic_return=[-500.]
# global_step=16999, episodic_return=[-500.]
# global_step=17499, episodic_return=[-500.]
# global_step=17999, episodic_return=[-500.]
# global_step=18499, episodic_return=[-500.]
# global_step=18999, episodic_return=[-500.]
# global_step=19499, episodic_return=[-500.]
# global_step=19999, episodic_return=[-500.]
# global_step=20499, episodic_return=[-500.]
# global_step=20999, episodic_return=[-500.]
# global_step=21499, episodic_return=[-500.]
# global_step=21999, episodic_return=[-500.]
# global_step=22271, episodic_return=[-271.]
# global_step=22771, episodic_return=[-500.]
# global_step=23271, episodic_return=[-500.]
# global_step=23771, episodic_return=[-500.]
# global_step=24271, episodic_return=[-500.]
# global_step=24771, episodic_return=[-500.]
# global_step=25271, episodic_return=[-500.]
# global_step=25771, episodic_return=[-500.]
# global_step=26271, episodic_return=[-500.]
# global_step=26771, episodic_return=[-500.]
# global_step=27271, episodic_return=[-500.]
# global_step=27771, episodic_return=[-500.]
# global_step=28271, episodic_return=[-500.]
# global_step=28771, episodic_return=[-500.]
# global_step=29271, episodic_return=[-500.]
# global_step=29771, episodic_return=[-500.]
# global_step=30271, episodic_return=[-500.]
# global_step=30771, episodic_return=[-500.]
# global_step=31271, episodic_return=[-500.]
# global_step=31717, episodic_return=[-445.]
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-64.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-64.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-64.mp4
# global_step=31984, episodic_return=[-266.]
# global_step=32465, episodic_return=[-480.]
# global_step=32965, episodic_return=[-500.]
# global_step=33329, episodic_return=[-363.]
# global_step=33829, episodic_return=[-500.]
# global_step=34329, episodic_return=[-500.]
# global_step=34629, episodic_return=[-299.]
# global_step=35106, episodic_return=[-476.]
# global_step=35606, episodic_return=[-500.]
# global_step=35865, episodic_return=[-258.]
# global_step=36365, episodic_return=[-500.]
# global_step=36764, episodic_return=[-398.]
# global_step=37264, episodic_return=[-500.]
# global_step=37764, episodic_return=[-500.]
# global_step=38103, episodic_return=[-338.]
# global_step=38545, episodic_return=[-441.]
# global_step=38837, episodic_return=[-291.]
# global_step=39337, episodic_return=[-500.]
# global_step=39837, episodic_return=[-500.]
# global_step=40337, episodic_return=[-500.]
# global_step=40751, episodic_return=[-413.]
# global_step=41100, episodic_return=[-348.]
# global_step=41463, episodic_return=[-362.]
# global_step=41963, episodic_return=[-500.]
# global_step=42394, episodic_return=[-430.]
# global_step=42736, episodic_return=[-341.]
# global_step=43113, episodic_return=[-376.]
# global_step=43611, episodic_return=[-497.]
# global_step=43963, episodic_return=[-351.]
# global_step=44390, episodic_return=[-426.]
# global_step=44642, episodic_return=[-251.]
# global_step=45142, episodic_return=[-500.]
# global_step=45396, episodic_return=[-253.]
# global_step=45896, episodic_return=[-500.]
# global_step=46311, episodic_return=[-414.]
# global_step=46811, episodic_return=[-500.]
# global_step=47048, episodic_return=[-236.]
# global_step=47548, episodic_return=[-500.]
# global_step=47827, episodic_return=[-278.]
# global_step=48242, episodic_return=[-414.]
# global_step=48542, episodic_return=[-299.]
# global_step=48951, episodic_return=[-408.]
# global_step=49358, episodic_return=[-406.]
# global_step=49575, episodic_return=[-216.]
# global_step=49994, episodic_return=[-418.]
# global_step=50247, episodic_return=[-252.]
# global_step=50668, episodic_return=[-420.]
# global_step=50952, episodic_return=[-283.]
# global_step=51406, episodic_return=[-453.]
# global_step=51600, episodic_return=[-193.]
# global_step=51890, episodic_return=[-289.]
# global_step=52180, episodic_return=[-289.]
# global_step=52423, episodic_return=[-242.]
# global_step=52689, episodic_return=[-265.]
# global_step=53034, episodic_return=[-344.]
# global_step=53457, episodic_return=[-422.]
# global_step=53810, episodic_return=[-352.]
# global_step=54033, episodic_return=[-222.]
# global_step=54533, episodic_return=[-500.]
# global_step=54945, episodic_return=[-411.]
# global_step=55211, episodic_return=[-265.]
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-125.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-125.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-125.mp4
# global_step=55469, episodic_return=[-257.]
# global_step=55781, episodic_return=[-311.]
# global_step=56056, episodic_return=[-274.]
# global_step=56422, episodic_return=[-365.]
# global_step=56757, episodic_return=[-334.]
# global_step=56964, episodic_return=[-206.]
# global_step=57305, episodic_return=[-340.]
# global_step=57558, episodic_return=[-252.]
# global_step=57872, episodic_return=[-313.]
# global_step=58078, episodic_return=[-205.]
# global_step=58516, episodic_return=[-437.]
# global_step=58867, episodic_return=[-350.]
# global_step=59168, episodic_return=[-300.]
# global_step=59492, episodic_return=[-323.]
# global_step=59722, episodic_return=[-229.]
# global_step=59992, episodic_return=[-269.]
# global_step=60341, episodic_return=[-348.]
# global_step=60565, episodic_return=[-223.]
# global_step=60758, episodic_return=[-192.]
# global_step=61013, episodic_return=[-254.]
# global_step=61240, episodic_return=[-226.]
# global_step=61471, episodic_return=[-230.]
# global_step=61650, episodic_return=[-178.]
# global_step=61821, episodic_return=[-170.]
# global_step=62117, episodic_return=[-295.]
# global_step=62398, episodic_return=[-280.]
# global_step=62780, episodic_return=[-381.]
# global_step=63077, episodic_return=[-296.]
# global_step=63297, episodic_return=[-219.]
# global_step=63797, episodic_return=[-500.]
# global_step=64082, episodic_return=[-284.]
# global_step=64270, episodic_return=[-187.]
# global_step=64538, episodic_return=[-267.]
# global_step=64881, episodic_return=[-342.]
# global_step=65076, episodic_return=[-194.]
# global_step=65390, episodic_return=[-313.]
# global_step=65682, episodic_return=[-291.]
# global_step=65883, episodic_return=[-200.]
# global_step=66175, episodic_return=[-291.]
# global_step=66500, episodic_return=[-324.]
# global_step=66698, episodic_return=[-197.]
# global_step=66917, episodic_return=[-218.]
# global_step=67216, episodic_return=[-298.]
# global_step=67449, episodic_return=[-232.]
# global_step=67691, episodic_return=[-241.]
# global_step=67985, episodic_return=[-293.]
# global_step=68302, episodic_return=[-316.]
# global_step=68450, episodic_return=[-147.]
# global_step=68714, episodic_return=[-263.]
# global_step=68980, episodic_return=[-265.]
# global_step=69181, episodic_return=[-200.]
# global_step=69406, episodic_return=[-224.]
# global_step=69728, episodic_return=[-321.]
# global_step=69986, episodic_return=[-257.]
# global_step=70222, episodic_return=[-235.]
# global_step=70436, episodic_return=[-213.]
# global_step=70697, episodic_return=[-260.]
# global_step=70915, episodic_return=[-217.]
# global_step=71217, episodic_return=[-301.]
# global_step=71426, episodic_return=[-208.]
# global_step=71625, episodic_return=[-198.]
# global_step=71829, episodic_return=[-203.]
# global_step=72136, episodic_return=[-306.]
# global_step=72296, episodic_return=[-159.]
# global_step=72478, episodic_return=[-181.]
# global_step=72754, episodic_return=[-275.]
# global_step=73014, episodic_return=[-259.]
# global_step=73310, episodic_return=[-295.]
# global_step=73548, episodic_return=[-237.]
# global_step=73765, episodic_return=[-216.]
# global_step=73963, episodic_return=[-197.]
# global_step=74192, episodic_return=[-228.]
# global_step=74438, episodic_return=[-245.]
# global_step=74632, episodic_return=[-193.]
# global_step=74848, episodic_return=[-215.]
# global_step=75137, episodic_return=[-288.]
# global_step=75281, episodic_return=[-143.]
# global_step=75507, episodic_return=[-225.]
# global_step=75755, episodic_return=[-247.]
# global_step=75933, episodic_return=[-177.]
# global_step=76119, episodic_return=[-185.]
# global_step=76363, episodic_return=[-243.]
# global_step=76625, episodic_return=[-261.]
# global_step=76902, episodic_return=[-276.]
# global_step=77088, episodic_return=[-185.]
# global_step=77424, episodic_return=[-335.]
# global_step=77798, episodic_return=[-373.]
# global_step=77949, episodic_return=[-150.]
# global_step=78228, episodic_return=[-278.]
# global_step=78384, episodic_return=[-155.]
# global_step=78652, episodic_return=[-267.]
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-216.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-216.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-216.mp4
# global_step=78814, episodic_return=[-161.]
# global_step=79132, episodic_return=[-317.]
# global_step=79354, episodic_return=[-221.]
# global_step=79556, episodic_return=[-201.]
# global_step=79723, episodic_return=[-166.]
# global_step=79942, episodic_return=[-218.]
# global_step=80131, episodic_return=[-188.]
# global_step=80358, episodic_return=[-226.]
# global_step=80602, episodic_return=[-243.]
# global_step=80747, episodic_return=[-144.]
# global_step=80975, episodic_return=[-227.]
# global_step=81212, episodic_return=[-236.]
# global_step=81448, episodic_return=[-235.]
# global_step=81656, episodic_return=[-207.]
# global_step=81875, episodic_return=[-218.]
# global_step=82097, episodic_return=[-221.]
# global_step=82314, episodic_return=[-216.]
# global_step=82521, episodic_return=[-206.]
# global_step=82679, episodic_return=[-157.]
# global_step=82916, episodic_return=[-236.]
# global_step=83154, episodic_return=[-237.]
# global_step=83358, episodic_return=[-203.]
# global_step=83549, episodic_return=[-190.]
# global_step=83806, episodic_return=[-256.]
# global_step=84097, episodic_return=[-290.]
# global_step=84316, episodic_return=[-218.]
# global_step=84519, episodic_return=[-202.]
# global_step=84745, episodic_return=[-225.]
# global_step=84946, episodic_return=[-200.]
# global_step=85149, episodic_return=[-202.]
# global_step=85362, episodic_return=[-212.]
# global_step=85529, episodic_return=[-166.]
# global_step=85740, episodic_return=[-210.]
# global_step=85985, episodic_return=[-244.]
# global_step=86186, episodic_return=[-200.]
# global_step=86476, episodic_return=[-289.]
# global_step=86636, episodic_return=[-159.]
# global_step=86814, episodic_return=[-177.]
# global_step=86995, episodic_return=[-180.]
# global_step=87218, episodic_return=[-222.]
# global_step=87484, episodic_return=[-265.]
# global_step=87683, episodic_return=[-198.]
# global_step=87908, episodic_return=[-224.]
# global_step=88073, episodic_return=[-164.]
# global_step=88240, episodic_return=[-166.]
# global_step=88461, episodic_return=[-220.]
# global_step=88747, episodic_return=[-285.]
# global_step=88938, episodic_return=[-190.]
# global_step=89108, episodic_return=[-169.]
# global_step=89382, episodic_return=[-273.]
# global_step=89625, episodic_return=[-242.]
# global_step=89772, episodic_return=[-146.]
# global_step=89975, episodic_return=[-202.]
# global_step=90200, episodic_return=[-224.]
# global_step=90348, episodic_return=[-147.]
# global_step=90512, episodic_return=[-163.]
# global_step=90772, episodic_return=[-259.]
# global_step=91003, episodic_return=[-230.]
# global_step=91205, episodic_return=[-201.]
# global_step=91405, episodic_return=[-199.]
# global_step=91599, episodic_return=[-193.]
# global_step=91816, episodic_return=[-216.]
# global_step=91936, episodic_return=[-119.]
# global_step=92163, episodic_return=[-226.]
# global_step=92438, episodic_return=[-274.]
# global_step=92608, episodic_return=[-169.]
# global_step=92770, episodic_return=[-161.]
# global_step=92960, episodic_return=[-189.]
# global_step=93137, episodic_return=[-176.]
# global_step=93318, episodic_return=[-180.]
# global_step=93512, episodic_return=[-193.]
# global_step=93823, episodic_return=[-310.]
# global_step=93972, episodic_return=[-148.]
# global_step=94220, episodic_return=[-247.]
# global_step=94450, episodic_return=[-229.]
# global_step=94700, episodic_return=[-249.]
# global_step=94918, episodic_return=[-217.]
# global_step=95111, episodic_return=[-192.]
# global_step=95238, episodic_return=[-126.]
# global_step=95436, episodic_return=[-197.]
# global_step=95576, episodic_return=[-139.]
# global_step=95775, episodic_return=[-198.]
# global_step=96023, episodic_return=[-247.]
# global_step=96123, episodic_return=[-99.]
# global_step=96307, episodic_return=[-183.]
# global_step=96503, episodic_return=[-195.]
# global_step=96679, episodic_return=[-175.]
# global_step=96808, episodic_return=[-128.]
# global_step=97047, episodic_return=[-238.]
# global_step=97197, episodic_return=[-149.]
# global_step=97428, episodic_return=[-230.]
# global_step=97664, episodic_return=[-235.]
# global_step=97820, episodic_return=[-155.]
# global_step=98049, episodic_return=[-228.]
# global_step=98209, episodic_return=[-159.]
# global_step=98418, episodic_return=[-208.]
# global_step=98621, episodic_return=[-202.]
# global_step=98809, episodic_return=[-187.]
# global_step=99004, episodic_return=[-194.]
# global_step=99187, episodic_return=[-182.]
# global_step=99357, episodic_return=[-169.]
# global_step=99578, episodic_return=[-220.]
# global_step=99742, episodic_return=[-163.]
# global_step=99945, episodic_return=[-202.]
# global_step=100126, episodic_return=[-180.]
# global_step=100343, episodic_return=[-216.]
# global_step=100572, episodic_return=[-228.]
# global_step=100791, episodic_return=[-218.]
# global_step=100971, episodic_return=[-179.]
# global_step=101142, episodic_return=[-170.]
# global_step=101302, episodic_return=[-159.]
# global_step=101506, episodic_return=[-203.]
# global_step=101666, episodic_return=[-159.]
# global_step=101850, episodic_return=[-183.]
# global_step=102110, episodic_return=[-259.]
# global_step=102273, episodic_return=[-162.]
# global_step=102469, episodic_return=[-195.]
# global_step=102669, episodic_return=[-199.]
# global_step=102836, episodic_return=[-166.]
# global_step=103195, episodic_return=[-358.]
# global_step=103444, episodic_return=[-248.]
# global_step=103669, episodic_return=[-224.]
# global_step=103859, episodic_return=[-189.]
# global_step=104010, episodic_return=[-150.]
# global_step=104165, episodic_return=[-154.]
# global_step=104386, episodic_return=[-220.]
# global_step=104632, episodic_return=[-245.]
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-343.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-343.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-343.mp4
# global_step=104774, episodic_return=[-141.]
# global_step=104953, episodic_return=[-178.]
# global_step=105115, episodic_return=[-161.]
# global_step=105253, episodic_return=[-137.]
# global_step=105407, episodic_return=[-153.]
# global_step=105565, episodic_return=[-157.]
# global_step=105762, episodic_return=[-196.]
# global_step=105928, episodic_return=[-165.]
# global_step=106134, episodic_return=[-205.]
# global_step=106446, episodic_return=[-311.]
# global_step=106605, episodic_return=[-158.]
# global_step=106803, episodic_return=[-197.]
# global_step=106948, episodic_return=[-144.]
# global_step=107135, episodic_return=[-186.]
# global_step=107322, episodic_return=[-186.]
# global_step=107505, episodic_return=[-182.]
# global_step=107704, episodic_return=[-198.]
# global_step=107848, episodic_return=[-143.]
# global_step=108012, episodic_return=[-163.]
# global_step=108189, episodic_return=[-176.]
# global_step=108340, episodic_return=[-150.]
# global_step=108539, episodic_return=[-198.]
# global_step=108709, episodic_return=[-169.]
# global_step=108900, episodic_return=[-190.]
# global_step=109085, episodic_return=[-184.]
# global_step=109305, episodic_return=[-219.]
# global_step=109462, episodic_return=[-156.]
# global_step=109704, episodic_return=[-241.]
# global_step=109854, episodic_return=[-149.]
# global_step=109999, episodic_return=[-144.]
# global_step=110182, episodic_return=[-182.]
# global_step=110326, episodic_return=[-143.]
# global_step=110470, episodic_return=[-143.]
# global_step=110593, episodic_return=[-122.]
# global_step=110763, episodic_return=[-169.]
# global_step=111263, episodic_return=[-500.]
# global_step=111397, episodic_return=[-133.]
# global_step=111583, episodic_return=[-185.]
# global_step=111767, episodic_return=[-183.]
# global_step=111979, episodic_return=[-211.]
# global_step=112223, episodic_return=[-243.]
# global_step=112340, episodic_return=[-116.]
# global_step=112484, episodic_return=[-143.]
# global_step=112625, episodic_return=[-140.]
# global_step=112758, episodic_return=[-132.]
# global_step=112902, episodic_return=[-143.]
# global_step=113083, episodic_return=[-180.]
# global_step=113210, episodic_return=[-126.]
# global_step=113531, episodic_return=[-320.]
# global_step=113672, episodic_return=[-140.]
# global_step=113790, episodic_return=[-117.]
# global_step=113960, episodic_return=[-169.]
# global_step=114089, episodic_return=[-128.]
# global_step=114282, episodic_return=[-192.]
# global_step=114440, episodic_return=[-157.]
# global_step=114598, episodic_return=[-157.]
# global_step=114710, episodic_return=[-111.]
# global_step=114944, episodic_return=[-233.]
# global_step=115108, episodic_return=[-163.]
# global_step=115279, episodic_return=[-170.]
# global_step=115657, episodic_return=[-377.]
# global_step=115847, episodic_return=[-189.]
# global_step=116023, episodic_return=[-175.]
# global_step=116180, episodic_return=[-156.]
# global_step=116348, episodic_return=[-167.]
# global_step=116526, episodic_return=[-177.]
# global_step=116639, episodic_return=[-112.]
# global_step=116760, episodic_return=[-120.]
# global_step=116911, episodic_return=[-150.]
# global_step=117103, episodic_return=[-191.]
# global_step=117260, episodic_return=[-156.]
# global_step=117418, episodic_return=[-157.]
# global_step=117558, episodic_return=[-139.]
# global_step=117701, episodic_return=[-142.]
# global_step=117883, episodic_return=[-181.]
# global_step=118046, episodic_return=[-162.]
# global_step=118318, episodic_return=[-271.]
# global_step=118485, episodic_return=[-166.]
# global_step=118688, episodic_return=[-202.]
# global_step=118877, episodic_return=[-188.]
# global_step=119052, episodic_return=[-174.]
# global_step=119205, episodic_return=[-152.]
# global_step=119390, episodic_return=[-184.]
# global_step=119538, episodic_return=[-147.]
# global_step=119650, episodic_return=[-111.]
# global_step=119776, episodic_return=[-125.]
# global_step=119943, episodic_return=[-166.]
# global_step=120078, episodic_return=[-134.]
# global_step=120210, episodic_return=[-131.]
# global_step=120376, episodic_return=[-165.]
# global_step=120590, episodic_return=[-213.]
# global_step=120695, episodic_return=[-104.]
# global_step=120786, episodic_return=[-90.]
# global_step=120998, episodic_return=[-211.]
# global_step=121184, episodic_return=[-185.]
# global_step=121347, episodic_return=[-162.]
# global_step=121536, episodic_return=[-188.]
# global_step=121666, episodic_return=[-129.]
# global_step=121844, episodic_return=[-177.]
# global_step=122019, episodic_return=[-174.]
# global_step=122241, episodic_return=[-221.]
# global_step=122347, episodic_return=[-105.]
# global_step=122501, episodic_return=[-153.]
# global_step=122647, episodic_return=[-145.]
# global_step=122770, episodic_return=[-122.]
# global_step=122890, episodic_return=[-119.]
# global_step=123027, episodic_return=[-136.]
# global_step=123169, episodic_return=[-141.]
# global_step=123400, episodic_return=[-230.]
# global_step=123573, episodic_return=[-172.]
# global_step=123751, episodic_return=[-177.]
# global_step=123897, episodic_return=[-145.]
# global_step=124042, episodic_return=[-144.]
# global_step=124171, episodic_return=[-128.]
# global_step=124313, episodic_return=[-141.]
# global_step=124813, episodic_return=[-500.]
# global_step=124987, episodic_return=[-173.]
# global_step=125131, episodic_return=[-143.]
# global_step=125290, episodic_return=[-158.]
# global_step=125425, episodic_return=[-134.]
# global_step=125546, episodic_return=[-120.]
# global_step=125662, episodic_return=[-115.]
# global_step=125838, episodic_return=[-175.]
# global_step=126048, episodic_return=[-209.]
# global_step=126214, episodic_return=[-165.]
# global_step=126359, episodic_return=[-144.]
# global_step=126520, episodic_return=[-160.]
# global_step=126635, episodic_return=[-114.]
# global_step=126783, episodic_return=[-147.]
# global_step=126911, episodic_return=[-127.]
# global_step=127059, episodic_return=[-147.]
# global_step=127196, episodic_return=[-136.]
# global_step=127382, episodic_return=[-185.]
# global_step=127503, episodic_return=[-120.]
# global_step=127617, episodic_return=[-113.]
# global_step=127768, episodic_return=[-150.]
# global_step=127896, episodic_return=[-127.]
# global_step=127999, episodic_return=[-102.]
# global_step=128154, episodic_return=[-154.]
# global_step=128285, episodic_return=[-130.]
# global_step=128444, episodic_return=[-158.]
# global_step=128644, episodic_return=[-199.]
# global_step=128779, episodic_return=[-134.]
# global_step=128882, episodic_return=[-102.]
# global_step=129040, episodic_return=[-157.]
# global_step=129158, episodic_return=[-117.]
# global_step=129311, episodic_return=[-152.]
# global_step=129453, episodic_return=[-141.]
# global_step=129616, episodic_return=[-162.]
# global_step=129800, episodic_return=[-183.]
# global_step=130006, episodic_return=[-205.]
# global_step=130150, episodic_return=[-143.]
# global_step=130295, episodic_return=[-144.]
# global_step=130435, episodic_return=[-139.]
# global_step=130599, episodic_return=[-163.]
# global_step=130771, episodic_return=[-171.]
# global_step=130926, episodic_return=[-154.]
# global_step=131038, episodic_return=[-111.]
# global_step=131128, episodic_return=[-89.]
# global_step=131248, episodic_return=[-119.]
# global_step=131381, episodic_return=[-132.]
# global_step=131531, episodic_return=[-149.]
# global_step=131687, episodic_return=[-155.]
# global_step=131839, episodic_return=[-151.]
# global_step=131979, episodic_return=[-139.]
# global_step=132130, episodic_return=[-150.]
# global_step=132262, episodic_return=[-131.]
# global_step=132416, episodic_return=[-153.]
# global_step=132533, episodic_return=[-116.]
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-512.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-512.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-512.mp4
# global_step=132680, episodic_return=[-146.]
# global_step=132778, episodic_return=[-97.]
# global_step=132892, episodic_return=[-113.]
# global_step=133105, episodic_return=[-212.]
# global_step=133226, episodic_return=[-120.]
# global_step=133354, episodic_return=[-127.]
# global_step=133493, episodic_return=[-138.]
# global_step=133659, episodic_return=[-165.]
# global_step=133776, episodic_return=[-116.]
# global_step=133948, episodic_return=[-171.]
# global_step=134101, episodic_return=[-152.]
# global_step=134231, episodic_return=[-129.]
# global_step=134377, episodic_return=[-145.]
# global_step=134503, episodic_return=[-125.]
# global_step=134672, episodic_return=[-168.]
# global_step=134828, episodic_return=[-155.]
# global_step=134987, episodic_return=[-158.]
# global_step=135163, episodic_return=[-175.]
# global_step=135297, episodic_return=[-133.]
# global_step=135510, episodic_return=[-212.]
# global_step=135653, episodic_return=[-142.]
# global_step=135769, episodic_return=[-115.]
# global_step=135929, episodic_return=[-159.]
# global_step=136132, episodic_return=[-202.]
# global_step=136283, episodic_return=[-150.]
# global_step=136396, episodic_return=[-112.]
# global_step=136498, episodic_return=[-101.]
# global_step=136672, episodic_return=[-173.]
# global_step=136803, episodic_return=[-130.]
# global_step=137009, episodic_return=[-205.]
# global_step=137212, episodic_return=[-202.]
# global_step=137367, episodic_return=[-154.]
# global_step=137504, episodic_return=[-136.]
# global_step=137606, episodic_return=[-101.]
# global_step=137712, episodic_return=[-105.]
# global_step=137847, episodic_return=[-134.]
# global_step=137930, episodic_return=[-82.]
# global_step=138093, episodic_return=[-162.]
# global_step=138203, episodic_return=[-109.]
# global_step=138362, episodic_return=[-158.]
# global_step=138505, episodic_return=[-142.]
# global_step=138622, episodic_return=[-116.]
# global_step=138752, episodic_return=[-129.]
# global_step=138966, episodic_return=[-213.]
# global_step=139080, episodic_return=[-113.]
# global_step=139196, episodic_return=[-115.]
# global_step=139320, episodic_return=[-123.]
# global_step=139430, episodic_return=[-109.]
# global_step=139562, episodic_return=[-131.]
# global_step=139716, episodic_return=[-153.]
# global_step=139812, episodic_return=[-95.]
# global_step=139941, episodic_return=[-128.]
# global_step=140083, episodic_return=[-141.]
# global_step=140274, episodic_return=[-190.]
# global_step=140380, episodic_return=[-105.]
# global_step=140494, episodic_return=[-113.]
# global_step=140634, episodic_return=[-139.]
# global_step=140731, episodic_return=[-96.]
# global_step=140866, episodic_return=[-134.]
# global_step=141032, episodic_return=[-165.]
# global_step=141290, episodic_return=[-257.]
# global_step=141415, episodic_return=[-124.]
# global_step=141593, episodic_return=[-177.]
# global_step=141765, episodic_return=[-171.]
# global_step=141946, episodic_return=[-180.]
# global_step=142075, episodic_return=[-128.]
# global_step=142218, episodic_return=[-142.]
# global_step=142351, episodic_return=[-132.]
# global_step=142484, episodic_return=[-132.]
# global_step=142614, episodic_return=[-129.]
# global_step=142712, episodic_return=[-97.]
# global_step=142888, episodic_return=[-175.]
# global_step=143066, episodic_return=[-177.]
# global_step=143195, episodic_return=[-128.]
# global_step=143347, episodic_return=[-151.]
# global_step=143515, episodic_return=[-167.]
# global_step=143643, episodic_return=[-127.]
# global_step=143763, episodic_return=[-119.]
# global_step=143869, episodic_return=[-105.]
# global_step=143991, episodic_return=[-121.]
# global_step=144154, episodic_return=[-162.]
# global_step=144285, episodic_return=[-130.]
# global_step=144419, episodic_return=[-133.]
# global_step=144549, episodic_return=[-129.]
# global_step=144748, episodic_return=[-198.]
# global_step=144904, episodic_return=[-155.]
# global_step=145003, episodic_return=[-98.]
# global_step=145142, episodic_return=[-138.]
# global_step=145318, episodic_return=[-175.]
# global_step=145423, episodic_return=[-104.]
# global_step=145629, episodic_return=[-205.]
# global_step=145735, episodic_return=[-105.]
# global_step=145864, episodic_return=[-128.]
# global_step=145983, episodic_return=[-118.]
# global_step=146097, episodic_return=[-113.]
# global_step=146276, episodic_return=[-178.]
# global_step=146418, episodic_return=[-141.]
# global_step=146545, episodic_return=[-126.]
# global_step=146686, episodic_return=[-140.]
# global_step=146836, episodic_return=[-149.]
# global_step=147019, episodic_return=[-182.]
# global_step=147133, episodic_return=[-113.]
# global_step=147243, episodic_return=[-109.]
# global_step=147400, episodic_return=[-156.]
# global_step=147541, episodic_return=[-140.]
# global_step=147687, episodic_return=[-145.]
# global_step=147783, episodic_return=[-95.]
# global_step=147944, episodic_return=[-160.]
# global_step=148079, episodic_return=[-134.]
# global_step=148206, episodic_return=[-126.]
# global_step=148322, episodic_return=[-115.]
# global_step=148466, episodic_return=[-143.]
# global_step=148585, episodic_return=[-118.]
# global_step=148718, episodic_return=[-132.]
# global_step=148859, episodic_return=[-140.]
# global_step=148997, episodic_return=[-137.]
# global_step=149173, episodic_return=[-175.]
# global_step=149373, episodic_return=[-199.]
# global_step=149503, episodic_return=[-129.]
# global_step=149617, episodic_return=[-113.]
# global_step=149772, episodic_return=[-154.]
# global_step=149899, episodic_return=[-126.]
# global_step=150018, episodic_return=[-118.]
# global_step=150108, episodic_return=[-89.]
# global_step=150225, episodic_return=[-116.]
# global_step=150367, episodic_return=[-141.]
# global_step=150469, episodic_return=[-101.]
# global_step=150969, episodic_return=[-500.]
# global_step=151103, episodic_return=[-133.]
# global_step=151603, episodic_return=[-500.]
# global_step=151707, episodic_return=[-103.]
# global_step=151801, episodic_return=[-93.]
# global_step=151920, episodic_return=[-118.]
# global_step=152031, episodic_return=[-110.]
# global_step=152163, episodic_return=[-131.]
# global_step=152319, episodic_return=[-155.]
# global_step=152437, episodic_return=[-117.]
# global_step=152556, episodic_return=[-118.]
# global_step=152691, episodic_return=[-134.]
# global_step=152833, episodic_return=[-141.]
# global_step=152995, episodic_return=[-161.]
# global_step=153106, episodic_return=[-110.]
# global_step=153254, episodic_return=[-147.]
# global_step=153363, episodic_return=[-108.]
# global_step=153497, episodic_return=[-133.]
# global_step=153644, episodic_return=[-146.]
# global_step=153820, episodic_return=[-175.]
# global_step=153958, episodic_return=[-137.]
# global_step=154090, episodic_return=[-131.]
# global_step=154236, episodic_return=[-145.]
# global_step=154329, episodic_return=[-92.]
# global_step=154482, episodic_return=[-152.]
# global_step=154623, episodic_return=[-140.]
# global_step=154730, episodic_return=[-106.]
# global_step=154858, episodic_return=[-127.]
# global_step=155011, episodic_return=[-152.]
# global_step=155170, episodic_return=[-158.]
# global_step=155273, episodic_return=[-102.]
# global_step=155422, episodic_return=[-148.]
# global_step=155570, episodic_return=[-147.]
# global_step=155685, episodic_return=[-114.]
# global_step=155824, episodic_return=[-138.]
# global_step=155962, episodic_return=[-137.]
# global_step=156087, episodic_return=[-124.]
# global_step=156316, episodic_return=[-228.]
# global_step=156463, episodic_return=[-146.]
# global_step=156561, episodic_return=[-97.]
# global_step=156678, episodic_return=[-116.]
# global_step=156798, episodic_return=[-119.]
# global_step=156939, episodic_return=[-140.]
# global_step=157049, episodic_return=[-109.]
# global_step=157190, episodic_return=[-140.]
# global_step=157318, episodic_return=[-127.]
# global_step=157487, episodic_return=[-168.]
# global_step=157657, episodic_return=[-169.]
# global_step=157793, episodic_return=[-135.]
# global_step=157887, episodic_return=[-93.]
# global_step=157998, episodic_return=[-110.]
# global_step=158124, episodic_return=[-125.]
# global_step=158245, episodic_return=[-120.]
# global_step=158366, episodic_return=[-120.]
# global_step=158505, episodic_return=[-138.]
# global_step=158646, episodic_return=[-140.]
# global_step=158752, episodic_return=[-105.]
# global_step=158881, episodic_return=[-128.]
# global_step=158991, episodic_return=[-109.]
# global_step=159095, episodic_return=[-103.]
# global_step=159218, episodic_return=[-122.]
# global_step=159342, episodic_return=[-123.]
# global_step=159471, episodic_return=[-128.]
# global_step=159579, episodic_return=[-107.]
# global_step=159700, episodic_return=[-120.]
# global_step=159852, episodic_return=[-151.]
# global_step=159974, episodic_return=[-121.]
# global_step=160098, episodic_return=[-123.]
# global_step=160224, episodic_return=[-125.]
# global_step=160331, episodic_return=[-106.]
# global_step=160496, episodic_return=[-164.]
# global_step=160615, episodic_return=[-118.]
# global_step=160730, episodic_return=[-114.]
# global_step=160853, episodic_return=[-122.]
# global_step=160944, episodic_return=[-90.]
# global_step=161080, episodic_return=[-135.]
# global_step=161171, episodic_return=[-90.]
# global_step=161305, episodic_return=[-133.]
# global_step=161429, episodic_return=[-123.]
# global_step=161579, episodic_return=[-149.]
# global_step=161699, episodic_return=[-119.]
# global_step=161840, episodic_return=[-140.]
# global_step=161978, episodic_return=[-137.]
# global_step=162109, episodic_return=[-130.]
# global_step=162248, episodic_return=[-138.]
# global_step=162351, episodic_return=[-102.]
# global_step=162496, episodic_return=[-144.]
# global_step=162611, episodic_return=[-114.]
# global_step=162815, episodic_return=[-203.]
# global_step=162961, episodic_return=[-145.]
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-729.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-729.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-729.mp4
# global_step=163080, episodic_return=[-118.]
# global_step=163179, episodic_return=[-98.]
# global_step=163284, episodic_return=[-104.]
# global_step=163396, episodic_return=[-111.]
# global_step=163499, episodic_return=[-102.]
# global_step=163600, episodic_return=[-100.]
# global_step=163746, episodic_return=[-145.]
# global_step=163876, episodic_return=[-129.]
# global_step=163984, episodic_return=[-107.]
# global_step=164102, episodic_return=[-117.]
# global_step=164204, episodic_return=[-101.]
# global_step=164492, episodic_return=[-287.]
# global_step=164588, episodic_return=[-95.]
# global_step=164697, episodic_return=[-108.]
# global_step=164827, episodic_return=[-129.]
# global_step=164945, episodic_return=[-117.]
# global_step=165053, episodic_return=[-107.]
# global_step=165147, episodic_return=[-93.]
# global_step=165259, episodic_return=[-111.]
# global_step=165379, episodic_return=[-119.]
# global_step=165472, episodic_return=[-92.]
# global_step=165588, episodic_return=[-115.]
# global_step=165712, episodic_return=[-123.]
# global_step=165818, episodic_return=[-105.]
# global_step=166318, episodic_return=[-500.]
# global_step=166414, episodic_return=[-95.]
# global_step=166519, episodic_return=[-104.]
# global_step=166637, episodic_return=[-117.]
# global_step=166761, episodic_return=[-123.]
# global_step=166875, episodic_return=[-113.]
# global_step=167016, episodic_return=[-140.]
# global_step=167120, episodic_return=[-103.]
# global_step=167218, episodic_return=[-97.]
# global_step=167353, episodic_return=[-134.]
# global_step=167495, episodic_return=[-141.]
# global_step=167611, episodic_return=[-115.]
# global_step=167734, episodic_return=[-122.]
# global_step=167879, episodic_return=[-144.]
# global_step=168024, episodic_return=[-144.]
# global_step=168137, episodic_return=[-112.]
# global_step=168264, episodic_return=[-126.]
# global_step=168370, episodic_return=[-105.]
# global_step=168492, episodic_return=[-121.]
# global_step=168595, episodic_return=[-102.]
# global_step=168682, episodic_return=[-86.]
# global_step=168782, episodic_return=[-99.]
# global_step=168921, episodic_return=[-138.]
# global_step=169054, episodic_return=[-132.]
# global_step=169204, episodic_return=[-149.]
# global_step=169330, episodic_return=[-125.]
# global_step=169458, episodic_return=[-127.]
# global_step=169586, episodic_return=[-127.]
# global_step=169731, episodic_return=[-144.]
# global_step=169822, episodic_return=[-90.]
# global_step=169965, episodic_return=[-142.]
# global_step=170084, episodic_return=[-118.]
# global_step=170203, episodic_return=[-118.]
# global_step=170320, episodic_return=[-116.]
# global_step=170409, episodic_return=[-88.]
# global_step=170535, episodic_return=[-125.]
# global_step=170639, episodic_return=[-103.]
# global_step=170773, episodic_return=[-133.]
# global_step=170869, episodic_return=[-95.]
# global_step=170952, episodic_return=[-82.]
# global_step=171060, episodic_return=[-107.]
# global_step=171176, episodic_return=[-115.]
# global_step=171289, episodic_return=[-112.]
# global_step=171400, episodic_return=[-110.]
# global_step=171515, episodic_return=[-114.]
# global_step=171633, episodic_return=[-117.]
# global_step=171720, episodic_return=[-86.]
# global_step=171854, episodic_return=[-133.]
# global_step=172225, episodic_return=[-370.]
# global_step=172334, episodic_return=[-108.]
# global_step=172481, episodic_return=[-146.]
# global_step=172667, episodic_return=[-185.]
# global_step=172805, episodic_return=[-137.]
# global_step=172896, episodic_return=[-90.]
# global_step=172999, episodic_return=[-102.]
# global_step=173114, episodic_return=[-114.]
# global_step=173235, episodic_return=[-120.]
# global_step=173333, episodic_return=[-97.]
# global_step=173447, episodic_return=[-113.]
# global_step=173537, episodic_return=[-89.]
# global_step=173662, episodic_return=[-124.]
# global_step=173781, episodic_return=[-118.]
# global_step=173912, episodic_return=[-130.]
# global_step=174011, episodic_return=[-98.]
# global_step=174130, episodic_return=[-118.]
# global_step=174288, episodic_return=[-157.]
# global_step=174387, episodic_return=[-98.]
# global_step=174489, episodic_return=[-101.]
# global_step=174602, episodic_return=[-112.]
# global_step=174701, episodic_return=[-98.]
# global_step=174814, episodic_return=[-112.]
# global_step=174921, episodic_return=[-106.]
# global_step=175035, episodic_return=[-113.]
# global_step=175204, episodic_return=[-168.]
# global_step=175305, episodic_return=[-100.]
# global_step=175426, episodic_return=[-120.]
# global_step=175543, episodic_return=[-116.]
# global_step=175669, episodic_return=[-125.]
# global_step=175772, episodic_return=[-102.]
# global_step=175875, episodic_return=[-102.]
# global_step=175985, episodic_return=[-109.]
# global_step=176088, episodic_return=[-102.]
# global_step=176196, episodic_return=[-107.]
# global_step=176313, episodic_return=[-116.]
# global_step=176431, episodic_return=[-117.]
# global_step=176555, episodic_return=[-123.]
# global_step=176649, episodic_return=[-93.]
# global_step=176761, episodic_return=[-111.]
# global_step=176871, episodic_return=[-109.]
# global_step=176975, episodic_return=[-103.]
# global_step=177075, episodic_return=[-99.]
# global_step=177177, episodic_return=[-101.]
# global_step=177266, episodic_return=[-88.]
# global_step=177356, episodic_return=[-89.]
# global_step=177458, episodic_return=[-101.]
# global_step=177542, episodic_return=[-83.]
# global_step=177664, episodic_return=[-121.]
# global_step=177767, episodic_return=[-102.]
# global_step=177932, episodic_return=[-164.]
# global_step=178033, episodic_return=[-100.]
# global_step=178166, episodic_return=[-132.]
# global_step=178284, episodic_return=[-117.]
# global_step=178417, episodic_return=[-132.]
# global_step=178517, episodic_return=[-99.]
# global_step=178634, episodic_return=[-116.]
# global_step=178750, episodic_return=[-115.]
# global_step=178859, episodic_return=[-108.]
# global_step=178991, episodic_return=[-131.]
# global_step=179104, episodic_return=[-112.]
# global_step=179198, episodic_return=[-93.]
# global_step=179294, episodic_return=[-95.]
# global_step=179436, episodic_return=[-141.]
# global_step=179550, episodic_return=[-113.]
# global_step=179656, episodic_return=[-105.]
# global_step=179761, episodic_return=[-104.]
# global_step=179871, episodic_return=[-109.]
# global_step=180049, episodic_return=[-177.]
# global_step=180146, episodic_return=[-96.]
# global_step=180245, episodic_return=[-98.]
# global_step=180363, episodic_return=[-117.]
# global_step=180447, episodic_return=[-83.]
# global_step=180576, episodic_return=[-128.]
# global_step=180659, episodic_return=[-82.]
# global_step=180776, episodic_return=[-116.]
# global_step=180896, episodic_return=[-119.]
# global_step=181017, episodic_return=[-120.]
# global_step=181140, episodic_return=[-122.]
# global_step=181252, episodic_return=[-111.]
# global_step=181387, episodic_return=[-134.]
# global_step=181563, episodic_return=[-175.]
# global_step=181638, episodic_return=[-74.]
# global_step=181740, episodic_return=[-101.]
# global_step=181866, episodic_return=[-125.]
# global_step=181986, episodic_return=[-119.]
# global_step=182100, episodic_return=[-113.]
# global_step=182205, episodic_return=[-104.]
# global_step=182287, episodic_return=[-81.]
# global_step=182417, episodic_return=[-129.]
# global_step=182503, episodic_return=[-85.]
# global_step=182600, episodic_return=[-96.]
# global_step=182706, episodic_return=[-105.]
# global_step=182845, episodic_return=[-138.]
# global_step=182959, episodic_return=[-113.]
# global_step=183054, episodic_return=[-94.]
# global_step=183185, episodic_return=[-130.]
# global_step=183276, episodic_return=[-90.]
# global_step=183390, episodic_return=[-113.]
# global_step=183480, episodic_return=[-89.]
# global_step=183697, episodic_return=[-216.]
# global_step=183784, episodic_return=[-86.]
# global_step=183900, episodic_return=[-115.]
# global_step=184004, episodic_return=[-103.]
# global_step=184096, episodic_return=[-91.]
# global_step=184232, episodic_return=[-135.]
# global_step=184321, episodic_return=[-88.]
# global_step=184487, episodic_return=[-165.]
# global_step=184601, episodic_return=[-113.]
# global_step=184685, episodic_return=[-83.]
# global_step=184794, episodic_return=[-108.]
# global_step=184915, episodic_return=[-120.]
# global_step=185046, episodic_return=[-130.]
# global_step=185154, episodic_return=[-107.]
# global_step=185278, episodic_return=[-123.]
# global_step=185368, episodic_return=[-89.]
# global_step=185457, episodic_return=[-88.]
# global_step=185553, episodic_return=[-95.]
# global_step=185660, episodic_return=[-106.]
# global_step=185773, episodic_return=[-112.]
# global_step=185887, episodic_return=[-113.]
# global_step=185999, episodic_return=[-111.]
# global_step=186090, episodic_return=[-90.]
# global_step=186198, episodic_return=[-107.]
# global_step=186333, episodic_return=[-134.]
# global_step=186426, episodic_return=[-92.]
# global_step=186525, episodic_return=[-98.]
# global_step=186688, episodic_return=[-162.]
# global_step=186794, episodic_return=[-105.]
# global_step=186927, episodic_return=[-132.]
# global_step=187015, episodic_return=[-87.]
# global_step=187123, episodic_return=[-107.]
# global_step=187231, episodic_return=[-107.]
# global_step=187311, episodic_return=[-79.]
# global_step=187422, episodic_return=[-110.]
# global_step=187534, episodic_return=[-111.]
# global_step=187621, episodic_return=[-86.]
# global_step=187722, episodic_return=[-100.]
# global_step=187836, episodic_return=[-113.]
# global_step=187956, episodic_return=[-119.]
# global_step=188102, episodic_return=[-145.]
# global_step=188203, episodic_return=[-100.]
# global_step=188291, episodic_return=[-87.]
# global_step=188413, episodic_return=[-121.]
# global_step=188532, episodic_return=[-118.]
# global_step=188630, episodic_return=[-97.]
# global_step=188717, episodic_return=[-86.]
# global_step=188822, episodic_return=[-104.]
# global_step=188920, episodic_return=[-97.]
# global_step=189003, episodic_return=[-82.]
# global_step=189091, episodic_return=[-87.]
# global_step=189193, episodic_return=[-101.]
# global_step=189293, episodic_return=[-99.]
# global_step=189386, episodic_return=[-92.]
# global_step=189471, episodic_return=[-84.]
# global_step=189583, episodic_return=[-111.]
# global_step=189698, episodic_return=[-114.]
# global_step=189820, episodic_return=[-121.]
# global_step=189918, episodic_return=[-97.]
# global_step=190012, episodic_return=[-93.]
# global_step=190105, episodic_return=[-92.]
# global_step=190204, episodic_return=[-98.]
# global_step=190326, episodic_return=[-121.]
# global_step=190418, episodic_return=[-91.]
# global_step=190507, episodic_return=[-88.]
# global_step=190598, episodic_return=[-90.]
# global_step=190694, episodic_return=[-95.]
# global_step=190785, episodic_return=[-90.]
# global_step=190914, episodic_return=[-128.]
# global_step=190987, episodic_return=[-72.]
# global_step=191092, episodic_return=[-104.]
# global_step=191186, episodic_return=[-93.]
# global_step=191359, episodic_return=[-172.]
# global_step=191465, episodic_return=[-105.]
# global_step=191590, episodic_return=[-124.]
# global_step=191681, episodic_return=[-90.]
# global_step=191765, episodic_return=[-83.]
# global_step=191897, episodic_return=[-131.]
# global_step=192012, episodic_return=[-114.]
# global_step=192147, episodic_return=[-134.]
# global_step=192253, episodic_return=[-105.]
# global_step=192368, episodic_return=[-114.]
# global_step=192481, episodic_return=[-112.]
# global_step=192593, episodic_return=[-111.]
# global_step=192710, episodic_return=[-116.]
# global_step=192806, episodic_return=[-95.]
# global_step=192916, episodic_return=[-109.]
# global_step=193018, episodic_return=[-101.]
# global_step=193140, episodic_return=[-121.]
# global_step=193221, episodic_return=[-80.]
# global_step=193316, episodic_return=[-94.]
# global_step=193432, episodic_return=[-115.]
# global_step=193524, episodic_return=[-91.]
# global_step=193624, episodic_return=[-99.]
# global_step=193707, episodic_return=[-82.]
# global_step=193848, episodic_return=[-140.]
# global_step=193961, episodic_return=[-112.]
# global_step=194073, episodic_return=[-111.]
# global_step=194188, episodic_return=[-114.]
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-1000.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373/rl-video-episode-1000.mp4
# global_step=194278, episodic_return=[-89.]
# ...
# global_step=483720, episodic_return=[-112.]
# global_step=483803, episodic_return=[-82.]
# global_step=483886, episodic_return=[-82.]
# global_step=483981, episodic_return=[-94.]
# global_step=484056, episodic_return=[-74.]
# global_step=484145, episodic_return=[-88.]
# global_step=484243, episodic_return=[-97.]
# global_step=484334, episodic_return=[-90.]
# global_step=484417, episodic_return=[-82.]
# global_step=484505, episodic_return=[-87.]
# global_step=484589, episodic_return=[-83.]
# global_step=484680, episodic_return=[-90.]
# global_step=484763, episodic_return=[-82.]
# global_step=484858, episodic_return=[-94.]
# global_step=484959, episodic_return=[-100.]
# global_step=485043, episodic_return=[-83.]
# global_step=485182, episodic_return=[-138.]
# global_step=485282, episodic_return=[-99.]
# global_step=485367, episodic_return=[-84.]
# global_step=485465, episodic_return=[-97.]
# global_step=485539, episodic_return=[-73.]
# global_step=485644, episodic_return=[-104.]
# global_step=485731, episodic_return=[-86.]
# global_step=485793, episodic_return=[-61.]
# global_step=485894, episodic_return=[-100.]
# global_step=486057, episodic_return=[-162.]
# global_step=486136, episodic_return=[-78.]
# global_step=486226, episodic_return=[-89.]
# global_step=486316, episodic_return=[-89.]
# global_step=486411, episodic_return=[-94.]
# global_step=486497, episodic_return=[-85.]
# global_step=486590, episodic_return=[-92.]
# global_step=486688, episodic_return=[-97.]
# global_step=486779, episodic_return=[-90.]
# global_step=486872, episodic_return=[-92.]
# global_step=486948, episodic_return=[-75.]
# global_step=487058, episodic_return=[-109.]
# global_step=487139, episodic_return=[-80.]
# global_step=487236, episodic_return=[-96.]
# global_step=487319, episodic_return=[-82.]
# global_step=487459, episodic_return=[-139.]
# global_step=487528, episodic_return=[-68.]
# global_step=487598, episodic_return=[-69.]
# global_step=487697, episodic_return=[-98.]
# global_step=487786, episodic_return=[-88.]
# global_step=487868, episodic_return=[-81.]
# global_step=487944, episodic_return=[-75.]
# global_step=488015, episodic_return=[-70.]
# global_step=488109, episodic_return=[-93.]
# global_step=488184, episodic_return=[-74.]
# global_step=488260, episodic_return=[-75.]
# global_step=488343, episodic_return=[-82.]
# global_step=488434, episodic_return=[-90.]
# global_step=488517, episodic_return=[-82.]
# global_step=488617, episodic_return=[-99.]
# global_step=488700, episodic_return=[-82.]
# global_step=488791, episodic_return=[-90.]
# global_step=488889, episodic_return=[-97.]
# global_step=488981, episodic_return=[-91.]
# global_step=489060, episodic_return=[-78.]
# global_step=489154, episodic_return=[-93.]
# global_step=489254, episodic_return=[-99.]
# global_step=489350, episodic_return=[-95.]
# global_step=489465, episodic_return=[-114.]
# global_step=489544, episodic_return=[-78.]
# global_step=489834, episodic_return=[-289.]
# global_step=489935, episodic_return=[-100.]
# global_step=490024, episodic_return=[-88.]
# global_step=490109, episodic_return=[-84.]
# global_step=490200, episodic_return=[-90.]
# global_step=490283, episodic_return=[-82.]
# global_step=490394, episodic_return=[-110.]
# global_step=490465, episodic_return=[-70.]
# global_step=490550, episodic_return=[-84.]
# global_step=490633, episodic_return=[-82.]
# global_step=490712, episodic_return=[-78.]
# global_step=490803, episodic_return=[-90.]
# global_step=490926, episodic_return=[-122.]
# global_step=491004, episodic_return=[-77.]
# global_step=491110, episodic_return=[-105.]
# global_step=491186, episodic_return=[-75.]
# global_step=491274, episodic_return=[-87.]
# global_step=491345, episodic_return=[-70.]
# global_step=491443, episodic_return=[-97.]
# global_step=491527, episodic_return=[-83.]
# global_step=491607, episodic_return=[-79.]
# global_step=491683, episodic_return=[-75.]
# global_step=491787, episodic_return=[-103.]
# global_step=491870, episodic_return=[-82.]
# global_step=491959, episodic_return=[-88.]
# global_step=492038, episodic_return=[-78.]
# global_step=492111, episodic_return=[-72.]
# global_step=492181, episodic_return=[-69.]
# global_step=492275, episodic_return=[-93.]
# global_step=492360, episodic_return=[-84.]
# global_step=492439, episodic_return=[-78.]
# global_step=492518, episodic_return=[-78.]
# global_step=492626, episodic_return=[-107.]
# global_step=492695, episodic_return=[-68.]
# global_step=492791, episodic_return=[-95.]
# global_step=492887, episodic_return=[-95.]
# global_step=492984, episodic_return=[-96.]
# global_step=493100, episodic_return=[-115.]
# global_step=493170, episodic_return=[-69.]
# global_step=493260, episodic_return=[-89.]
# global_step=493334, episodic_return=[-73.]
# global_step=493427, episodic_return=[-92.]
# global_step=493528, episodic_return=[-100.]
# global_step=493650, episodic_return=[-121.]
# global_step=493728, episodic_return=[-77.]
# global_step=493814, episodic_return=[-85.]
# global_step=493903, episodic_return=[-88.]
# global_step=493987, episodic_return=[-83.]
# global_step=494075, episodic_return=[-87.]
# global_step=494157, episodic_return=[-81.]
# global_step=494242, episodic_return=[-84.]
# global_step=494324, episodic_return=[-81.]
# global_step=494406, episodic_return=[-81.]
# global_step=494477, episodic_return=[-70.]
# global_step=494572, episodic_return=[-94.]
# global_step=494660, episodic_return=[-87.]
# global_step=494732, episodic_return=[-71.]
# global_step=494810, episodic_return=[-77.]
# global_step=494903, episodic_return=[-92.]
# global_step=494977, episodic_return=[-73.]
# global_step=495065, episodic_return=[-87.]
# global_step=495148, episodic_return=[-82.]
# global_step=495231, episodic_return=[-82.]
# global_step=495300, episodic_return=[-68.]
# global_step=495394, episodic_return=[-93.]
# global_step=495474, episodic_return=[-79.]
# global_step=495538, episodic_return=[-63.]
# global_step=495608, episodic_return=[-69.]
# global_step=495694, episodic_return=[-85.]
# global_step=495787, episodic_return=[-92.]
# global_step=495865, episodic_return=[-77.]
# global_step=495964, episodic_return=[-98.]
# global_step=496041, episodic_return=[-76.]
# global_step=496144, episodic_return=[-102.]
# global_step=496239, episodic_return=[-94.]
# global_step=496324, episodic_return=[-84.]
# global_step=496419, episodic_return=[-94.]
# global_step=496494, episodic_return=[-74.]
# global_step=496576, episodic_return=[-81.]
# global_step=496658, episodic_return=[-81.]
# global_step=496728, episodic_return=[-69.]
# global_step=496839, episodic_return=[-110.]
# global_step=496931, episodic_return=[-91.]
# global_step=497028, episodic_return=[-96.]
# global_step=497104, episodic_return=[-75.]
# global_step=497182, episodic_return=[-77.]
# global_step=497277, episodic_return=[-94.]
# global_step=497378, episodic_return=[-100.]
# global_step=497486, episodic_return=[-107.]
# global_step=497554, episodic_return=[-67.]
# global_step=497630, episodic_return=[-75.]
# global_step=497717, episodic_return=[-86.]
# global_step=497795, episodic_return=[-77.]
# global_step=497868, episodic_return=[-72.]
# global_step=497957, episodic_return=[-88.]
# global_step=498032, episodic_return=[-74.]
# global_step=498112, episodic_return=[-79.]
# global_step=498229, episodic_return=[-116.]
# global_step=498315, episodic_return=[-85.]
# global_step=498379, episodic_return=[-63.]
# global_step=498465, episodic_return=[-85.]
# global_step=498538, episodic_return=[-72.]
# global_step=498629, episodic_return=[-90.]
# global_step=498705, episodic_return=[-75.]
# global_step=498802, episodic_return=[-96.]
# global_step=498913, episodic_return=[-110.]
# global_step=498976, episodic_return=[-62.]
# global_step=499051, episodic_return=[-74.]
# global_step=499124, episodic_return=[-72.]
# global_step=499200, episodic_return=[-75.]
# global_step=499286, episodic_return=[-85.]
# global_step=499372, episodic_return=[-85.]
# global_step=499454, episodic_return=[-81.]
# global_step=499528, episodic_return=[-73.]
# global_step=499605, episodic_return=[-76.]
# global_step=499694, episodic_return=[-88.]
# global_step=499794, episodic_return=[-99.]
# global_step=499913, episodic_return=[-118.]
# global_step=499977, episodic_return=[-63.]
# Model Saved
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-0.mp4
# eval_episode=0, episodic_return=[-75.]
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-1.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-1.mp4
# eval_episode=1, episodic_return=[-101.]
# eval_episode=2, episodic_return=[-76.]
# eval_episode=3, episodic_return=[-81.]
# eval_episode=4, episodic_return=[-99.]
# eval_episode=5, episodic_return=[-75.]
# eval_episode=6, episodic_return=[-90.]
# eval_episode=7, episodic_return=[-69.]
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-8.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-8.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-8.mp4
# eval_episode=8, episodic_return=[-99.]
# eval_episode=9, episodic_return=[-82.]
# eval_episode=10, episodic_return=[-86.]
# eval_episode=11, episodic_return=[-63.]
# eval_episode=12, episodic_return=[-96.]
# eval_episode=13, episodic_return=[-92.]
# eval_episode=14, episodic_return=[-63.]
# eval_episode=15, episodic_return=[-78.]
# eval_episode=16, episodic_return=[-77.]
# eval_episode=17, episodic_return=[-79.]
# eval_episode=18, episodic_return=[-86.]
# eval_episode=19, episodic_return=[-92.]
# eval_episode=20, episodic_return=[-69.]
# eval_episode=21, episodic_return=[-80.]
# eval_episode=22, episodic_return=[-84.]
# eval_episode=23, episodic_return=[-63.]
# eval_episode=24, episodic_return=[-115.]
# eval_episode=25, episodic_return=[-68.]
# eval_episode=26, episodic_return=[-69.]
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-27.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-27.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-27.mp4
# eval_episode=27, episodic_return=[-74.]
# eval_episode=28, episodic_return=[-80.]
# eval_episode=29, episodic_return=[-83.]
# eval_episode=30, episodic_return=[-82.]
# eval_episode=31, episodic_return=[-76.]
# eval_episode=32, episodic_return=[-103.]
# eval_episode=33, episodic_return=[-70.]
# eval_episode=34, episodic_return=[-75.]
# eval_episode=35, episodic_return=[-91.]
# eval_episode=36, episodic_return=[-83.]
# eval_episode=37, episodic_return=[-78.]
# eval_episode=38, episodic_return=[-108.]
# eval_episode=39, episodic_return=[-76.]
# eval_episode=40, episodic_return=[-100.]
# eval_episode=41, episodic_return=[-126.]
# eval_episode=42, episodic_return=[-85.]
# eval_episode=43, episodic_return=[-102.]
# eval_episode=44, episodic_return=[-92.]
# eval_episode=45, episodic_return=[-85.]
# eval_episode=46, episodic_return=[-143.]
# eval_episode=47, episodic_return=[-89.]
# eval_episode=48, episodic_return=[-95.]
# eval_episode=49, episodic_return=[-89.]
# eval_episode=50, episodic_return=[-82.]
# eval_episode=51, episodic_return=[-102.]
# eval_episode=52, episodic_return=[-104.]
# eval_episode=53, episodic_return=[-81.]
# eval_episode=54, episodic_return=[-85.]
# eval_episode=55, episodic_return=[-102.]
# eval_episode=56, episodic_return=[-86.]
# eval_episode=57, episodic_return=[-62.]
# eval_episode=58, episodic_return=[-92.]
# eval_episode=59, episodic_return=[-89.]
# eval_episode=60, episodic_return=[-103.]
# eval_episode=61, episodic_return=[-93.]
# eval_episode=62, episodic_return=[-70.]
# eval_episode=63, episodic_return=[-86.]
# Moviepy - Building video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-64.mp4.
# Moviepy - Writing video /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-64.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/video/Acrobot-v1__1__1699875373-eval/rl-video-episode-64.mp4
# eval_episode=64, episodic_return=[-82.]
# eval_episode=65, episodic_return=[-79.]
# eval_episode=66, episodic_return=[-86.]
# eval_episode=67, episodic_return=[-87.]
# eval_episode=68, episodic_return=[-94.]
# eval_episode=69, episodic_return=[-87.]
# eval_episode=70, episodic_return=[-82.]
# eval_episode=71, episodic_return=[-75.]
# eval_episode=72, episodic_return=[-64.]
# eval_episode=73, episodic_return=[-75.]
# eval_episode=74, episodic_return=[-74.]
# eval_episode=75, episodic_return=[-71.]
# eval_episode=76, episodic_return=[-118.]
# eval_episode=77, episodic_return=[-75.]
# eval_episode=78, episodic_return=[-90.]
# eval_episode=79, episodic_return=[-69.]
# eval_episode=80, episodic_return=[-69.]
# eval_episode=81, episodic_return=[-101.]
# eval_episode=82, episodic_return=[-95.]
# eval_episode=83, episodic_return=[-72.]
# eval_episode=84, episodic_return=[-69.]
# eval_episode=85, episodic_return=[-121.]
# eval_episode=86, episodic_return=[-69.]
# eval_episode=87, episodic_return=[-182.]
# eval_episode=88, episodic_return=[-90.]
# eval_episode=89, episodic_return=[-92.]
# eval_episode=90, episodic_return=[-70.]
# eval_episode=91, episodic_return=[-99.]
# eval_episode=92, episodic_return=[-70.]
# eval_episode=93, episodic_return=[-81.]
# eval_episode=94, episodic_return=[-68.]
# eval_episode=95, episodic_return=[-73.]
# eval_episode=96, episodic_return=[-94.]
# eval_episode=97, episodic_return=[-74.]
# eval_episode=98, episodic_return=[-77.]
# eval_episode=99, episodic_return=[-90.]
# VBox(children=(Label(value='4.383 MB of 4.383 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>charts/SPS</td><td>▁▃▅▇▇████████▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▅▅▅▅▅▅▅▅▅▅</td></tr><tr><td>charts/episodic_length</td><td>█▅▄▄▂▃▂▂▂▃▂▂▂▁▃▂▁▂▁▂▁▂▁▁▁▁▁▁▁▂▁▂▁▃▁▂▁▁▂▂</td></tr><tr><td>charts/episodic_return</td><td>▁▄▅▅▇▆▇▇▇▆▇▇▇█▆▇█▇█▇█▇███████▇█▇█▆█▇██▇▇</td></tr><tr><td>charts/epsilon</td><td>█▇▆▅▅▄▄▃▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/episodic_return</td><td>▇▇▇█▅▄▇▆█▆█▇▆█▅▂▄▃▆▄▆▆▃▅▃▅▅▄▇▇▁▅▃▇█▅▄▆▄▅</td></tr><tr><td>global_step</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>losses/q_values</td><td>█▆▃▁▁▂▃▄▄▄▃▄▃▄▃▄▃▄▄▃▄▃▃▄▃▄▄▄▃▄▄▄▃▄▃▄▄▄▄▄</td></tr><tr><td>losses/td_loss</td><td>▁▂▂▅█▅▄▃▂▃▂▃▃▃▃▃▃▃▃▂▃▃▃▄▃▄▄▄▃▃▃▃▃▄▄▄▄▃▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>charts/SPS</td><td>1173.0</td></tr><tr><td>charts/episodic_length</td><td>64.0</td></tr><tr><td>charts/episodic_return</td><td>-63.0</td></tr><tr><td>charts/epsilon</td><td>0.05</td></tr><tr><td>eval/episodic_return</td><td>-90.0</td></tr><tr><td>global_step</td><td>499977</td></tr><tr><td>losses/q_values</td><td>-32.39475</td></tr><tr><td>losses/td_loss</td><td>1.19261</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Acrobot-v1__1__1699875373</strong> at: <a href='https://wandb.ai/chkda/rl-algos-benchmark/runs/a8xpkqlw' target="_blank">https://wandb.ai/chkda/rl-algos-benchmark/runs/a8xpkqlw</a><br/> View job at <a href='https://wandb.ai/chkda/rl-algos-benchmark/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjExNTIyNzIxOQ==/version_details/v3' target="_blank">https://wandb.ai/chkda/rl-algos-benchmark/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjExNTIyNzIxOQ==/version_details/v3</a><br/>Synced 5 W&B file(s), 19 media file(s), 2 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231113_113613-a8xpkqlw/logs</code>
