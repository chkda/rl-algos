# %%
# !apt-get install -y \
#     libgl1-mesa-dev \
#     libgl1-mesa-glx \
#     libglew-dev \
#     libosmesa6-dev \
#     software-properties-common

# !apt-get install -y patchelf

# !apt-get update --fix-missing
# !pip install stable-baselines3
# !pip install mujoco
# !pip install  --upgrade gymnasium==0.29
# !pip install free-mujoco-py

# %%
import os
import time
import wandb
import random
import numpy as np
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
from stable_baselines3.common.buffers import ReplayBuffer

# %%
def make_env(env_id, seed, idx, capture_video, run_name):
    def thunk():
        if capture_video and idx == 0:
            env = gym.make(env_id, render_mode="rgb_array")
            env = gym.wrappers.RecordVideo(env, f"videos/{run_name}")
        else:
            env = gym.make(env_id)

        env = gym.wrappers.RecordEpisodeStatistics(env)
        env.action_space.seed(seed)
        env.observation_space.seed(seed)
        return env

    return thunk

# %%
class QNetwork(nn.Module):

    def __init__(self, env):
        super().__init__()
        self.fc1 = nn.Linear(np.array(env.single_observation_space.shape).prod() +  np.prod(env.single_action_space.shape), 256)
        self.fc2 = nn.Linear(256, 256)
        self.fc3 = nn.Linear(256, 1)

    def forward(self, x, a):
        x = torch.cat([x,a], 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)

        return x

# %%
class Actor(nn.Module):

    def __init__(self, env):
        super().__init__()
        self.fc1 = nn.Linear(np.array(env.single_observation_space.shape).prod(), 256)
        self.fc2 = nn.Linear(256, 256)
        self.fc_mu = nn.Linear(256, np.prod(env.single_action_space.shape))
        self.register_buffer(
            "action_scale", torch.tensor((env.action_space.high - env.action_space.low) / 2.0, dtype = torch.float32)
        )

        self.register_buffer(
            "action_bias", torch.tensor((env.action_space.high + env.action_space.low)/ 2.0, dtype =torch.float32 )
        )

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = torch.tanh(self.fc_mu(x))
        return x * self.action_scale + self.action_bias

# %%
def train(env_id,
          seed,
          total_timesteps,
          learning_rate,
          buffer_size,
          gamma,
          tau,
          batch_size,
          policy_noise ,
          exploration_noise,
          learning_starts,
          policy_frequency,
          noise_clip):

    run_name = f"{env_id}__{seed}__{int(time.time())}"
    wandb.init(
        project="td3-mujoco-benchmark",
        config={
            "env":env_id,
            "seed":seed,
            "timesteps":total_timesteps,
            "buffer_size":buffer_size,
            "gamma":gamma,
            "tau":tau,
            "batch_size":batch_size,
            "policy_noise":policy_noise,
            "exploration_noise":exploration_noise,
            "learning_starts":learning_starts,
            "policy_frequency":policy_frequency,
            "noise_clip":noise_clip,
        },
        sync_tensorboard=True,
        monitor_gym=True,
        name=run_name
    )
    writer = SummaryWriter(f"runs/{run_name}")


    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    envs = gym.vector.SyncVectorEnv([make_env(env_id, seed, 0, True, run_name)])

    actor = Actor(envs).to(device)
    target_actor = Actor(envs).to(device)
    qf1 = QNetwork(envs).to(device)
    qf2 = QNetwork(envs).to(device)
    qf1_target = QNetwork(envs).to(device)
    qf2_target = QNetwork(envs).to(device)

    target_actor.load_state_dict(actor.state_dict())
    qf1_target.load_state_dict(qf1.state_dict())
    qf2_target.load_state_dict(qf2.state_dict())
    q_optimiser = optim.Adam(list(qf1.parameters()) + list(qf2.parameters()), lr=learning_rate)
    actor_optimiser = optim.Adam(actor.parameters(), lr=learning_rate)


    envs.single_observation_space.dtype = np.float32
    rb = ReplayBuffer(
        buffer_size,
        envs.single_observation_space,
        envs.single_action_space,
        device,
        handle_timeout_termination=False,
    )

    start_time = time.time()

    obs, _ = envs.reset(seed=seed)
    for global_step in range(total_timesteps):

        if global_step < learning_starts:
            actions = np.array([envs.single_action_space.sample() for _ in range(envs.num_envs)])
            # print("GlobalStep:",global_step,":Actions:", actions)
        else:
            with torch.no_grad():
                actions = actor(torch.Tensor(obs).to(device))
                actions += torch.normal(0, actor.action_scale * exploration_noise)
                # print("GlobalStep:",global_step,":Unclippe Actions:", actions)
                actions = actions.cpu().numpy()
                # print("GlobalStep:",global_step,":Actions:", actions)

        next_obs, rewards, terminated, truncated, infos = envs.step(actions)

        if "final_info" in infos:
            for info in infos["final_info"]:
                print(f"global_step={global_step} episodic_return={info['episode']['r']}")
                writer.add_scalar("charts/episodic_return", info["episode"]["r"], global_step)
                writer.add_scalar("charts/episodic_length", info["episode"]["l"], global_step)
                break


        real_next_obs = next_obs.copy()

        for idx, d in enumerate(truncated):
            if d:
                real_next_obs[idx] = infos["final_observation"][idx]

        rb.add(obs, real_next_obs, actions, rewards, terminated, infos)

        obs = next_obs

        if global_step > learning_starts:
            data = rb.sample(batch_size)
            with torch.no_grad():
                clipped_noise = (torch.randn_like(data.actions, device=device) * policy_noise).clamp(
                    -noise_clip, noise_clip
                ) * target_actor.action_scale

                next_state_actions = (target_actor(data.next_observations) + clipped_noise).clamp(
                    envs.single_action_space.low[0], envs.single_action_space.high[0]
                )

                qf1_next_target = qf1_target(data.next_observations, next_state_actions)
                qf2_next_target = qf2_target(data.next_observations, next_state_actions)
                min_qf_next_state_target = torch.min(qf1_next_target, qf2_next_target)
                next_q_value = data.rewards.flatten() + (1 - data.dones.flatten()) * gamma * (min_qf_next_state_target).view(-1)

            qf1_a_values = qf1(data.observations, data.actions).view(-1)
            qf2_a_values = qf2(data.observations, data.actions).view(-1)
            qf1_loss = F.mse_loss(qf1_a_values, next_q_value)
            qf2_loss = F.mse_loss(qf2_a_values, next_q_value)
            qf_loss = qf1_loss + qf2_loss

            q_optimiser.zero_grad()
            qf_loss.backward()
            q_optimiser.step()

            if global_step % policy_frequency == 0:
                actor_loss = -qf1(data.observations, actor(data.observations)).mean()
                actor_optimiser.zero_grad()
                actor_loss.backward()
                actor_optimiser.step()

                for param, target_param in zip(actor.parameters(), target_actor.parameters()):
                    target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
                for param, target_param in zip(qf1.parameters(), qf1_target.parameters()):
                    target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
                for param, target_param in zip(qf2.parameters(), qf2_target.parameters()):
                    target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)

            if global_step % 100 == 0:
                writer.add_scalar("losses/qf1_values", qf1_a_values.mean().item(), global_step)
                writer.add_scalar("losses/qf2_values", qf2_a_values.mean().item(), global_step)
                writer.add_scalar("losses/qf1_loss", qf1_loss.item(), global_step)
                writer.add_scalar("losses/qf2_loss", qf2_loss.item(), global_step)
                writer.add_scalar("losses/qf_loss", qf_loss.item() / 2.0, global_step)
                writer.add_scalar("losses/actor_loss", actor_loss.item(), global_step)
                writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)

    envs.close()
    writer.close()
    wandb.finish()

# %%
env = {"hopper":"Hopper-v2","humanoid":"Humanoid-v2","halfCheetah":"HalfCheetah-v2","ant":"Ant-v2"}
seed = 1
total_timesteps = 1000000
learning_rate = 0.0003
buffer_size = 1000000
gamma = 0.99
tau = 0.005
batch_size = 512
policy_noise = 0.2
exploration_noise = 0.4
learning_starts = 25000
policy_frequency = 2
noise_clip = 0.5

# %%
train(
    env["humanoid"],
    seed,
    total_timesteps,
    learning_rate,
    buffer_size,
    gamma,
    tau,
    batch_size,
    policy_noise,
    exploration_noise,
    learning_starts,
    policy_frequency,
    noise_clip
)
# Out:
# wandb: Currently logged in as: chkda. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/notebooks/rl-algos/wandb/run-20231119_071003-jguhdb4k</code>
# Syncing run <strong><a href='https://wandb.ai/chkda/td3-mujoco-benchmark/runs/jguhdb4k' target="_blank">Humanoid-v2__1__1700377799</a></strong> to <a href='https://wandb.ai/chkda/td3-mujoco-benchmark' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/chkda/td3-mujoco-benchmark' target="_blank">https://wandb.ai/chkda/td3-mujoco-benchmark</a>
#  View run at <a href='https://wandb.ai/chkda/td3-mujoco-benchmark/runs/jguhdb4k' target="_blank">https://wandb.ai/chkda/td3-mujoco-benchmark/runs/jguhdb4k</a>
# /usr/local/lib/python3.9/dist-packages/gymnasium/envs/registration.py:523: DeprecationWarning: WARN: The environment Humanoid-v2 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(
# /usr/local/lib/python3.9/dist-packages/gymnasium/envs/mujoco/mujoco_env.py:185: DeprecationWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.deprecation(
# /usr/local/lib/python3.9/dist-packages/gymnasium/utils/passive_env_checker.py:164: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be <class 'numpy.float32'>, actual type: float64
#   logger.warn(
# /usr/local/lib/python3.9/dist-packages/gymnasium/utils/passive_env_checker.py:188: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /usr/local/lib/python3.9/dist-packages/gymnasium/utils/passive_env_checker.py:164: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be <class 'numpy.float32'>, actual type: float64
#   logger.warn(
# /usr/local/lib/python3.9/dist-packages/gymnasium/utils/passive_env_checker.py:188: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# Moviepy - Building video /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-0.mp4
# global_step=23 episodic_return=[121.24579]
# Moviepy - Building video /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-1.mp4.
# Moviepy - Writing video /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-1.mp4
# global_step=47 episodic_return=[119.5225]
# global_step=68 episodic_return=[108.16019]
# global_step=85 episodic_return=[83.25718]
# global_step=102 episodic_return=[83.582855]
# global_step=120 episodic_return=[88.58781]
# global_step=154 episodic_return=[163.99673]
# global_step=176 episodic_return=[104.62305]
# Moviepy - Building video /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-8.mp4.
# Moviepy - Writing video /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-8.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-8.mp4
# global_step=193 episodic_return=[83.57454]
# global_step=218 episodic_return=[129.3954]
# global_step=237 episodic_return=[95.060486]
# global_step=263 episodic_return=[131.10318]
# global_step=283 episodic_return=[100.64491]
# global_step=311 episodic_return=[138.91057]
# global_step=332 episodic_return=[105.19732]
# global_step=378 episodic_return=[228.43713]
# global_step=409 episodic_return=[161.85236]
# global_step=429 episodic_return=[100.045456]
# global_step=448 episodic_return=[94.742546]
# global_step=481 episodic_return=[165.44429]
# global_step=501 episodic_return=[101.72737]
# global_step=534 episodic_return=[164.74854]
# global_step=582 episodic_return=[234.22275]
# global_step=601 episodic_return=[95.23885]
# global_step=629 episodic_return=[140.49931]
# global_step=647 episodic_return=[89.55818]
# global_step=665 episodic_return=[88.441986]
# Moviepy - Building video /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-27.mp4.
# Moviepy - Writing video /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-27.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-27.mp4
# global_step=697 episodic_return=[153.09024]
# global_step=722 episodic_return=[129.82297]
# global_step=742 episodic_return=[98.66413]
# global_step=761 episodic_return=[96.38866]
# global_step=782 episodic_return=[107.38056]
# global_step=800 episodic_return=[89.66012]
# global_step=822 episodic_return=[112.00469]
# global_step=845 episodic_return=[117.41867]
# global_step=868 episodic_return=[118.5095]
# global_step=888 episodic_return=[98.70106]
# global_step=909 episodic_return=[104.24773]
# global_step=941 episodic_return=[161.68684]
# global_step=958 episodic_return=[83.54515]
# global_step=976 episodic_return=[88.36508]
# global_step=999 episodic_return=[116.14726]
# global_step=1017 episodic_return=[89.44524]
# global_step=1036 episodic_return=[95.87257]
# global_step=1069 episodic_return=[159.50243]
# global_step=1093 episodic_return=[121.28822]
# global_step=1112 episodic_return=[95.75477]

# Moviepy - Building video /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-125.mp4.
# Moviepy - Writing video /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-125.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-125.mp4
# global_step=3027 episodic_return=[144.58939]
# global_step=3048 episodic_return=[106.03525]
# global_step=3066 episodic_return=[88.58104]
# global_step=3095 episodic_return=[147.59845]
# global_step=3122 episodic_return=[138.32521]
# global_step=3140 episodic_return=[90.66418]
# global_step=3161 episodic_return=[106.7882]
# global_step=3179 episodic_return=[89.2904]
# global_step=3203 episodic_return=[121.749435]
# global_step=3229 episodic_return=[134.46132]
# global_step=3251 episodic_return=[110.218414]
# global_step=3269 episodic_return=[88.98237]
# global_step=3287 episodic_return=[88.82217]
# global_step=3350 episodic_return=[321.02838]
# global_step=3385 episodic_return=[182.1854]
# global_step=3417 episodic_return=[165.14932]
# global_step=3445 episodic_return=[136.80377]
# global_step=3462 episodic_return=[83.5225]
# global_step=3481 episodic_return=[94.72623]
# global_step=3514 episodic_return=[171.73305]
# global_step=3533 episodic_return=[93.33027]
# global_step=3560 episodic_return=[132.57335]
# global_step=3588 episodic_return=[140.26161]
# global_step=3606 episodic_return=[88.6801]
# global_step=3632 episodic_return=[136.48152]
# global_step=3652 episodic_return=[98.03257]
# global_step=3675 episodic_return=[116.01856]
# global_step=3701 episodic_return=[130.17352]
# global_step=3728 episodic_return=[139.62941]
# global_step=3751 episodic_return=[112.47064]
# global_step=3770 episodic_return=[95.51865]
# global_step=3796 episodic_return=[136.88425]
# global_step=3848 episodic_return=[250.8129]
# global_step=3869 episodic_return=[105.674736]
# global_step=3887 episodic_return=[89.50798]
# global_step=3904 episodic_return=[83.37486]
# global_step=3925 episodic_return=[107.80575]
# global_step=3967 episodic_return=[215.04942]
# global_step=3999 episodic_return=[155.01463]
# global_step=4025 episodic_return=[132.9666]
# global_step=4045 episodic_return=[101.27663]
# global_step=4070 episodic_return=[128.83743]
# global_step=4090 episodic_return=[100.60416]
# global_step=4126 episodic_return=[169.724]
# global_step=4145 episodic_return=[95.03794]
# global_step=4184 episodic_return=[195.72476]
# global_step=4202 episodic_return=[89.29097]
# global_step=4220 episodic_return=[89.298294]
# global_step=4256 episodic_return=[172.73427]
# global_step=4276 episodic_return=[101.15409]
# global_step=4311 episodic_return=[175.01514]
# global_step=4332 episodic_return=[105.45072]
# global_step=4351 episodic_return=[93.27296]
# global_step=4369 episodic_return=[88.16554]
# global_step=4387 episodic_return=[88.72995]
# global_step=4409 episodic_return=[111.23827]
# global_step=4427 episodic_return=[89.21815]
# global_step=4457 episodic_return=[147.92781]
# global_step=4485 episodic_return=[144.12381]
# global_step=4504 episodic_return=[94.541695]
# global_step=4531 episodic_return=[137.28703]
# global_step=4551 episodic_return=[101.27413]
# global_step=4574 episodic_return=[118.548676]
# global_step=4609 episodic_return=[180.97482]
# global_step=4628 episodic_return=[94.92812]
# global_step=22383 episodic_return=[107.72811]
# global_step=22414 episodic_return=[155.0533]
# global_step=22440 episodic_return=[135.95566]
# global_step=22458 episodic_return=[90.75524]
# global_step=22478 episodic_return=[100.43152]
# global_step=22500 episodic_return=[111.10857]
# global_step=22524 episodic_return=[125.14558]
# global_step=22541 episodic_return=[83.670815]
# global_step=22563 episodic_return=[113.50871]
# global_step=22595 episodic_return=[157.56789]
# global_step=22613 episodic_return=[90.15433]
# global_step=22662 episodic_return=[235.49472]
# global_step=22689 episodic_return=[141.48706]
# global_step=22718 episodic_return=[148.02905]
# global_step=22736 episodic_return=[88.62122]
# global_step=22764 episodic_return=[146.9431]
# global_step=22782 episodic_return=[88.871895]
# global_step=22800 episodic_return=[89.043724]
# global_step=22835 episodic_return=[183.03596]
# global_step=22853 episodic_return=[88.878975]
# global_step=22888 episodic_return=[172.02269]
# global_step=22907 episodic_return=[94.61527]
# global_step=22931 episodic_return=[124.45307]
# global_step=22982 episodic_return=[268.65887]
# ...
# global_step=732680 episodic_return=[5200.345]
# global_step=733680 episodic_return=[5168.292]
# global_step=734680 episodic_return=[5218.1035]
# global_step=735680 episodic_return=[5172.0366]
# global_step=736680 episodic_return=[5154.4966]
# global_step=737680 episodic_return=[5199.487]
# global_step=738680 episodic_return=[5066.2085]
# global_step=738789 episodic_return=[560.2845]
# global_step=739789 episodic_return=[5180.2046]
# global_step=739934 episodic_return=[750.83997]
# global_step=740934 episodic_return=[5178.5884]
# global_step=741934 episodic_return=[5154.0146]
# global_step=742934 episodic_return=[5086.2715]
# global_step=743934 episodic_return=[5106.3965]
# global_step=744934 episodic_return=[5128.882]
# global_step=745934 episodic_return=[5036.1147]
# global_step=746934 episodic_return=[5170.472]
# global_step=747934 episodic_return=[5181.6885]
# global_step=748456 episodic_return=[2683.3103]
# global_step=749456 episodic_return=[5195.924]
# global_step=749971 episodic_return=[2706.6199]
# global_step=750971 episodic_return=[5203.7686]
# global_step=751971 episodic_return=[5082.9053]
# global_step=752930 episodic_return=[4985.141]
# global_step=753930 episodic_return=[5196.198]
# global_step=754930 episodic_return=[5165.376]
# global_step=755930 episodic_return=[5238.1846]
# global_step=756930 episodic_return=[5156.163]
# global_step=757930 episodic_return=[5238.064]
# global_step=758930 episodic_return=[5186.496]
# global_step=759930 episodic_return=[5261.117]
# global_step=760930 episodic_return=[5253.1484]
# global_step=761930 episodic_return=[5211.75]
# global_step=762930 episodic_return=[5237.8315]
# global_step=763930 episodic_return=[5263.028]
# global_step=764930 episodic_return=[5205.328]
# global_step=765930 episodic_return=[5213.823]
# global_step=766930 episodic_return=[5247.9487]
# global_step=767930 episodic_return=[5308.726]
# global_step=768930 episodic_return=[5194.9155]
# global_step=769930 episodic_return=[5275.1875]
# global_step=770930 episodic_return=[5187.7344]
# global_step=771930 episodic_return=[5220.1167]
# global_step=772930 episodic_return=[5228.895]
# global_step=773930 episodic_return=[5215.9165]
# global_step=774930 episodic_return=[5179.9126]
# global_step=775135 episodic_return=[1154.5094]
# global_step=845004 episodic_return=[2751.5684]
# global_step=846004 episodic_return=[5144.2896]
# global_step=847004 episodic_return=[5194.331]
# global_step=848004 episodic_return=[5230.936]
# global_step=849004 episodic_return=[5078.425]
# global_step=850004 episodic_return=[5256.0146]
# global_step=851004 episodic_return=[5257.81]
# global_step=852004 episodic_return=[5257.314]
# global_step=853004 episodic_return=[5277.693]
# global_step=854004 episodic_return=[5301.3535]
# global_step=855004 episodic_return=[5056.773]
# global_step=856004 episodic_return=[5270.875]
# global_step=857004 episodic_return=[5261.9595]
# global_step=858004 episodic_return=[4995.2275]
# global_step=859004 episodic_return=[5259.3374]
# global_step=860004 episodic_return=[5233.631]
# global_step=861004 episodic_return=[5172.9746]
# global_step=862004 episodic_return=[5216.627]
# global_step=863004 episodic_return=[5160.076]
# global_step=863578 episodic_return=[2925.7393]
# global_step=864277 episodic_return=[3662.8198]
# global_step=865277 episodic_return=[5209.0366]
# global_step=866277 episodic_return=[5234.356]
# global_step=867277 episodic_return=[5192.916]
# global_step=868277 episodic_return=[5228.2134]
# global_step=869277 episodic_return=[5296.537]
# global_step=870277 episodic_return=[5126.334]
# global_step=871277 episodic_return=[5234.2563]
# global_step=872101 episodic_return=[4372.208]
# global_step=873101 episodic_return=[5266.7446]
# global_step=874101 episodic_return=[5177.1445]
# global_step=875101 episodic_return=[5262.51]
# global_step=876101 episodic_return=[5213.4204]
# global_step=877101 episodic_return=[5227.606]
# global_step=878101 episodic_return=[5105.97]
# global_step=879101 episodic_return=[5184.09]
# global_step=880101 episodic_return=[5244.088]
# global_step=881101 episodic_return=[5327.5522]
# global_step=882101 episodic_return=[5231.064]
# global_step=883101 episodic_return=[5248.614]
# global_step=883309 episodic_return=[1010.09033]
# global_step=884309 episodic_return=[5149.3335]
# global_step=885309 episodic_return=[5173.3984]
# global_step=886309 episodic_return=[5209.8555]
# global_step=887309 episodic_return=[5225.367]
# global_step=888309 episodic_return=[5224.427]
# global_step=889309 episodic_return=[5239.07]
# global_step=890309 episodic_return=[5317.55]
# global_step=891309 episodic_return=[5258.3945]
# global_step=892309 episodic_return=[5269.859]
# global_step=893309 episodic_return=[5115.0405]
# global_step=894309 episodic_return=[5239.921]
# global_step=895309 episodic_return=[5196.1255]
# global_step=896309 episodic_return=[5257.568]
# global_step=897309 episodic_return=[5262.381]
# global_step=898309 episodic_return=[5199.353]
# global_step=899309 episodic_return=[5300.5615]
# global_step=900309 episodic_return=[5208.819]
# global_step=901309 episodic_return=[5250.9937]
# global_step=902309 episodic_return=[5207.7505]
# global_step=903279 episodic_return=[4900.529]
# global_step=904279 episodic_return=[5201.7544]
# global_step=905279 episodic_return=[5281.187]
# global_step=906279 episodic_return=[5189.3555]
# global_step=907279 episodic_return=[5275.6865]
# global_step=907889 episodic_return=[3204.9675]
# global_step=908889 episodic_return=[5283.208]
# global_step=909889 episodic_return=[5297.604]
# global_step=910889 episodic_return=[5312.428]
# global_step=911889 episodic_return=[5239.1826]
# global_step=912889 episodic_return=[5257.449]
# global_step=913889 episodic_return=[5273.9453]
# global_step=914888 episodic_return=[5376.6274]
# global_step=915888 episodic_return=[5265.803]
# global_step=916156 episodic_return=[1439.1797]
# global_step=917156 episodic_return=[5204.3213]
# global_step=918156 episodic_return=[5285.2437]
# Moviepy - Building video /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-5000.mp4.
# Moviepy - Writing video /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-5000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl-algos/videos/Humanoid-v2__1__1700377799/rl-video-episode-5000.mp4
# global_step=919156 episodic_return=[5263.2183]
# global_step=920156 episodic_return=[5258.71]
# global_step=921156 episodic_return=[5182.184]
# global_step=922156 episodic_return=[5214.099]
# global_step=923156 episodic_return=[5197.045]
# global_step=924156 episodic_return=[5200.3115]
# global_step=924582 episodic_return=[2257.1204]
# global_step=925582 episodic_return=[5261.934]
# global_step=926582 episodic_return=[5222.3306]
# global_step=927582 episodic_return=[5156.303]
# global_step=928582 episodic_return=[5265.825]
# global_step=929582 episodic_return=[5229.543]
# global_step=930582 episodic_return=[5137.8506]
# global_step=931582 episodic_return=[5285.85]
# global_step=932582 episodic_return=[5204.3286]
# global_step=932698 episodic_return=[641.55176]
# global_step=933698 episodic_return=[5212.221]
# global_step=934698 episodic_return=[5206.1255]
# global_step=935698 episodic_return=[5165.8784]
# global_step=935920 episodic_return=[1120.8134]
# global_step=936920 episodic_return=[5228.0156]
# global_step=937920 episodic_return=[5143.7085]
# global_step=938920 episodic_return=[5195.8984]
# global_step=939920 episodic_return=[5021.502]
# global_step=940920 episodic_return=[5096.473]
# global_step=941920 episodic_return=[5186.7085]
# global_step=942920 episodic_return=[5142.9062]
# global_step=943920 episodic_return=[5151.0933]
# global_step=944920 episodic_return=[5170.3003]
# global_step=945920 episodic_return=[5167.2217]
# global_step=946868 episodic_return=[4913.966]
# global_step=947868 episodic_return=[5201.0815]
# global_step=948868 episodic_return=[5200.5576]
# global_step=949868 episodic_return=[5182.8696]
# global_step=950868 episodic_return=[5210.723]
# global_step=951868 episodic_return=[5201.602]
# global_step=952868 episodic_return=[5144.8486]
# global_step=953868 episodic_return=[5209.1055]
# global_step=954868 episodic_return=[5178.251]
# global_step=955868 episodic_return=[5225.9375]
# global_step=956868 episodic_return=[5167.0615]
# global_step=957868 episodic_return=[5196.9136]
# global_step=958868 episodic_return=[5205.725]
# global_step=959868 episodic_return=[5225.696]
# global_step=960868 episodic_return=[5262.984]
# global_step=961868 episodic_return=[5275.756]
# global_step=962868 episodic_return=[5237.001]
# global_step=963868 episodic_return=[5225.838]
# global_step=964868 episodic_return=[5227.694]
# global_step=965868 episodic_return=[5260.8843]
# global_step=966868 episodic_return=[5224.3916]
# global_step=967868 episodic_return=[5174.812]
# global_step=968868 episodic_return=[5229.5547]
# global_step=969868 episodic_return=[5288.604]
# global_step=970868 episodic_return=[5269.448]
# global_step=971868 episodic_return=[5137.711]
# global_step=972868 episodic_return=[5165.4795]
# global_step=973868 episodic_return=[5187.809]
# global_step=974868 episodic_return=[5198.422]
# global_step=975868 episodic_return=[5281.6045]
# global_step=976868 episodic_return=[5186.3936]
# global_step=977868 episodic_return=[5304.407]
# global_step=978868 episodic_return=[5227.575]
# global_step=979868 episodic_return=[5170.7344]
# global_step=980868 episodic_return=[5217.5938]
# global_step=981868 episodic_return=[5268.9062]
# global_step=982868 episodic_return=[5231.272]
# global_step=983868 episodic_return=[5274.0195]
# global_step=983974 episodic_return=[553.6561]
# global_step=984515 episodic_return=[2877.4348]
# global_step=985515 episodic_return=[5255.598]
# global_step=986515 episodic_return=[5261.243]
# global_step=987515 episodic_return=[5229.648]
# global_step=988515 episodic_return=[5202.271]
# global_step=989515 episodic_return=[5089.552]
# global_step=990515 episodic_return=[5195.8076]
# global_step=991515 episodic_return=[5242.6426]
# global_step=992515 episodic_return=[5288.3076]
# global_step=993515 episodic_return=[5260.0625]
# global_step=994515 episodic_return=[5304.1387]
# global_step=995515 episodic_return=[5320.313]
# global_step=996515 episodic_return=[5302.2446]
# global_step=997515 episodic_return=[5239.7163]
# global_step=998515 episodic_return=[5265.5435]
# global_step=999515 episodic_return=[5220.7856]
# VBox(children=(Label(value='6.524 MB of 6.524 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>charts/SPS</td><td>█▅▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>charts/episodic_length</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▂▂▁▂▂▂▂▁▂▂▃▃██████</td></tr><tr><td>charts/episodic_return</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▂▂▁▂▂▂▂▁▂▂▃▃██████</td></tr><tr><td>global_step</td><td>▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>losses/actor_loss</td><td>█▇▆▆▆▆▆▆▆▆▅▅▅▅▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>losses/qf1_loss</td><td>▁▁▂▃▅▄▄▄▄▄▅▅▆▅▇▇▇▇▇▇█▆▇█▇▆▆▇█▆▇▆▇▆▇▇▅▇▇▆</td></tr><tr><td>losses/qf1_values</td><td>▁▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇█▇▇▇███████</td></tr><tr><td>losses/qf2_loss</td><td>▁▁▂▄▅▄▄▄▄▄▄▆▅▇▇█▇█▇▇▇███▇▇█▇▇▇▇▇█▇▆█▇▇▇▆</td></tr><tr><td>losses/qf2_values</td><td>▁▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇█▇▇▇███████</td></tr><tr><td>losses/qf_loss</td><td>▁▁▂▄▅▄▄▄▄▄▅▅▆▆▇▇▇█▇▇█▇██▇▇▇▇█▆▇▇▇▇▇▇▆▇▇▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>charts/SPS</td><td>90.0</td></tr><tr><td>charts/episodic_length</td><td>1000.0</td></tr><tr><td>charts/episodic_return</td><td>5220.78564</td></tr><tr><td>global_step</td><td>999900</td></tr><tr><td>losses/actor_loss</td><td>-420.78198</td></tr><tr><td>losses/qf1_loss</td><td>53.95958</td></tr><tr><td>losses/qf1_values</td><td>417.00497</td></tr><tr><td>losses/qf2_loss</td><td>43.33659</td></tr><tr><td>losses/qf2_values</td><td>418.29453</td></tr><tr><td>losses/qf_loss</td><td>48.64809</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Humanoid-v2__1__1700377799</strong> at: <a href='https://wandb.ai/chkda/td3-mujoco-benchmark/runs/jguhdb4k' target="_blank">https://wandb.ai/chkda/td3-mujoco-benchmark/runs/jguhdb4k</a><br/> View job at <a href='https://wandb.ai/chkda/td3-mujoco-benchmark/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjExNjg3MTg5Mw==/version_details/v1' target="_blank">https://wandb.ai/chkda/td3-mujoco-benchmark/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjExNjg3MTg5Mw==/version_details/v1</a><br/>Synced 5 W&B file(s), 15 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231119_071003-jguhdb4k/logs</code>
